# %% [markdown]
# # COMP30850- Assignment 1
# <b>By Brian Byrne - 18391933</b>
# The goal of this assignment is to construct and characterise network representations
# of two movie-related datasets. The datasets were identically structured JSON files containing data on different actors.The datasets were retrieved from a perosnalised zip file from <i>http://mlg.ucd.ie/modules/COMP30850/datasets/18391933.zip</i>. For the purpose of this study i have split the assignment into 4 sections:
# * <b>Network Construction</b>- Using the datasets to create a structured, weighted co-starring network of actors.
# * <b>Network Characterisation</b>- Using connectivity, visual and centrality measurement techniques to understand the layout and dimensions of the network.
# * <b>Ego-centric analysis</b>- Designing a subnetwork of the two larger networks out of important nodes for more percise and indepth analytics.
# * <b>Network Visualisation</b>- Using Gephi software tools to create more detailled networks graphs than would be possible using Jupyter Networks on it's own.

# %%
# Importing of relevant packagages 
import networkx as nx
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %% [markdown]
# ## 1. Network construction
#
# ### Loading the Data
# For this exercise we will parse the JSON data into pandas dataframes, for cleaning and filtering.

# %%
#Loading in of Datasets
load_set1=open("18391933-dataset1.json",)
set1_data=json.load(load_set1)
load_set1.close()

load_set2=open("18391933-dataset2.json",)
set2_data=json.load(load_set2)
load_set2.close()

# %% [markdown]
# <b>set1_df</b> and <b>set2_df</b> represent the two datasets from the zip file respectively.

# %%
#Adding the JSON datasets to pandas dataframes
set1_df=pd.DataFrame(set1_data)
set2_df=pd.DataFrame(set2_data)

set1_df.head()
# Out:
#         id             name        born  \
# 0   000128    Russell Crowe  1964-04-07
# 1  0206257   Rosario Dawson  1979-05-09
# 2   000905  Roberto Benigni  1952-10-27
# 3  0001833     Emily Watson  1967-01-14
# 4  5052065     Ansel Elgort  1994-03-14
#
#                                               movies
# 0  [{'id': '10059518', 'title': 'Unhinged', 'year...
# 1  [{'id': '13787320', 'title': 'Rocky Horror Sho...
# 2  [{'id': '8333746', 'title': 'Pinocchio', 'year...
# 3  [{'id': '10482370', 'title': 'The Third Day', ...
# 4  [{'id': '3864056', 'title': 'The Goldfinch', '...

# %%
set2_df.head()
# Out:
#         id               name        born  \
# 0  0000538        Colm Meaney  1953-05-30
# 1  0914455     Leonor Watling  1975-07-28
# 2  0000932        Halle Berry  1966-08-14
# 3  0000138  Leonardo DiCaprio  1974-11-11
# 4  0591485      Liza Minnelli  1946-03-12
#
#                                               movies
# 0  [{'id': '13356010', 'title': 'The Monkey', 'ye...
# 1  [{'id': '10039610', 'title': 'Mi hermano Juan'...
# 2  [{'id': '8310474', 'title': 'Bruised', 'year':...
# 3  [{'id': '8690814', 'title': 'Grant', 'year': 2...
# 4  [{'id': '10908058', 'title': 'The King of Come...

# %% [markdown]
# Our pandas dataframes clearly tell show the name, id, date of bith and an intricate list of details regarding each of the films we that they have starred in.
#
# ### Data cleaning
# After observing the data, we can remove unnecessary columns, as part of our data preprocessing. Moreover, we will construct dictionarys for each set where the key is each of the actors present and the values assigned to that key is a list of the "film id"s that the actors starred in. I chose to use film ID's as opposed to the films names as it is not uncommon for two or more films to have the exact same name. I.E. if I were to use the film name "Gulliver's Travels", then actors who starred in the 1977 film would be connected to actors who starred in the 2010 remake of the same name, which would be inaccurate.

# %%
#Function to remove unnecessary columns from the datasets
def clean(df):
    del df["id"]
    del df["born"]
    
    
clean(set1_df)
clean(set2_df)

# %%
set1_df.head()
# Out:
#               name                                             movies
# 0    Russell Crowe  [{'id': '10059518', 'title': 'Unhinged', 'year...
# 1   Rosario Dawson  [{'id': '13787320', 'title': 'Rocky Horror Sho...
# 2  Roberto Benigni  [{'id': '8333746', 'title': 'Pinocchio', 'year...
# 3     Emily Watson  [{'id': '10482370', 'title': 'The Third Day', ...
# 4     Ansel Elgort  [{'id': '3864056', 'title': 'The Goldfinch', '...

# %%
#Listing the actors by name to use as keys in future dictionarys and nodes
actors1=set1_df["name"]
actors2=set2_df["name"]

# %%
#this dictionary will return all the films of a specific actor when you use their name as the key
# in the dictionary
by_actor1={}
i=0
for actor in actors1:
    films=[]                  #The list of films for a given actor
    star=set1_df["movies"][i]
    limit=len(star)
    
    for j in range (0,limit):
        temp=set1_df["movies"][i][j]["id"]
        films.append(temp)
    
    by_actor1[actor]=films     #Filling in our dictionary
    i=i+1
    
 #######################################################################################   
## Repeating the process for the second dataset
by_actor2={}
i=0
for actor in actors2:
    films=[]
    star=set2_df["movies"][i]
    limit=len(star)
    
    for j in range (0,limit):
        temp=set2_df["movies"][i][j]["id"]
        films.append(temp)
    
    by_actor2[actor]=films
    i=i+1

# %% [markdown]
# ### Construction of Networks
# Now that we have dictionarys listing the film credit ids to each actor, we can constuct our network. Here I used the networkX library tools to build my graph. I wrote the following algorithm that identifies if two actors have any mutual film credits using nested for loops. The .intersection function returns and integer of the number of mutual film credits each actor has.This is equal to the weight of the edge between the two nodes. If there is one or more intersections, then two nodes and a weighted edge will be constructed within the graph. Another benefit of building by edges rather than by node, is that any <b>isolated nodes</b> (nodes that have no neighbours but exist in the networks) will not be included in the graph.

# %%
g1=nx.Graph()

## Use loops and the intersection function to find those that intersect

    
for i in range (len(actors1)-1):     #Comparing the films of actors to find costars
    list1=by_actor1[actors1[i]]
    for j in range(i+1,len(actors1)):
        list1_asSet=set(list1)
        list2=by_actor1[actors1[j]]
        intersection=list(list1_asSet.intersection(list2))  #list of mutually starred films by the two actors
        
        if intersection:
            g1.add_edge(actors1[i],actors1[j], weight=len(intersection))    
           #edges of actors who co-star in more films will be weighted by the number of mutual films they have   
##########################################################################################
#I have chosen this algorithm to populate my graph, as it assembles weighted edges and ignores
# isolated nodes that are independent of the other nodes (i.e has not co-starred with any actors in the dataset)
##########################################################################################
## Repeating the process for the second dataset
g2=nx.Graph()

    
for i in range (len(actors2)-1):
    list1=by_actor2[actors2[i]]
    for j in range(i+1,len(actors2)):
        list1_asSet=set(list1)
        list2=by_actor2[actors2[j]]
        intersection=list(list1_asSet.intersection(list2))
        
        if intersection:
            g2.add_edge(actors2[i],actors2[j], weight=len(intersection))

# %% [markdown]
# Now that we have created the two graphs from the networks, we can use the following functions to make sure graphs of the two networks have been successfully implemented

# %%
# Functions for displaying data and graphs of our networks
# Function to print edges 
def showEdges(graph):
    for edge in graph.edges(data=True):
        print(edge)

# Function to print nodes 
def showNodes(graph):
    for node in graph.nodes(data=True):
        print(node)
        
#function to draw our existing graph
def drawGraph(graph):
    plt.figure(figsize=(20,20))
    nx.draw_networkx(graph, with_labels=True, node_size=700, node_color="cyan" )
    plt.axis("off")
    plt.show()
# Function
def networkSizes(graph):
    print("Number of nodes:",graph.number_of_nodes())
    print("Number of edges:",graph.number_of_edges())

# %%
drawGraph(g1)
networkSizes(g1)
# Out:
# Number of nodes: 148
# Number of edges: 1425

# %%
showEdges(g1)
# Out:
# ('Russell Crowe', 'Diane Kruger', {'weight': 1})
# ('Russell Crowe', 'Christian Bale', {'weight': 1})
# ('Russell Crowe', 'Helena Bonham Carter', {'weight': 1})
# ('Russell Crowe', 'Gene Hackman', {'weight': 1})
# ('Russell Crowe', 'Jane Fonda', {'weight': 1})
# ('Russell Crowe', 'Cate Blanchett', {'weight': 1})
# ('Russell Crowe', 'Colin Farrell', {'weight': 1})
# ('Russell Crowe', 'Ben Kingsley', {'weight': 1})
# ('Russell Crowe', 'Jim Broadbent', {'weight': 1})
# ('Russell Crowe', 'Marion Cotillard', {'weight': 1})
# ('Russell Crowe', 'Amy Adams', {'weight': 1})
# ('Russell Crowe', 'Kevin Spacey', {'weight': 1})
# ('Russell Crowe', 'Tilda Swinton', {'weight': 1})
# ('Russell Crowe', 'Anthony Hopkins', {'weight': 2})
# ('Russell Crowe', 'Emma Watson', {'weight': 1})
# ('Diane Kruger', 'Mélanie Laurent', {'weight': 1})
# ('Diane Kruger', 'Michael Fassbender', {'weight': 1})
# ('Diane Kruger', 'Sarah Polley', {'weight': 1})
# ('Diane Kruger', 'Jane Fonda', {'weight': 1})
# ('Diane Kruger', 'Alexandra Maria Lara', {'weight': 1})
# ('Diane Kruger', 'Cate Blanchett', {'weight': 1})
# ('Diane Kruger', 'Tom Vaughan-Lawlor', {'weight': 1})
# ('Diane Kruger', 'Julie Christie', {'weight': 1})
# ('Diane Kruger', 'Nicolas Cage', {'weight': 2})
# ('Christian Bale', 'Emily Watson', {'weight': 2})
# ('Christian Bale', 'Sigourney Weaver', {'weight': 1})
# ('Christian Bale', 'Helena Bonham Carter', {'weight': 1})
# ('Christian Bale', 'Matt Damon', {'weight': 1})
# ('Christian Bale', 'Kenneth Branagh', {'weight': 2})
# ('Christian Bale', 'Cillian Murphy', {'weight': 3})
# ('Christian Bale', 'Cate Blanchett', {'weight': 3})
# ('Christian Bale', 'Frances McDormand', {'weight': 1})
# ('Christian Bale', 'Natalie Portman', {'weight': 1})
# ('Christian Bale', 'Colin Farrell', {'weight': 1})
# ('Christian Bale', 'Hiam Abbass', {'weight': 1})
# ('Christian Bale', 'Ben Kingsley', {'weight': 2})
# ('Christian Bale', 'Michelle Pfeiffer', {'weight': 1})
# ('Christian Bale', 'David Thewlis', {'weight': 1})
# ('Christian Bale', 'Jim Broadbent', {'weight': 1})
# ('Christian Bale', 'Marion Cotillard', {'weight': 2})
# ('Christian Bale', 'Ben Stiller', {'weight': 1})
# ('Christian Bale', 'Reese Witherspoon', {'weight': 1})
# ('Christian Bale', 'Robert De Niro', {'weight': 1})
# ('Christian Bale', 'Amy Adams', {'weight': 3})
# ('Christian Bale', 'Terry Crews', {'weight': 2})
# ('Christian Bale', 'Jonathan Pryce', {'weight': 1})
# ('Christian Bale', 'Forest Whitaker', {'weight': 1})
# ('Christian Bale', 'Susan Sarandon', {'weight': 1})
# ('Christian Bale', 'Andy Serkis', {'weight': 3})
# ('Christian Bale', 'Robbie Coltrane', {'weight': 1})
# ('Christian Bale', "Brían F. O'Byrne", {'weight': 1})
# ('Christian Bale', 'Winona Ryder', {'weight': 1})
# ('Christian Bale', 'Steve Zahn', {'weight': 1})
# ('Christian Bale', 'Nicolas Cage', {'weight': 1})
# ('Christian Bale', 'Aidan Gillen', {'weight': 1})
# ('Helena Bonham Carter', 'Emily Watson', {'weight': 1})
# ('Helena Bonham Carter', 'Ciarán Hinds', {'weight': 2})
# ('Helena Bonham Carter', 'Bonnie Wright', {'weight': 4})
# ('Helena Bonham Carter', 'Edward Norton', {'weight': 1})
# ('Helena Bonham Carter', 'F. Murray Abraham', {'weight': 1})
# ('Helena Bonham Carter', 'Toby Jones', {'weight': 1})
# ('Helena Bonham Carter', 'Maggie Smith', {'weight': 4})
# ('Helena Bonham Carter', 'Alan Rickman', {'weight': 7})
# ('Helena Bonham Carter', 'Mickey Rourke', {'weight': 1})
# ('Helena Bonham Carter', 'Tom Felton', {'weight': 4})
# ('Helena Bonham Carter', 'Kenneth Branagh', {'weight': 2})
# ('Helena Bonham Carter', 'Jim Carrey', {'weight': 1})
# ('Helena Bonham Carter', 'Sandra Bullock', {'weight': 1})
# ('Helena Bonham Carter', 'Cate Blanchett', {'weight': 2})
# ('Helena Bonham Carter', 'Glenn Close', {'weight': 1})
# ('Helena Bonham Carter', 'Ben Kingsley', {'weight': 3})
# ('Helena Bonham Carter', 'Michelle Pfeiffer', {'weight': 1})
# ('Helena Bonham Carter', 'David Thewlis', {'weight': 4})
# ('Helena Bonham Carter', 'Jim Broadbent', {'weight': 2})
# ('Helena Bonham Carter', 'Marion Cotillard', {'weight': 1})
# ('Helena Bonham Carter', 'Robert De Niro', {'weight': 1})
# ('Helena Bonham Carter', 'Helen McCrory', {'weight': 3})
# ('Helena Bonham Carter', 'Chloë Grace Moretz', {'weight': 1})
# ('Helena Bonham Carter', 'Sam Neill', {'weight': 3})
# ('Helena Bonham Carter', 'Terry Crews', {'weight': 1})
# ('Helena Bonham Carter', 'Matt Lucas', {'weight': 2})
# ('Helena Bonham Carter', 'Robbie Coltrane', {'weight': 5})
# ('Helena Bonham Carter', 'Anthony Hopkins', {'weight': 1})
# ('Helena Bonham Carter', 'Emma Watson', {'weight': 4})
# ('Helena Bonham Carter', 'Imelda Staunton', {'weight': 5})
# ('Helena Bonham Carter', 'Geoffrey Rush', {'weight': 1})
# ('Helena Bonham Carter', 'Colin Firth', {'weight': 1})
# ('Helena Bonham Carter', 'Meryl Streep', {'weight': 2})
# ('Gene Hackman', 'Sigourney Weaver', {'weight': 1})
# ('Gene Hackman', 'Matt Damon', {'weight': 1})
# ('Gene Hackman', 'Jack Black', {'weight': 1})
# ('Gene Hackman', 'Bette Midler', {'weight': 1})
# ('Gene Hackman', 'Mickey Rourke', {'weight': 1})
# ('Gene Hackman', 'Zach Galifianakis', {'weight': 1})
# ('Gene Hackman', 'Richard Dreyfuss', {'weight': 1})
# ('Gene Hackman', 'Frances McDormand', {'weight': 1})
# ('Gene Hackman', 'James Gandolfini', {'weight': 3})
# ('Gene Hackman', 'Laura Linney', {'weight': 1})
# ('Gene Hackman', 'Jim Broadbent', {'weight': 1})
# ('Gene Hackman', 'Ben Stiller', {'weight': 1})
# ('Gene Hackman', 'Reese Witherspoon', {'weight': 1})
# ('Gene Hackman', 'Joe Pesci', {'weight': 1})
# ('Gene Hackman', 'Julie Christie', {'weight': 1})
# ('Gene Hackman', 'Rachel Weisz', {'weight': 1})
# ('Gene Hackman', 'Kathy Bates', {'weight': 1})
# ('Gene Hackman', 'Susan Sarandon', {'weight': 1})
# ('Gene Hackman', 'Anthony Hopkins', {'weight': 1})
# ('Gene Hackman', 'Sylvester Stallone', {'weight': 1})
# ('Gene Hackman', 'Marcia Gay Harden', {'weight': 1})
# ('Gene Hackman', 'Laurence Olivier', {'weight': 1})
# ('Gene Hackman', 'Steve Zahn', {'weight': 1})
# ('Gene Hackman', 'Holly Hunter', {'weight': 1})
# ('Gene Hackman', 'Meryl Streep', {'weight': 1})
# ('Gene Hackman', 'Jennifer Lopez', {'weight': 1})
# ('Jane Fonda', 'Michael Douglas', {'weight': 1})
# ('Jane Fonda', 'Henry Fonda', {'weight': 1})
# ('Jane Fonda', 'Maggie Smith', {'weight': 1})
# ('Jane Fonda', 'Bette Midler', {'weight': 1})
# ('Jane Fonda', 'Alan Rickman', {'weight': 1})
# ('Jane Fonda', 'Richard Dreyfuss', {'weight': 1})
# ('Jane Fonda', 'Adam Driver', {'weight': 1})
# ('Jane Fonda', 'Robert De Niro', {'weight': 1})
# ('Jane Fonda', 'Rachel Weisz', {'weight': 1})
# ('Jane Fonda', 'Kathy Bates', {'weight': 1})
# ('Jane Fonda', 'Forest Whitaker', {'weight': 1})
# ('Jane Fonda', 'Tina Fey', {'weight': 1})
# ('Jane Fonda', 'Betty White', {'weight': 1})
# ('Jane Fonda', 'Meryl Streep', {'weight': 2})
# ('Jane Fonda', 'Jennifer Lopez', {'weight': 1})
# ('Cate Blanchett', 'Roberto Benigni', {'weight': 1})
# ('Cate Blanchett', 'Ciarán Hinds', {'weight': 2})
# ('Cate Blanchett', 'F. Murray Abraham', {'weight': 1})
# ('Cate Blanchett', 'Matt Damon', {'weight': 4})
# ('Cate Blanchett', 'Jack Black', {'weight': 1})
# ('Cate Blanchett', 'Michael Fassbender', {'weight': 1})
# ('Cate Blanchett', 'Sandra Bullock', {'weight': 1})
# ('Cate Blanchett', 'Frances McDormand', {'weight': 1})
# ('Cate Blanchett', 'Glenn Close', {'weight': 1})
# ('Cate Blanchett', 'Natalie Portman', {'weight': 2})
# ('Cate Blanchett', 'Colin Farrell', {'weight': 1})
# ('Cate Blanchett', 'Ben Kingsley', {'weight': 1})
# ('Cate Blanchett', 'Jim Broadbent', {'weight': 2})
# ('Cate Blanchett', 'Helen McCrory', {'weight': 1})
# ('Cate Blanchett', 'Kevin Spacey', {'weight': 1})
# ('Cate Blanchett', 'Sam Neill', {'weight': 2})
# ('Cate Blanchett', 'Forest Whitaker', {'weight': 1})
# ('Cate Blanchett', 'Tina Fey', {'weight': 1})
# ('Cate Blanchett', 'Jean Dujardin', {'weight': 1})
# ('Cate Blanchett', 'Bruce Willis', {'weight': 1})
# ('Cate Blanchett', 'Betty White', {'weight': 1})
# ('Cate Blanchett', 'Tilda Swinton', {'weight': 1})
# ('Cate Blanchett', 'Andy Serkis', {'weight': 5})
# ('Cate Blanchett', "Brían F. O'Byrne", {'weight': 1})
# ('Cate Blanchett', 'Anthony Hopkins', {'weight': 1})
# ('Cate Blanchett', 'Ian McKellen', {'weight': 6})
# ('Cate Blanchett', 'Geoffrey Rush', {'weight': 3})
# ('Cate Blanchett', 'Steve Zahn', {'weight': 1})
# ('Cate Blanchett', 'Samantha Morton', {'weight': 1})
# ('Cate Blanchett', 'Holly Hunter', {'weight': 1})
# ('Cate Blanchett', 'Meryl Streep', {'weight': 1})
# ('Colin Farrell', 'Rosario Dawson', {'weight': 1})
# ('Colin Farrell', 'Sissy Spacek', {'weight': 1})
# ('Colin Farrell', 'Ciarán Hinds', {'weight': 3})
# ('Colin Farrell', 'Jennifer Aniston', {'weight': 1})
# ('Colin Farrell', 'Keira Knightley', {'weight': 1})
# ('Colin Farrell', 'Edward Norton', {'weight': 1})
# ('Colin Farrell', 'F. Murray Abraham', {'weight': 1})
# ('Colin Farrell', 'Elizabeth Berrington', {'weight': 1})
# ('Colin Farrell', 'Cillian Murphy', {'weight': 1})
# ('Colin Farrell', 'David Thewlis', {'weight': 2})
# ('Colin Farrell', 'Kevin Spacey', {'weight': 2})
# ('Colin Farrell', 'Rachel Weisz', {'weight': 1})
# ('Colin Farrell', 'Kathy Bates', {'weight': 1})
# ('Colin Farrell', 'Jamie Foxx', {'weight': 2})
# ('Colin Farrell', 'Jonathan Pryce', {'weight': 1})
# ('Colin Farrell', 'Forest Whitaker', {'weight': 1})
# ('Colin Farrell', 'Tom Hanks', {'weight': 1})
# ('Colin Farrell', 'Bruce Willis', {'weight': 1})
# ('Colin Farrell', 'Tilda Swinton', {'weight': 1})
# ('Colin Farrell', "Brían F. O'Byrne", {'weight': 2})
# ('Colin Farrell', 'Anthony Hopkins', {'weight': 2})
# ('Colin Farrell', 'Samantha Morton', {'weight': 3})
# ('Ben Kingsley', 'Sissy Spacek', {'weight': 1})
# ('Ben Kingsley', 'Mélanie Laurent', {'weight': 1})
# ('Ben Kingsley', 'Edward Norton', {'weight': 1})
# ('Ben Kingsley', 'Glenda Jackson', {'weight': 1})
# ('Ben Kingsley', 'Sigourney Weaver', {'weight': 3})
# ('Ben Kingsley', 'F. Murray Abraham', {'weight': 1})
# ('Ben Kingsley', 'Abigail Breslin', {'weight': 1})
# ('Ben Kingsley', 'Patricia Clarkson', {'weight': 3})
# ('Ben Kingsley', 'Maggie Smith', {'weight': 1})
# ('Ben Kingsley', 'Natalie Portman', {'weight': 1})
# ('Ben Kingsley', 'Hiam Abbass', {'weight': 1})
# ('Ben Kingsley', 'David Thewlis', {'weight': 1})
# ('Ben Kingsley', 'Laura Linney', {'weight': 2})
# ('Ben Kingsley', 'Ben Stiller', {'weight': 1})
# ('Ben Kingsley', 'Joan Allen', {'weight': 1})
# ('Ben Kingsley', 'Helen McCrory', {'weight': 1})
# ('Ben Kingsley', 'Chloë Grace Moretz', {'weight': 1})
# ('Ben Kingsley', 'Jonathan Pryce', {'weight': 1})
# ('Ben Kingsley', 'Jessica Alba', {'weight': 1})
# ('Ben Kingsley', 'Carrie-Anne Moss', {'weight': 1})
# ('Ben Kingsley', 'Forest Whitaker', {'weight': 1})
# ('Ben Kingsley', 'Bruce Willis', {'weight': 1})
# ('Ben Kingsley', 'Mark Hamill', {'weight': 1})
# ('Ben Kingsley', 'Tilda Swinton', {'weight': 1})
# ('Ben Kingsley', 'Robbie Coltrane', {'weight': 1})
# ('Ben Kingsley', 'Anthony Hopkins', {'weight': 1})
# ('Ben Kingsley', 'Marcia Gay Harden', {'weight': 1})
# ('Ben Kingsley', 'Imelda Staunton', {'weight': 1})
# ('Ben Kingsley', 'Colin Firth', {'weight': 1})
# ('Ben Kingsley', 'Meryl Streep', {'weight': 1})
# ('Jim Broadbent', 'Ciarán Hinds', {'weight': 2})
# ('Jim Broadbent', 'Bonnie Wright', {'weight': 2})
# ('Jim Broadbent', 'Maggie Smith', {'weight': 4})
# ('Jim Broadbent', 'Alan Rickman', {'weight': 3})
# ('Jim Broadbent', 'Elizabeth Berrington', {'weight': 1})
# ('Jim Broadbent', 'Tom Felton', {'weight': 3})
# ('Jim Broadbent', 'Kenneth Branagh', {'weight': 1})
# ('Jim Broadbent', 'Cillian Murphy', {'weight': 1})
# ('Jim Broadbent', 'David Thewlis', {'weight': 4})
# ('Jim Broadbent', 'Laura Linney', {'weight': 1})
# ('Jim Broadbent', 'Marion Cotillard', {'weight': 1})
# ('Jim Broadbent', 'Reese Witherspoon', {'weight': 1})
# ('Jim Broadbent', 'Robert De Niro', {'weight': 1})
# ('Jim Broadbent', 'Helen McCrory', {'weight': 2})
# ('Jim Broadbent', 'Kathy Bates', {'weight': 1})
# ('Jim Broadbent', 'Jonathan Pryce', {'weight': 2})
# ('Jim Broadbent', 'Matt Lucas', {'weight': 2})
# ('Jim Broadbent', 'Forest Whitaker', {'weight': 1})
# ('Jim Broadbent', 'Tom Hanks', {'weight': 1})
# ('Jim Broadbent', 'Susan Sarandon', {'weight': 1})
# ('Jim Broadbent', 'Tilda Swinton', {'weight': 1})
# ('Jim Broadbent', 'Andy Serkis', {'weight': 5})
# ('Jim Broadbent', 'Pam Ferris', {'weight': 2})
# ('Jim Broadbent', 'Robbie Coltrane', {'weight': 4})
# ('Jim Broadbent', 'Anthony Hopkins', {'weight': 1})
# ('Jim Broadbent', 'Emma Watson', {'weight': 2})
# ('Jim Broadbent', 'Uma Thurman', {'weight': 1})
# ('Jim Broadbent', 'Imelda Staunton', {'weight': 7})
# ('Jim Broadbent', 'Ian McKellen', {'weight': 3})
# ('Jim Broadbent', 'Samantha Morton', {'weight': 1})
# ('Jim Broadbent', 'Colin Firth', {'weight': 5})
# ('Jim Broadbent', 'Meryl Streep', {'weight': 1})
# ('Marion Cotillard', 'Audrey Tautou', {'weight': 1})
# ('Marion Cotillard', 'Mélanie Laurent', {'weight': 1})
# ('Marion Cotillard', 'Edward Norton', {'weight': 1})
# ('Marion Cotillard', 'Matt Damon', {'weight': 1})
# ('Marion Cotillard', 'Michael Fassbender', {'weight': 2})
# ('Marion Cotillard', 'Cillian Murphy', {'weight': 2})
# ('Marion Cotillard', 'Jim Carrey', {'weight': 1})
# ('Marion Cotillard', 'David Thewlis', {'weight': 1})
# ('Marion Cotillard', 'Reese Witherspoon', {'weight': 1})
# ('Marion Cotillard', 'Kevin Spacey', {'weight': 1})
# ('Marion Cotillard', 'Kathy Bates', {'weight': 1})
# ('Marion Cotillard', 'Mila Kunis', {'weight': 1})
# ('Marion Cotillard', 'Forest Whitaker', {'weight': 1})
# ('Marion Cotillard', 'Tina Fey', {'weight': 1})
# ('Marion Cotillard', 'Jean Dujardin', {'weight': 2})
# ('Marion Cotillard', 'Susan Sarandon', {'weight': 1})
# ('Marion Cotillard', 'Sylvester Stallone', {'weight': 1})
# ('Marion Cotillard', 'Ian McKellen', {'weight': 1})
# ('Marion Cotillard', 'Aidan Gillen', {'weight': 1})
# ('Amy Adams', 'Ciarán Hinds', {'weight': 2})
# ('Amy Adams', 'Patrick Wilson', {'weight': 2})
# ('Amy Adams', 'Edward Norton', {'weight': 1})
# ('Amy Adams', 'Abigail Breslin', {'weight': 1})
# ('Amy Adams', 'Patricia Clarkson', {'weight': 1})
# ('Amy Adams', 'Jack Black', {'weight': 2})
# ('Amy Adams', 'Zach Galifianakis', {'weight': 1})
# ('Amy Adams', 'Frances McDormand', {'weight': 1})
# ('Amy Adams', 'Glenn Close', {'weight': 1})
# ('Amy Adams', 'David Thewlis', {'weight': 1})
# ('Amy Adams', 'Laura Linney', {'weight': 1})
# ('Amy Adams', 'Ben Stiller', {'weight': 2})
# ('Amy Adams', 'Robert De Niro', {'weight': 2})
# ('Amy Adams', 'Jason Segel', {'weight': 1})
# ('Amy Adams', 'Terry Crews', {'weight': 1})
# ('Amy Adams', 'Jessica Alba', {'weight': 1})
# ('Amy Adams', 'Forest Whitaker', {'weight': 2})
# ('Amy Adams', 'Tom Hanks', {'weight': 2})
# ('Amy Adams', 'Bruce Willis', {'weight': 1})
# ('Amy Adams', 'Susan Sarandon', {'weight': 1})
# ('Amy Adams', 'Sylvester Stallone', {'weight': 1})
# ('Amy Adams', 'Steve Zahn', {'weight': 1})
# ('Amy Adams', 'Debra Messing', {'weight': 1})
# ('Amy Adams', 'Holly Hunter', {'weight': 1})
# ('Amy Adams', 'Meryl Streep', {'weight': 2})
# ('Kevin Spacey', 'Ansel Elgort', {'weight': 2})
# ('Kevin Spacey', 'Ciarán Hinds', {'weight': 1})
# ('Kevin Spacey', 'Jennifer Aniston', {'weight': 3})
# ('Kevin Spacey', 'Michael Douglas', {'weight': 1})
# ('Kevin Spacey', 'Edward Norton', {'weight': 1})
# ('Kevin Spacey', 'Sigourney Weaver', {'weight': 1})
# ('Kevin Spacey', 'Angela Bassett', {'weight': 1})
# ('Kevin Spacey', 'Patricia Clarkson', {'weight': 2})
# ('Kevin Spacey', 'Elizabeth Berrington', {'weight': 1})
# ('Kevin Spacey', 'Sandra Bullock', {'weight': 1})
# ('Kevin Spacey', 'James Gandolfini', {'weight': 1})
# ('Kevin Spacey', 'Glenn Close', {'weight': 1})
# ('Kevin Spacey', 'Cleo King', {'weight': 1})
# ('Kevin Spacey', 'Sean Penn', {'weight': 1})
# ('Kevin Spacey', 'David Thewlis', {'weight': 1})
# ('Kevin Spacey', 'Laura Linney', {'weight': 2})
# ('Kevin Spacey', 'Reese Witherspoon', {'weight': 2})
# ('Kevin Spacey', 'Demi Moore', {'weight': 1})
# ('Kevin Spacey', 'Rachel Weisz', {'weight': 1})
# ('Kevin Spacey', 'Kathy Bates', {'weight': 1})
# ('Kevin Spacey', 'Jamie Foxx', {'weight': 3})
# ('Kevin Spacey', 'Jonathan Pryce', {'weight': 1})
# ('Kevin Spacey', 'Forest Whitaker', {'weight': 1})
# ('Kevin Spacey', 'Tom Hanks', {'weight': 1})
# ('Kevin Spacey', 'Susan Sarandon', {'weight': 1})
# ('Kevin Spacey', 'Pam Ferris', {'weight': 1})
# ('Kevin Spacey', 'Anthony Hopkins', {'weight': 2})
# ('Kevin Spacey', 'Uma Thurman', {'weight': 1})
# ('Kevin Spacey', 'Marcia Gay Harden', {'weight': 1})
# ('Kevin Spacey', 'Meryl Streep', {'weight': 3})
# ('Tilda Swinton', 'Ciarán Hinds', {'weight': 1})
# ('Tilda Swinton', 'Michael Douglas', {'weight': 1})
# ('Tilda Swinton', 'Edward Norton', {'weight': 3})
# ('Tilda Swinton', 'F. Murray Abraham', {'weight': 2})
# ('Tilda Swinton', 'Toby Jones', {'weight': 1})
# ('Tilda Swinton', 'Angela Bassett', {'weight': 1})
# ('Tilda Swinton', 'Adam Sandler', {'weight': 1})
# ('Tilda Swinton', 'Matt Damon', {'weight': 1})
# ('Tilda Swinton', 'Dolph Lundgren', {'weight': 1})
# ('Tilda Swinton', 'Frances McDormand', {'weight': 4})
# ('Tilda Swinton', 'Natalie Portman', {'weight': 1})
# ('Tilda Swinton', 'Adam Driver', {'weight': 1})
# ('Tilda Swinton', 'Hiam Abbass', {'weight': 1})
# ('Tilda Swinton', 'Michelle Pfeiffer', {'weight': 1})
# ('Tilda Swinton', 'David Thewlis', {'weight': 1})
# ('Tilda Swinton', 'Tom Vaughan-Lawlor', {'weight': 1})
# ('Tilda Swinton', 'Chloë Grace Moretz', {'weight': 1})
# ('Tilda Swinton', 'Rachel Weisz', {'weight': 1})
# ('Tilda Swinton', 'Bruce Willis', {'weight': 1})
# ('Tilda Swinton', 'Robbie Coltrane', {'weight': 1})
# ('Tilda Swinton', 'Laurence Olivier', {'weight': 1})
# ('Tilda Swinton', 'Nicolas Cage', {'weight': 1})
# ('Tilda Swinton', 'Meryl Streep', {'weight': 1})
# ('Anthony Hopkins', 'Rosario Dawson', {'weight': 1})
# ('Anthony Hopkins', 'Emily Watson', {'weight': 1})
# ('Anthony Hopkins', 'Ciarán Hinds', {'weight': 1})
# ('Anthony Hopkins', 'Jennifer Aniston', {'weight': 1})
# ('Anthony Hopkins', 'Michael Douglas', {'weight': 1})
# ('Anthony Hopkins', 'Edward Norton', {'weight': 1})
# ('Anthony Hopkins', 'Toby Jones', {'weight': 1})
# ('Anthony Hopkins', 'Angela Bassett', {'weight': 1})
# ('Anthony Hopkins', 'Patricia Clarkson', {'weight': 2})
# ('Anthony Hopkins', 'Matt Damon', {'weight': 1})
# ('Anthony Hopkins', 'Mickey Rourke', {'weight': 1})
# ('Anthony Hopkins', 'Jim Carrey', {'weight': 1})
# ('Anthony Hopkins', 'Alexandra Maria Lara', {'weight': 1})
# ('Anthony Hopkins', 'James Gandolfini', {'weight': 1})
# ('Anthony Hopkins', 'Glenn Close', {'weight': 1})
# ('Anthony Hopkins', 'Natalie Portman', {'weight': 2})
# ('Anthony Hopkins', 'Sean Penn', {'weight': 1})
# ('Anthony Hopkins', 'David Thewlis', {'weight': 2})
# ('Anthony Hopkins', 'Laura Linney', {'weight': 2})
# ('Anthony Hopkins', 'Reese Witherspoon', {'weight': 1})
# ('Anthony Hopkins', 'Joan Allen', {'weight': 1})
# ('Anthony Hopkins', 'Demi Moore', {'weight': 1})
# ('Anthony Hopkins', 'Sam Neill', {'weight': 1})
# ('Anthony Hopkins', 'Rachel Weisz', {'weight': 1})
# ('Anthony Hopkins', 'Jonathan Pryce', {'weight': 1})
# ('Anthony Hopkins', 'Tom Hanks', {'weight': 1})
# ('Anthony Hopkins', 'Bruce Willis', {'weight': 1})
# ('Anthony Hopkins', 'Susan Sarandon', {'weight': 2})
# ('Anthony Hopkins', 'Emma Watson', {'weight': 1})
# ('Anthony Hopkins', 'Winona Ryder', {'weight': 1})
# ('Anthony Hopkins', 'Marcia Gay Harden', {'weight': 2})
# ('Anthony Hopkins', 'Laurence Olivier', {'weight': 2})
# ('Anthony Hopkins', 'Meryl Streep', {'weight': 2})
# ('Emma Watson', 'Ciarán Hinds', {'weight': 2})
# ('Emma Watson', 'Bonnie Wright', {'weight': 9})
# ('Emma Watson', 'Michael Cera', {'weight': 1})
# ('Emma Watson', 'Sigourney Weaver', {'weight': 1})
# ('Emma Watson', 'Toby Jones', {'weight': 3})
# ('Emma Watson', 'Maggie Smith', {'weight': 7})
# ('Emma Watson', 'Alan Rickman', {'weight': 8})
# ('Emma Watson', 'Tom Felton', {'weight': 9})
# ('Emma Watson', 'Kenneth Branagh', {'weight': 2})
# ('Emma Watson', 'Seth Rogen', {'weight': 1})
# ('Emma Watson', 'David Thewlis', {'weight': 6})
# ('Emma Watson', 'Julie Christie', {'weight': 1})
# ('Emma Watson', 'Helen McCrory', {'weight': 3})
# ('Emma Watson', 'Jason Segel', {'weight': 1})
# ('Emma Watson', 'Tom Hanks', {'weight': 1})
# ('Emma Watson', 'Pam Ferris', {'weight': 1})
# ('Emma Watson', 'Robbie Coltrane', {'weight': 10})
# ('Emma Watson', 'Imelda Staunton', {'weight': 3})
# ('Emma Watson', 'Ian McKellen', {'weight': 1})
# ('Emma Watson', 'Meryl Streep', {'weight': 1})
# ('Rosario Dawson', 'Michael Cera', {'weight': 1})
# ('Rosario Dawson', 'Edward Norton', {'weight': 1})
# ('Rosario Dawson', 'Sigourney Weaver', {'weight': 1})
# ('Rosario Dawson', 'Abigail Breslin', {'weight': 1})
# ('Rosario Dawson', 'Katherine Heigl', {'weight': 1})
# ('Rosario Dawson', 'Adam Sandler', {'weight': 2})
# ('Rosario Dawson', 'Matt Damon', {'weight': 1})
# ('Rosario Dawson', 'Mickey Rourke', {'weight': 3})
# ('Rosario Dawson', 'Zach Galifianakis', {'weight': 1})
# ('Rosario Dawson', 'Reese Witherspoon', {'weight': 1})
# ('Rosario Dawson', 'Terry Crews', {'weight': 1})
# ('Rosario Dawson', 'Kathy Bates', {'weight': 1})
# ('Rosario Dawson', 'Emma Stone', {'weight': 1})
# ('Rosario Dawson', 'Jamie Foxx', {'weight': 2})
# ('Rosario Dawson', 'Jessica Alba', {'weight': 2})
# ('Rosario Dawson', 'Vera Farmiga', {'weight': 1})
# ('Rosario Dawson', 'Carrie-Anne Moss', {'weight': 1})
# ('Rosario Dawson', 'Pierce Brosnan', {'weight': 1})
# ('Rosario Dawson', 'Forest Whitaker', {'weight': 2})
# ('Rosario Dawson', 'Bruce Willis', {'weight': 4})
# ('Rosario Dawson', 'Sylvester Stallone', {'weight': 2})
# ('Rosario Dawson', 'Uma Thurman', {'weight': 2})
# ('Rosario Dawson', 'Steve Zahn', {'weight': 2})
# ('Rosario Dawson', 'Nicolas Cage', {'weight': 1})
# ('Michael Cera', 'Edward Norton', {'weight': 1})
# ('Michael Cera', 'Matt Damon', {'weight': 1})
# ('Michael Cera', 'Jack Black', {'weight': 2})
# ('Michael Cera', 'Zach Galifianakis', {'weight': 3})
# ('Michael Cera', 'Jim Carrey', {'weight': 1})
# ('Michael Cera', 'Seth Rogen', {'weight': 4})
# ('Michael Cera', 'Jason Segel', {'weight': 1})
# ('Michael Cera', 'Anna Kendrick', {'weight': 2})
# ('Michael Cera', 'Emma Stone', {'weight': 1})
# ('Edward Norton', 'Emily Watson', {'weight': 1})
# ('Edward Norton', 'Patrick Wilson', {'weight': 1})
# ('Edward Norton', 'Keira Knightley', {'weight': 1})
# ('Edward Norton', 'F. Murray Abraham', {'weight': 2})
# ('Edward Norton', 'Abigail Breslin', {'weight': 1})
# ('Edward Norton', 'Toby Jones', {'weight': 1})
# ('Edward Norton', 'Angela Bassett', {'weight': 1})
# ('Edward Norton', 'Matt Damon', {'weight': 1})
# ('Edward Norton', 'Jason Statham', {'weight': 1})
# ('Edward Norton', 'Zach Galifianakis', {'weight': 1})
# ('Edward Norton', 'Richard Dreyfuss', {'weight': 1})
# ('Edward Norton', 'Seth Rogen', {'weight': 1})
# ('Edward Norton', 'Frances McDormand', {'weight': 3})
# ('Edward Norton', 'Natalie Portman', {'weight': 1})
# ('Edward Norton', 'David Thewlis', {'weight': 1})
# ('Edward Norton', 'Laura Linney', {'weight': 1})
# ('Edward Norton', 'Ben Stiller', {'weight': 1})
# ('Edward Norton', 'Reese Witherspoon', {'weight': 1})
# ('Edward Norton', 'Joan Allen', {'weight': 1})
# ('Edward Norton', 'Robert De Niro', {'weight': 3})
# ('Edward Norton', 'Rachel Weisz', {'weight': 1})
# ('Edward Norton', 'Emma Stone', {'weight': 1})
# ('Edward Norton', 'Jessica Alba', {'weight': 1})
# ('Edward Norton', 'Pierce Brosnan', {'weight': 1})
# ('Edward Norton', 'Forest Whitaker', {'weight': 1})
# ('Edward Norton', 'Tina Fey', {'weight': 1})
# ('Edward Norton', 'Bruce Willis', {'weight': 3})
# ('Edward Norton', 'Susan Sarandon', {'weight': 1})
# ('Edward Norton', 'Pam Ferris', {'weight': 1})
# ('Edward Norton', 'Sylvester Stallone', {'weight': 1})
# ('Edward Norton', 'Goldie Hawn', {'weight': 1})
# ('Edward Norton', 'Geoffrey Rush', {'weight': 1})
# ('Edward Norton', 'Meryl Streep', {'weight': 1})
# ('Sigourney Weaver', 'Ciarán Hinds', {'weight': 2})
# ('Sigourney Weaver', 'F. Murray Abraham', {'weight': 1})
# ('Sigourney Weaver', 'Kate McKinnon', {'weight': 2})
# ('Sigourney Weaver', 'Toby Jones', {'weight': 2})
# ('Sigourney Weaver', 'Adam Sandler', {'weight': 1})
# ('Sigourney Weaver', 'Jack Black', {'weight': 1})
# ('Sigourney Weaver', 'Seána Kerslake', {'weight': 1})
# ('Sigourney Weaver', 'Cliff Robertson', {'weight': 1})
# ('Sigourney Weaver', 'Alan Rickman', {'weight': 2})
# ('Sigourney Weaver', 'Karan Soni', {'weight': 1})
# ('Sigourney Weaver', 'Cillian Murphy', {'weight': 1})
# ('Sigourney Weaver', 'Zach Galifianakis', {'weight': 1})
# ('Sigourney Weaver', 'Sandra Bullock', {'weight': 1})
# ('Sigourney Weaver', 'Seth Rogen', {'weight': 1})
# ('Sigourney Weaver', 'Adam Driver', {'weight': 1})
# ('Sigourney Weaver', 'Hiam Abbass', {'weight': 1})
# ('Sigourney Weaver', 'Laura Linney', {'weight': 1})
# ('Sigourney Weaver', 'Ben Stiller', {'weight': 1})
# ('Sigourney Weaver', 'Joan Allen', {'weight': 1})
# ('Sigourney Weaver', 'Robert De Niro', {'weight': 1})
# ('Sigourney Weaver', 'Sam Neill', {'weight': 1})
# ('Sigourney Weaver', 'Carrie-Anne Moss', {'weight': 2})
# ('Sigourney Weaver', 'Forest Whitaker', {'weight': 1})
# ('Sigourney Weaver', 'Tina Fey', {'weight': 1})
# ('Sigourney Weaver', 'Bruce Willis', {'weight': 1})
# ('Sigourney Weaver', 'Betty White', {'weight': 1})
# ('Sigourney Weaver', 'Robbie Coltrane', {'weight': 1})
# ('Sigourney Weaver', "Brían F. O'Byrne", {'weight': 1})
# ('Sigourney Weaver', 'Winona Ryder', {'weight': 1})
# ('Sigourney Weaver', 'Holly Hunter', {'weight': 1})
# ('Abigail Breslin', 'Patrick Wilson', {'weight': 1})
# ('Abigail Breslin', 'Katherine Heigl', {'weight': 1})
# ('Abigail Breslin', 'Patricia Clarkson', {'weight': 1})
# ('Abigail Breslin', 'Bette Midler', {'weight': 1})
# ('Abigail Breslin', 'Michelle Pfeiffer', {'weight': 1})
# ('Abigail Breslin', 'Robert De Niro', {'weight': 2})
# ('Abigail Breslin', 'Rachel Weisz', {'weight': 1})
# ('Abigail Breslin', 'Emma Stone', {'weight': 2})
# ('Abigail Breslin', 'Jessica Alba', {'weight': 1})
# ('Abigail Breslin', 'Forest Whitaker', {'weight': 1})
# ('Abigail Breslin', 'Bruce Willis', {'weight': 1})
# ('Abigail Breslin', 'Mark Hamill', {'weight': 1})
# ('Abigail Breslin', "Brían F. O'Byrne", {'weight': 1})
# ('Abigail Breslin', 'Sylvester Stallone', {'weight': 1})
# ('Abigail Breslin', 'Meryl Streep', {'weight': 1})
# ('Katherine Heigl', 'Patrick Wilson', {'weight': 1})
# ('Katherine Heigl', 'Seth Rogen', {'weight': 1})
# ('Katherine Heigl', 'Michelle Pfeiffer', {'weight': 1})
# ('Katherine Heigl', 'Robert De Niro', {'weight': 2})
# ('Katherine Heigl', 'Jason Segel', {'weight': 1})
# ('Katherine Heigl', 'Susan Sarandon', {'weight': 1})
# ('Adam Sandler', 'Emily Watson', {'weight': 2})
# ('Adam Sandler', 'Ansel Elgort', {'weight': 1})
# ('Adam Sandler', 'Jennifer Aniston', {'weight': 2})
# ('Adam Sandler', 'Jack Black', {'weight': 1})
# ('Adam Sandler', 'Seth Rogen', {'weight': 2})
# ('Adam Sandler', 'Adam Driver', {'weight': 1})
# ('Adam Sandler', 'Ben Stiller', {'weight': 3})
# ('Adam Sandler', 'Reese Witherspoon', {'weight': 1})
# ('Adam Sandler', 'Elaine Kao', {'weight': 1})
# ('Adam Sandler', 'Jason Segel', {'weight': 1})
# ('Adam Sandler', 'Terry Crews', {'weight': 5})
# ('Adam Sandler', 'Kathy Bates', {'weight': 1})
# ('Adam Sandler', 'Jonathan Pryce', {'weight': 1})
# ('Adam Sandler', 'Susan Sarandon', {'weight': 1})
# ('Adam Sandler', 'Andy Serkis', {'weight': 1})
# ('Adam Sandler', 'Sylvester Stallone', {'weight': 1})
# ('Adam Sandler', 'Winona Ryder', {'weight': 1})
# ('Adam Sandler', 'Steve Zahn', {'weight': 1})
# ('Matt Damon', 'Michael Douglas', {'weight': 1})
# ('Matt Damon', 'F. Murray Abraham', {'weight': 1})
# ('Matt Damon', 'Alan Rickman', {'weight': 1})
# ('Matt Damon', 'Mickey Rourke', {'weight': 1})
# ('Matt Damon', 'Karan Soni', {'weight': 1})
# ('Matt Damon', 'Jim Carrey', {'weight': 1})
# ('Matt Damon', 'Alexandra Maria Lara', {'weight': 1})
# ('Matt Damon', 'Frances McDormand', {'weight': 1})
# ('Matt Damon', 'David Thewlis', {'weight': 1})
# ('Matt Damon', 'Joe Pesci', {'weight': 1})
# ('Matt Damon', 'Joan Allen', {'weight': 2})
# ('Matt Damon', 'Robert De Niro', {'weight': 1})
# ('Matt Damon', 'Sam Neill', {'weight': 1})
# ('Matt Damon', 'Terry Crews', {'weight': 1})
# ('Matt Damon', 'Jonathan Pryce', {'weight': 1})
# ('Matt Damon', 'Vera Farmiga', {'weight': 1})
# ('Matt Damon', 'Tina Fey', {'weight': 1})
# ('Matt Damon', 'Tom Hanks', {'weight': 2})
# ('Matt Damon', 'Jean Dujardin', {'weight': 1})
# ('Matt Damon', 'Bruce Willis', {'weight': 1})
# ('Matt Damon', 'Mark Hamill', {'weight': 1})
# ('Matt Damon', 'Betty White', {'weight': 1})
# ('Matt Damon', 'Robbie Coltrane', {'weight': 1})
# ('Matt Damon', 'Meryl Streep', {'weight': 1})
# ('Matt Damon', 'Jennifer Lopez', {'weight': 1})
# ('Mickey Rourke', 'Patrick Wilson', {'weight': 1})
# ('Mickey Rourke', 'Keira Knightley', {'weight': 2})
# ('Mickey Rourke', 'Angela Bassett', {'weight': 1})
# ('Mickey Rourke', 'Patricia Clarkson', {'weight': 1})
# ('Mickey Rourke', 'Jason Statham', {'weight': 2})
# ('Mickey Rourke', 'Dolph Lundgren', {'weight': 2})
# ('Mickey Rourke', 'Joe Pesci', {'weight': 1})
# ('Mickey Rourke', 'Robert De Niro', {'weight': 1})
# ('Mickey Rourke', 'Terry Crews', {'weight': 1})
# ('Mickey Rourke', 'Jessica Alba', {'weight': 2})
# ('Mickey Rourke', 'Forest Whitaker', {'weight': 2})
# ('Mickey Rourke', 'Bruce Willis', {'weight': 3})
# ('Mickey Rourke', 'Andy Serkis', {'weight': 1})
# ('Mickey Rourke', 'Robbie Coltrane', {'weight': 1})
# ('Mickey Rourke', 'Sylvester Stallone', {'weight': 2})
# ('Mickey Rourke', 'Winona Ryder', {'weight': 1})
# ('Mickey Rourke', 'Nicolas Cage', {'weight': 1})
# ('Zach Galifianakis', 'Kate McKinnon', {'weight': 1})
# ('Zach Galifianakis', 'Toby Jones', {'weight': 1})
# ('Zach Galifianakis', 'Jack Black', {'weight': 2})
# ('Zach Galifianakis', 'Seth Rogen', {'weight': 1})
# ('Zach Galifianakis', 'Cleo King', {'weight': 2})
# ('Zach Galifianakis', 'Reese Witherspoon', {'weight': 1})
# ('Zach Galifianakis', 'Jason Segel', {'weight': 1})
# ('Zach Galifianakis', 'Anna Kendrick', {'weight': 1})
# ('Zach Galifianakis', 'Chloë Grace Moretz', {'weight': 1})
# ('Zach Galifianakis', 'Emma Stone', {'weight': 1})
# ('Zach Galifianakis', 'Jamie Foxx', {'weight': 1})
# ('Zach Galifianakis', 'Vera Farmiga', {'weight': 1})
# ('Zach Galifianakis', 'Matt Lucas', {'weight': 1})
# ('Zach Galifianakis', 'Tina Fey', {'weight': 1})
# ('Zach Galifianakis', 'Marcia Gay Harden', {'weight': 1})
# ('Zach Galifianakis', 'Nicolas Cage', {'weight': 1})
# ('Reese Witherspoon', 'Sissy Spacek', {'weight': 1})
# ('Reese Witherspoon', 'Jennifer Aniston', {'weight': 1})
# ('Reese Witherspoon', 'Michael Douglas', {'weight': 1})
# ('Reese Witherspoon', 'Angela Bassett', {'weight': 2})
# ('Reese Witherspoon', 'Seth Rogen', {'weight': 1})
# ('Reese Witherspoon', 'Glenn Close', {'weight': 1})
# ('Reese Witherspoon', 'Joan Allen', {'weight': 1})
# ('Reese Witherspoon', 'Tom Hanks', {'weight': 1})
# ('Reese Witherspoon', 'Susan Sarandon', {'weight': 2})
# ('Reese Witherspoon', 'Sally Field', {'weight': 1})
# ('Reese Witherspoon', 'Colin Firth', {'weight': 2})
# ('Reese Witherspoon', 'Meryl Streep', {'weight': 2})
# ('Terry Crews', 'Wesley Snipes', {'weight': 1})
# ('Terry Crews', 'Jason Statham', {'weight': 3})
# ('Terry Crews', 'Dolph Lundgren', {'weight': 3})
# ('Terry Crews', 'Karan Soni', {'weight': 1})
# ('Terry Crews', 'Cleo King', {'weight': 1})
# ('Terry Crews', 'Ben Stiller', {'weight': 1})
# ('Terry Crews', 'Elaine Kao', {'weight': 1})
# ('Terry Crews', 'Matt Lucas', {'weight': 1})
# ('Terry Crews', 'Forest Whitaker', {'weight': 2})
# ('Terry Crews', 'Tina Fey', {'weight': 1})
# ('Terry Crews', 'Bruce Willis', {'weight': 2})
# ('Terry Crews', 'Sylvester Stallone', {'weight': 4})
# ('Terry Crews', 'Steve Zahn', {'weight': 1})
# ('Kathy Bates', 'Jennifer Aniston', {'weight': 1})
# ('Kathy Bates', 'F. Murray Abraham', {'weight': 1})
# ('Kathy Bates', 'Elizabeth Berrington', {'weight': 1})
# ('Kathy Bates', 'Sandra Bullock', {'weight': 1})
# ('Kathy Bates', 'James Gandolfini', {'weight': 1})
# ('Kathy Bates', 'Glenn Close', {'weight': 1})
# ('Kathy Bates', 'Natalie Portman', {'weight': 1})
# ('Kathy Bates', 'Cleo King', {'weight': 1})
# ('Kathy Bates', 'Michelle Pfeiffer', {'weight': 2})
# ('Kathy Bates', 'Joan Allen', {'weight': 1})
# ('Kathy Bates', 'Robert De Niro', {'weight': 1})
# ('Kathy Bates', 'George C. Scott', {'weight': 1})
# ('Kathy Bates', 'Rachel Weisz', {'weight': 3})
# ('Kathy Bates', 'Jamie Foxx', {'weight': 1})
# ('Kathy Bates', 'Jonathan Pryce', {'weight': 1})
# ('Kathy Bates', 'Jessica Alba', {'weight': 1})
# ('Kathy Bates', 'Bruce Willis', {'weight': 1})
# ('Kathy Bates', 'Susan Sarandon', {'weight': 4})
# ('Kathy Bates', 'Marcia Gay Harden', {'weight': 1})
# ('Kathy Bates', 'Imelda Staunton', {'weight': 1})
# ('Kathy Bates', 'Ian McKellen', {'weight': 2})
# ('Kathy Bates', 'Jessica Tandy', {'weight': 2})
# ('Kathy Bates', 'Holly Hunter', {'weight': 1})
# ('Emma Stone', 'Sissy Spacek', {'weight': 1})
# ('Emma Stone', 'Michael Douglas', {'weight': 1})
# ('Emma Stone', 'Patricia Clarkson', {'weight': 2})
# ('Emma Stone', 'Seth Rogen', {'weight': 2})
# ('Emma Stone', 'Glenn Close', {'weight': 1})
# ('Emma Stone', 'Sean Penn', {'weight': 1})
# ('Emma Stone', 'Jason Segel', {'weight': 1})
# ('Emma Stone', 'Chloë Grace Moretz', {'weight': 1})
# ('Emma Stone', 'Rachel Weisz', {'weight': 2})
# ('Emma Stone', 'Jamie Foxx', {'weight': 1})
# ('Emma Stone', 'Mila Kunis', {'weight': 1})
# ('Emma Stone', 'Sally Field', {'weight': 3})
# ('Emma Stone', 'Uma Thurman', {'weight': 1})
# ('Emma Stone', 'Marcia Gay Harden', {'weight': 1})
# ('Emma Stone', 'Kelly Marie Tran', {'weight': 1})
# ('Emma Stone', 'Colin Firth', {'weight': 1})
# ('Emma Stone', 'Nicolas Cage', {'weight': 2})
# ('Jamie Foxx', 'Ansel Elgort', {'weight': 1})
# ('Jamie Foxx', 'Ciarán Hinds', {'weight': 1})
# ('Jamie Foxx', 'Jennifer Aniston', {'weight': 2})
# ('Jamie Foxx', 'F. Murray Abraham', {'weight': 1})
# ('Jamie Foxx', 'Angela Bassett', {'weight': 1})
# ('Jamie Foxx', 'Patricia Clarkson', {'weight': 1})
# ('Jamie Foxx', 'Jason Statham', {'weight': 1})
# ('Jamie Foxx', 'Natalie Portman', {'weight': 1})
# ('Jamie Foxx', 'Cleo King', {'weight': 2})
# ('Jamie Foxx', 'Sean Penn', {'weight': 1})
# ('Jamie Foxx', 'Ben Stiller', {'weight': 1})
# ('Jamie Foxx', 'Jessica Alba', {'weight': 1})
# ('Jamie Foxx', 'Mila Kunis', {'weight': 1})
# ('Jamie Foxx', 'Forest Whitaker', {'weight': 1})
# ('Jamie Foxx', 'Tina Fey', {'weight': 1})
# ('Jamie Foxx', 'Sally Field', {'weight': 1})
# ('Jamie Foxx', 'Sylvester Stallone', {'weight': 1})
# ('Jamie Foxx', 'Uma Thurman', {'weight': 1})
# ('Jessica Alba', 'Patrick Wilson', {'weight': 2})
# ('Jessica Alba', 'Jason Statham', {'weight': 1})
# ('Jessica Alba', 'Cleo King', {'weight': 1})
# ('Jessica Alba', 'Marlee Matlin', {'weight': 1})
# ('Jessica Alba', 'Ben Stiller', {'weight': 3})
# ('Jessica Alba', 'Robert De Niro', {'weight': 4})
# ('Jessica Alba', 'Chloë Grace Moretz', {'weight': 1})
# ('Jessica Alba', 'Pierce Brosnan', {'weight': 1})
# ('Jessica Alba', 'Forest Whitaker', {'weight': 1})
# ('Jessica Alba', 'Bruce Willis', {'weight': 3})
# ('Jessica Alba', 'Sylvester Stallone', {'weight': 1})
# ('Jessica Alba', 'Winona Ryder', {'weight': 1})
# ('Jessica Alba', 'Steve Zahn', {'weight': 1})
# ('Vera Farmiga', 'Patrick Wilson', {'weight': 5})
# ('Vera Farmiga', 'Angela Bassett', {'weight': 1})
# ('Vera Farmiga', 'David Thewlis', {'weight': 1})
# ('Vera Farmiga', 'Robert De Niro', {'weight': 1})
# ('Vera Farmiga', 'Anna Kendrick', {'weight': 1})
# ('Vera Farmiga', 'Sam Neill', {'weight': 1})
# ('Vera Farmiga', 'Winona Ryder', {'weight': 1})
# ('Vera Farmiga', 'Ian McKellen', {'weight': 1})
# ('Vera Farmiga', 'Meryl Streep', {'weight': 1})
# ('Carrie-Anne Moss', 'Emily Watson', {'weight': 1})
# ('Carrie-Anne Moss', 'Alan Rickman', {'weight': 1})
# ('Carrie-Anne Moss', 'Richard Dreyfuss', {'weight': 1})
# ('Carrie-Anne Moss', 'Glenn Close', {'weight': 1})
# ('Carrie-Anne Moss', 'Cleo King', {'weight': 1})
# ('Carrie-Anne Moss', 'Chloë Grace Moretz', {'weight': 1})
# ('Pierce Brosnan', 'Ciarán Hinds', {'weight': 1})
# ('Pierce Brosnan', 'Angela Bassett', {'weight': 1})
# ('Pierce Brosnan', 'Patricia Clarkson', {'weight': 1})
# ('Pierce Brosnan', 'Jack Black', {'weight': 1})
# ('Pierce Brosnan', 'Glenn Close', {'weight': 1})
# ('Pierce Brosnan', 'Natalie Portman', {'weight': 1})
# ('Pierce Brosnan', 'Marlee Matlin', {'weight': 1})
# ('Pierce Brosnan', 'Sam Neill', {'weight': 1})
# ('Pierce Brosnan', 'Jonathan Pryce', {'weight': 1})
# ('Pierce Brosnan', 'Susan Sarandon', {'weight': 1})
# ('Pierce Brosnan', 'Sally Field', {'weight': 1})
# ('Pierce Brosnan', 'Robbie Coltrane', {'weight': 2})
# ('Pierce Brosnan', 'Uma Thurman', {'weight': 1})
# ('Pierce Brosnan', 'Geoffrey Rush', {'weight': 1})
# ('Pierce Brosnan', 'Colin Firth', {'weight': 2})
# ('Pierce Brosnan', 'Meryl Streep', {'weight': 2})
# ('Forest Whitaker', 'Patrick Wilson', {'weight': 1})
# ('Forest Whitaker', 'Angela Bassett', {'weight': 2})
# ('Forest Whitaker', 'Alan Rickman', {'weight': 1})
# ('Forest Whitaker', 'Richard Dreyfuss', {'weight': 2})
# ('Forest Whitaker', 'James Gandolfini', {'weight': 1})
# ('Forest Whitaker', 'Sean Penn', {'weight': 1})
# ('Forest Whitaker', 'Robert De Niro', {'weight': 2})
# ('Forest Whitaker', 'Bruce Willis', {'weight': 2})
# ('Forest Whitaker', 'Susan Sarandon', {'weight': 1})
# ('Forest Whitaker', 'Andy Serkis', {'weight': 1})
# ('Forest Whitaker', 'Marie-Josée Croze', {'weight': 1})
# ('Forest Whitaker', 'Sylvester Stallone', {'weight': 1})
# ('Forest Whitaker', 'Marcia Gay Harden', {'weight': 1})
# ('Forest Whitaker', 'Nicolas Cage', {'weight': 1})
# ('Forest Whitaker', 'Meryl Streep', {'weight': 1})
# ('Bruce Willis', 'Patrick Wilson', {'weight': 1})
# ('Bruce Willis', 'F. Murray Abraham', {'weight': 2})
# ('Bruce Willis', 'Jack Black', {'weight': 1})
# ('Bruce Willis', 'Jason Statham', {'weight': 2})
# ('Bruce Willis', 'Alan Rickman', {'weight': 1})
# ('Bruce Willis', 'Dolph Lundgren', {'weight': 2})
# ('Bruce Willis', 'Richard Dreyfuss', {'weight': 1})
# ('Bruce Willis', 'Frances McDormand', {'weight': 1})
# ('Bruce Willis', 'James Gandolfini', {'weight': 1})
# ('Bruce Willis', 'Marlee Matlin', {'weight': 1})
# ('Bruce Willis', 'Sean Penn', {'weight': 1})
# ('Bruce Willis', 'Michelle Pfeiffer', {'weight': 1})
# ('Bruce Willis', 'David Thewlis', {'weight': 1})
# ('Bruce Willis', 'Joan Allen', {'weight': 1})
# ('Bruce Willis', 'Demi Moore', {'weight': 4})
# ('Bruce Willis', 'Chris Tucker', {'weight': 1})
# ('Bruce Willis', 'Robert De Niro', {'weight': 2})
# ('Bruce Willis', 'Jonathan Pryce', {'weight': 1})
# ('Bruce Willis', 'Mila Kunis', {'weight': 1})
# ('Bruce Willis', 'Tom Hanks', {'weight': 1})
# ('Bruce Willis', 'Susan Sarandon', {'weight': 1})
# ('Bruce Willis', 'Mark Hamill', {'weight': 1})
# ('Bruce Willis', 'Betty White', {'weight': 1})
# ('Bruce Willis', 'Robbie Coltrane', {'weight': 1})
# ('Bruce Willis', "Brían F. O'Byrne", {'weight': 1})
# ('Bruce Willis', 'Sylvester Stallone', {'weight': 3})
# ('Bruce Willis', 'Uma Thurman', {'weight': 1})
# ('Bruce Willis', 'Goldie Hawn', {'weight': 1})
# ('Bruce Willis', 'Nicolas Cage', {'weight': 1})
# ('Bruce Willis', 'Jessica Tandy', {'weight': 1})
# ('Bruce Willis', 'Meryl Streep', {'weight': 1})
# ('Sylvester Stallone', 'Patrick Wilson', {'weight': 1})
# ('Sylvester Stallone', 'F. Murray Abraham', {'weight': 1})
# ('Sylvester Stallone', 'Wesley Snipes', {'weight': 2})
# ('Sylvester Stallone', 'Jack Black', {'weight': 1})
# ('Sylvester Stallone', 'Jason Statham', {'weight': 3})
# ('Sylvester Stallone', 'Dolph Lundgren', {'weight': 5})
# ('Sylvester Stallone', 'Sandra Bullock', {'weight': 1})
# ('Sylvester Stallone', 'Demi Moore', {'weight': 1})
# ('Sylvester Stallone', 'Robert De Niro', {'weight': 3})
# ('Sylvester Stallone', 'Sam Neill', {'weight': 1})
# ('Sylvester Stallone', 'Ian McKellen', {'weight': 1})
# ('Sylvester Stallone', 'Jennifer Lopez', {'weight': 1})
# ('Uma Thurman', 'Toby Jones', {'weight': 1})
# ('Uma Thurman', 'Sarah Polley', {'weight': 1})
# ('Uma Thurman', 'Glenn Close', {'weight': 1})
# ('Uma Thurman', 'Natalie Portman', {'weight': 1})
# ('Uma Thurman', 'Sean Penn', {'weight': 1})
# ('Uma Thurman', 'Michelle Pfeiffer', {'weight': 1})
# ('Uma Thurman', 'Robert De Niro', {'weight': 2})
# ('Uma Thurman', 'Chloë Grace Moretz', {'weight': 1})
# ('Uma Thurman', 'Jonathan Pryce', {'weight': 1})
# ('Uma Thurman', 'Mark Hamill', {'weight': 1})
# ('Uma Thurman', 'Robbie Coltrane', {'weight': 1})
# ('Uma Thurman', 'Geoffrey Rush', {'weight': 1})
# ('Uma Thurman', 'Steve Zahn', {'weight': 1})
# ('Uma Thurman', 'Samantha Morton', {'weight': 1})
# ('Uma Thurman', 'Colin Firth', {'weight': 1})
# ('Uma Thurman', 'Meryl Streep', {'weight': 1})
# ('Steve Zahn', 'Jennifer Aniston', {'weight': 2})
# ('Steve Zahn', 'Jack Black', {'weight': 1})
# ('Steve Zahn', 'Sandra Bullock', {'weight': 1})
# ('Steve Zahn', 'Frances McDormand', {'weight': 1})
# ('Steve Zahn', 'James Gandolfini', {'weight': 1})
# ('Steve Zahn', 'Cleo King', {'weight': 1})
# ('Steve Zahn', 'Ben Stiller', {'weight': 1})
# ('Steve Zahn', 'Chloë Grace Moretz', {'weight': 1})
# ('Steve Zahn', 'Tom Hanks', {'weight': 4})
# ('Steve Zahn', 'Sally Field', {'weight': 1})
# ('Steve Zahn', 'Andy Serkis', {'weight': 1})
# ('Steve Zahn', 'Winona Ryder', {'weight': 1})
# ('Steve Zahn', 'Jennifer Lopez', {'weight': 1})
# ('Nicolas Cage', 'Ciarán Hinds', {'weight': 1})
# ('Nicolas Cage', 'Jim Carrey', {'weight': 1})
# ('Nicolas Cage', 'Frances McDormand', {'weight': 1})
# ('Nicolas Cage', 'James Gandolfini', {'weight': 1})
# ('Nicolas Cage', 'Sean Penn', {'weight': 2})
# ('Nicolas Cage', 'Joan Allen', {'weight': 2})
# ('Nicolas Cage', 'Chloë Grace Moretz', {'weight': 1})
# ('Nicolas Cage', 'Matt Lucas', {'weight': 1})
# ('Nicolas Cage', "Brían F. O'Byrne", {'weight': 1})
# ('Nicolas Cage', 'Kelly Marie Tran', {'weight': 1})
# ('Nicolas Cage', 'Holly Hunter', {'weight': 1})
# ('Nicolas Cage', 'Meryl Streep', {'weight': 2})
# ('Roberto Benigni', 'Glenn Close', {'weight': 1})
# ('Roberto Benigni', 'Winona Ryder', {'weight': 1})
# ('Glenn Close', 'Sissy Spacek', {'weight': 1})
# ('Glenn Close', 'Ciarán Hinds', {'weight': 1})
# ('Glenn Close', 'Patrick Wilson', {'weight': 1})
# ('Glenn Close', 'Jennifer Aniston', {'weight': 1})
# ('Glenn Close', 'Michael Douglas', {'weight': 2})
# ('Glenn Close', 'Angela Bassett', {'weight': 1})
# ('Glenn Close', 'Patricia Clarkson', {'weight': 1})
# ('Glenn Close', 'Maggie Smith', {'weight': 1})
# ('Glenn Close', 'Jack Black', {'weight': 1})
# ('Glenn Close', 'Bette Midler', {'weight': 1})
# ('Glenn Close', 'Sandra Bullock', {'weight': 1})
# ('Glenn Close', 'Frances McDormand', {'weight': 1})
# ('Glenn Close', 'Natalie Portman', {'weight': 1})
# ('Glenn Close', 'Michelle Pfeiffer', {'weight': 1})
# ('Glenn Close', 'Rachel Weisz', {'weight': 1})
# ('Glenn Close', 'Jonathan Pryce', {'weight': 1})
# ('Glenn Close', 'Mila Kunis', {'weight': 1})
# ('Glenn Close', 'Tom Hanks', {'weight': 1})
# ('Glenn Close', 'Jean Dujardin', {'weight': 1})
# ('Glenn Close', 'Susan Sarandon', {'weight': 1})
# ('Glenn Close', 'Winona Ryder', {'weight': 1})
# ('Glenn Close', 'Jessica Tandy', {'weight': 1})
# ('Glenn Close', 'Holly Hunter', {'weight': 2})
# ('Glenn Close', 'Meryl Streep', {'weight': 3})
# ('Winona Ryder', 'Jason Statham', {'weight': 1})
# ('Winona Ryder', 'Kenneth Branagh', {'weight': 1})
# ('Winona Ryder', 'Natalie Portman', {'weight': 2})
# ('Winona Ryder', 'Michelle Pfeiffer', {'weight': 1})
# ('Winona Ryder', 'Ben Stiller', {'weight': 3})
# ('Winona Ryder', 'Joan Allen', {'weight': 1})
# ('Winona Ryder', 'Jonathan Pryce', {'weight': 1})
# ('Winona Ryder', 'Mila Kunis', {'weight': 1})
# ('Winona Ryder', 'Susan Sarandon', {'weight': 1})
# ('Winona Ryder', 'Debra Messing', {'weight': 1})
# ('Winona Ryder', 'Meryl Streep', {'weight': 1})
# ('Emily Watson', 'Keira Knightley', {'weight': 2})
# ('Emily Watson', 'Maggie Smith', {'weight': 2})
# ('Emily Watson', 'Jack Black', {'weight': 1})
# ('Emily Watson', 'Tom Felton', {'weight': 1})
# ('Emily Watson', 'David Thewlis', {'weight': 2})
# ('Emily Watson', 'Susan Sarandon', {'weight': 2})
# ('Emily Watson', 'Pam Ferris', {'weight': 1})
# ('Emily Watson', 'Geoffrey Rush', {'weight': 2})
# ('Emily Watson', 'Samantha Morton', {'weight': 1})
# ('Emily Watson', 'Colin Firth', {'weight': 2})
# ('Keira Knightley', 'Michael Fassbender', {'weight': 1})
# ('Keira Knightley', 'Alan Rickman', {'weight': 1})
# ('Keira Knightley', 'Kenneth Branagh', {'weight': 1})
# ('Keira Knightley', 'Cillian Murphy', {'weight': 1})
# ('Keira Knightley', 'Alexandra Maria Lara', {'weight': 1})
# ('Keira Knightley', 'Natalie Portman', {'weight': 1})
# ('Keira Knightley', 'David Thewlis', {'weight': 1})
# ('Keira Knightley', 'Laura Linney', {'weight': 1})
# ('Keira Knightley', 'Chloë Grace Moretz', {'weight': 1})
# ('Keira Knightley', 'Sam Neill', {'weight': 1})
# ('Keira Knightley', 'Jonathan Pryce', {'weight': 3})
# ('Keira Knightley', 'Andy Serkis', {'weight': 1})
# ('Keira Knightley', 'Geoffrey Rush', {'weight': 4})
# ('Keira Knightley', 'Colin Firth', {'weight': 2})
# ('Maggie Smith', 'Ciarán Hinds', {'weight': 1})
# ('Maggie Smith', 'Bonnie Wright', {'weight': 7})
# ('Maggie Smith', 'Toby Jones', {'weight': 2})
# ('Maggie Smith', 'Bette Midler', {'weight': 1})
# ('Maggie Smith', 'Jason Statham', {'weight': 1})
# ('Maggie Smith', 'Alan Rickman', {'weight': 7})
# ('Maggie Smith', 'Tom Felton', {'weight': 7})
# ('Maggie Smith', 'Kenneth Branagh', {'weight': 1})
# ('Maggie Smith', 'Sandra Bullock', {'weight': 1})
# ('Maggie Smith', 'Art Carney', {'weight': 1})
# ('Maggie Smith', 'David Thewlis', {'weight': 4})
# ('Maggie Smith', 'Tom Vaughan-Lawlor', {'weight': 1})
# ('Maggie Smith', 'Julie Christie', {'weight': 1})
# ('Maggie Smith', 'Helen McCrory', {'weight': 3})
# ('Maggie Smith', 'Matt Lucas', {'weight': 2})
# ('Maggie Smith', 'Pam Ferris', {'weight': 1})
# ('Maggie Smith', 'Robbie Coltrane', {'weight': 7})
# ('Maggie Smith', 'Marcia Gay Harden', {'weight': 2})
# ('Maggie Smith', 'Imelda Staunton', {'weight': 4})
# ('Maggie Smith', 'Laurence Olivier', {'weight': 1})
# ('Maggie Smith', 'Goldie Hawn', {'weight': 1})
# ('Maggie Smith', 'Ian McKellen', {'weight': 2})
# ('Maggie Smith', 'Aidan Gillen', {'weight': 1})
# ('Maggie Smith', 'Alec Guinness', {'weight': 1})
# ('Jack Black', 'Ciarán Hinds', {'weight': 1})
# ('Jack Black', 'Wesley Snipes', {'weight': 2})
# ('Jack Black', 'Alan Rickman', {'weight': 1})
# ('Jack Black', 'Karan Soni', {'weight': 1})
# ('Jack Black', 'Jim Carrey', {'weight': 1})
# ('Jack Black', 'Sandra Bullock', {'weight': 1})
# ('Jack Black', 'Seth Rogen', {'weight': 10})
# ('Jack Black', 'Frances McDormand', {'weight': 1})
# ('Jack Black', 'Natalie Portman', {'weight': 1})
# ('Jack Black', 'Sean Penn', {'weight': 1})
# ('Jack Black', 'Ben Stiller', {'weight': 9})
# ('Jack Black', 'Robert De Niro', {'weight': 3})
# ('Jack Black', 'Jason Segel', {'weight': 4})
# ('Jack Black', 'Rachel Weisz', {'weight': 1})
# ('Jack Black', 'Susan Sarandon', {'weight': 4})
# ('Jack Black', 'Andy Serkis', {'weight': 2})
# ('Jack Black', 'Samantha Morton', {'weight': 1})
# ('Jack Black', 'Holly Hunter', {'weight': 1})
# ('Tom Felton', 'Ciarán Hinds', {'weight': 1})
# ('Tom Felton', 'Bonnie Wright', {'weight': 9})
# ('Tom Felton', 'Toby Jones', {'weight': 2})
# ('Tom Felton', 'Alan Rickman', {'weight': 8})
# ('Tom Felton', 'Kenneth Branagh', {'weight': 1})
# ('Tom Felton', 'David Thewlis', {'weight': 5})
# ('Tom Felton', 'Julie Christie', {'weight': 1})
# ('Tom Felton', 'Helen McCrory', {'weight': 3})
# ('Tom Felton', 'Matt Lucas', {'weight': 1})
# ('Tom Felton', 'Andy Serkis', {'weight': 1})
# ('Tom Felton', 'Pam Ferris', {'weight': 1})
# ('Tom Felton', 'Robbie Coltrane', {'weight': 9})
# ('Tom Felton', 'Imelda Staunton', {'weight': 4})
# ('David Thewlis', 'Ciarán Hinds', {'weight': 3})
# ('David Thewlis', 'Bonnie Wright', {'weight': 5})
# ('David Thewlis', 'Toby Jones', {'weight': 2})
# ('David Thewlis', 'Michael Fassbender', {'weight': 1})
# ('David Thewlis', 'Alan Rickman', {'weight': 5})
# ('David Thewlis', 'Elizabeth Berrington', {'weight': 1})
# ('David Thewlis', 'Richard Dreyfuss', {'weight': 1})
# ('David Thewlis', 'Laura Linney', {'weight': 1})
# ('David Thewlis', 'Julie Christie', {'weight': 3})
# ('David Thewlis', 'Helen McCrory', {'weight': 3})
# ('David Thewlis', 'Sam Neill', {'weight': 1})
# ('David Thewlis', 'Rachel Weisz', {'weight': 1})
# ('David Thewlis', 'Jonathan Pryce', {'weight': 1})
# ('David Thewlis', 'Susan Sarandon', {'weight': 1})
# ('David Thewlis', 'Pam Ferris', {'weight': 2})
# ('David Thewlis', 'Robbie Coltrane', {'weight': 5})
# ('David Thewlis', "Brían F. O'Byrne", {'weight': 2})
# ('David Thewlis', 'Imelda Staunton', {'weight': 4})
# ('David Thewlis', 'Ian McKellen', {'weight': 1})
# ('David Thewlis', 'Colin Firth', {'weight': 1})
# ('David Thewlis', 'Alec Guinness', {'weight': 1})
# ('Susan Sarandon', 'Jennifer Aniston', {'weight': 1})
# ('Susan Sarandon', 'Audrey Tautou', {'weight': 1})
# ('Susan Sarandon', 'Michael Douglas', {'weight': 3})
# ('Susan Sarandon', 'Angela Bassett', {'weight': 2})
# ('Susan Sarandon', 'Henry Fonda', {'weight': 1})
# ('Susan Sarandon', 'Patricia Clarkson', {'weight': 3})
# ('Susan Sarandon', 'Alan Rickman', {'weight': 2})
# ('Susan Sarandon', 'Kenneth Branagh', {'weight': 1})
# ('Susan Sarandon', 'Cillian Murphy', {'weight': 1})
# ...
# ('Frances McDormand', 'Michael Douglas', {'weight': 1})
# ('Frances McDormand', 'F. Murray Abraham', {'weight': 1})
# ('Frances McDormand', 'Dolph Lundgren', {'weight': 1})
# ('Frances McDormand', 'Elizabeth Berrington', {'weight': 1})
# ('Frances McDormand', 'Kenneth Branagh', {'weight': 1})
# ('Frances McDormand', 'Richard Dreyfuss', {'weight': 1})
# ('Frances McDormand', 'James Gandolfini', {'weight': 1})
# ('Frances McDormand', 'Sean Penn', {'weight': 1})
# ('Frances McDormand', 'Laura Linney', {'weight': 2})
# ('Frances McDormand', 'Ben Stiller', {'weight': 1})
# ('Frances McDormand', 'Demi Moore', {'weight': 1})
# ('Frances McDormand', 'Robert De Niro', {'weight': 1})
# ('Frances McDormand', "Brían F. O'Byrne", {'weight': 1})
# ('Frances McDormand', 'Marcia Gay Harden', {'weight': 1})
# ('Frances McDormand', 'Holly Hunter', {'weight': 3})
# ('Joe Pesci', 'Robert De Niro', {'weight': 7})
# ('Joe Pesci', 'Jonathan Pryce', {'weight': 1})
# ('Holly Hunter', 'Patrick Wilson', {'weight': 1})
# ('Holly Hunter', 'Alan Rickman', {'weight': 1})
# ('Holly Hunter', 'Kenneth Branagh', {'weight': 1})
# ('Holly Hunter', 'Richard Dreyfuss', {'weight': 3})
# ('Holly Hunter', 'Natalie Portman', {'weight': 1})
# ('Holly Hunter', 'Laura Linney', {'weight': 1})
# ('Holly Hunter', 'Sam Neill', {'weight': 1})
# ('Holly Hunter', "Brían F. O'Byrne", {'weight': 1})
# ('Holly Hunter', 'Goldie Hawn', {'weight': 1})
# ('Ciarán Hinds', 'Patrick Wilson', {'weight': 1})
# ('Ciarán Hinds', 'Bonnie Wright', {'weight': 2})
# ('Ciarán Hinds', 'Toby Jones', {'weight': 3})
# ('Ciarán Hinds', 'Alan Rickman', {'weight': 1})
# ('Ciarán Hinds', 'Elizabeth Berrington', {'weight': 1})
# ('Ciarán Hinds', 'Adam Driver', {'weight': 1})
# ('Ciarán Hinds', 'Hiam Abbass', {'weight': 2})
# ('Ciarán Hinds', 'Sean Penn', {'weight': 1})
# ('Ciarán Hinds', 'Helen McCrory', {'weight': 2})
# ('Ciarán Hinds', 'Tom Hanks', {'weight': 1})
# ('Ciarán Hinds', 'Jean Dujardin', {'weight': 1})
# ('Ciarán Hinds', 'Robbie Coltrane', {'weight': 2})
# ('Ciarán Hinds', 'Marie-Josée Croze', {'weight': 1})
# ('Ciarán Hinds', 'Aidan Gillen', {'weight': 2})
# ('Patrick Wilson', 'Jennifer Aniston', {'weight': 1})
# ('Patrick Wilson', 'Dolph Lundgren', {'weight': 1})
# ('Patrick Wilson', 'Richard Dreyfuss', {'weight': 1})
# ('Patrick Wilson', 'Robert De Niro', {'weight': 1})
# ('Patrick Wilson', 'Sam Neill', {'weight': 1})
# ('Patrick Wilson', 'Debra Messing', {'weight': 1})
# ('Patrick Wilson', 'Meryl Streep', {'weight': 2})
# ('Bonnie Wright', 'Toby Jones', {'weight': 2})
# ('Bonnie Wright', 'Alan Rickman', {'weight': 8})
# ('Bonnie Wright', 'Kenneth Branagh', {'weight': 1})
# ('Bonnie Wright', 'Helen McCrory', {'weight': 3})
# ('Bonnie Wright', 'Robbie Coltrane', {'weight': 9})
# ('Bonnie Wright', 'Imelda Staunton', {'weight': 3})
# ('Toby Jones', 'Alan Rickman', {'weight': 2})
# ('Toby Jones', 'Elizabeth Berrington', {'weight': 2})
# ('Toby Jones', 'Kenneth Branagh', {'weight': 2})
# ('Toby Jones', 'Cillian Murphy', {'weight': 3})
# ('Toby Jones', 'Sandra Bullock', {'weight': 1})
# ('Toby Jones', 'Richard Dreyfuss', {'weight': 1})
# ('Toby Jones', 'Natalie Portman', {'weight': 1})
# ('Toby Jones', 'Robert De Niro', {'weight': 1})
# ('Toby Jones', 'Helen McCrory', {'weight': 2})
# ('Toby Jones', 'Tina Fey', {'weight': 1})
# ('Toby Jones', 'Andy Serkis', {'weight': 2})
# ('Toby Jones', 'Robbie Coltrane', {'weight': 2})
# ('Toby Jones', 'Marcia Gay Harden', {'weight': 1})
# ('Toby Jones', 'Imelda Staunton', {'weight': 1})
# ('Alan Rickman', 'Birgit Minichmayr', {'weight': 1})
# ('Alan Rickman', 'Kenneth Branagh', {'weight': 1})
# ('Alan Rickman', 'Laura Linney', {'weight': 1})
# ('Alan Rickman', 'Helen McCrory', {'weight': 4})
# ('Alan Rickman', 'Matt Lucas', {'weight': 2})
# ('Alan Rickman', 'Andy Serkis', {'weight': 1})
# ('Alan Rickman', 'Robbie Coltrane', {'weight': 9})
# ('Alan Rickman', 'Imelda Staunton', {'weight': 5})
# ('Alan Rickman', 'Ian McKellen', {'weight': 1})
# ('Alan Rickman', 'Alec Guinness', {'weight': 1})
# ('Elizabeth Berrington', 'Kate McKinnon', {'weight': 1})
# ('Elizabeth Berrington', 'Rachel Weisz', {'weight': 1})
# ('Elizabeth Berrington', "Brían F. O'Byrne", {'weight': 1})
# ('Elizabeth Berrington', 'Imelda Staunton', {'weight': 2})
# ('Adam Driver', 'F. Murray Abraham', {'weight': 1})
# ('Adam Driver', 'Ben Stiller', {'weight': 2})
# ('Adam Driver', 'Jonathan Pryce', {'weight': 1})
# ('Adam Driver', 'Tina Fey', {'weight': 1})
# ('Adam Driver', 'Mark Hamill', {'weight': 3})
# ('Adam Driver', 'Sally Field', {'weight': 1})
# ('Adam Driver', 'Andy Serkis', {'weight': 3})
# ('Adam Driver', 'Kelly Marie Tran', {'weight': 2})
# ('Hiam Abbass', 'Natalie Portman', {'weight': 1})
# ('Hiam Abbass', 'Marie-Josée Croze', {'weight': 1})
# ('Sean Penn', 'Michael Douglas', {'weight': 1})
# ('Sean Penn', 'Kate McKinnon', {'weight': 1})
# ('Sean Penn', 'James Gandolfini', {'weight': 2})
# ('Sean Penn', 'Natalie Portman', {'weight': 1})
# ('Sean Penn', 'Michelle Pfeiffer', {'weight': 1})
# ('Sean Penn', 'Laura Linney', {'weight': 1})
# ('Sean Penn', 'Ben Stiller', {'weight': 2})
# ('Sean Penn', 'Demi Moore', {'weight': 1})
# ('Sean Penn', 'Robert De Niro', {'weight': 2})
# ('Sean Penn', 'George C. Scott', {'weight': 1})
# ('Sean Penn', 'Marcia Gay Harden', {'weight': 1})
# ('Sean Penn', 'Meryl Streep', {'weight': 1})
# ('Sean Penn', 'Jennifer Lopez', {'weight': 1})
# ('Helen McCrory', 'Michael Douglas', {'weight': 1})
# ('Helen McCrory', 'Ben Stiller', {'weight': 1})
# ('Helen McCrory', 'Tina Fey', {'weight': 1})
# ('Helen McCrory', 'Robbie Coltrane', {'weight': 3})
# ('Helen McCrory', 'Imelda Staunton', {'weight': 2})
# ('Helen McCrory', 'Goldie Hawn', {'weight': 1})
# ('Helen McCrory', 'Meryl Streep', {'weight': 1})
# ('Tom Hanks', 'Jennifer Aniston', {'weight': 1})
# ('Tom Hanks', 'Audrey Tautou', {'weight': 1})
# ('Tom Hanks', 'Michael Douglas', {'weight': 1})
# ('Tom Hanks', 'F. Murray Abraham', {'weight': 1})
# ('Tom Hanks', 'Angela Bassett', {'weight': 1})
# ('Tom Hanks', 'Sandra Bullock', {'weight': 1})
# ('Tom Hanks', 'Laura Linney', {'weight': 1})
# ('Tom Hanks', 'Betty White', {'weight': 1})
# ('Tom Hanks', 'Sally Field', {'weight': 3})
# ('Tom Hanks', 'Ian McKellen', {'weight': 1})
# ('Tom Hanks', 'Meryl Streep', {'weight': 2})
# ('Jean Dujardin', 'Marie-Josée Croze', {'weight': 1})
# ('Robbie Coltrane', 'F. Murray Abraham', {'weight': 1})
# ('Robbie Coltrane', 'Kenneth Branagh', {'weight': 2})
# ('Robbie Coltrane', 'Richard Dreyfuss', {'weight': 1})
# ('Robbie Coltrane', 'Laura Linney', {'weight': 1})
# ('Robbie Coltrane', 'Rachel Weisz', {'weight': 1})
# ('Robbie Coltrane', 'Mark Hamill', {'weight': 2})
# ('Robbie Coltrane', 'Andy Serkis', {'weight': 3})
# ('Robbie Coltrane', 'Imelda Staunton', {'weight': 4})
# ('Robbie Coltrane', 'Ian McKellen', {'weight': 1})
# ('Marie-Josée Croze', 'Aidan Gillen', {'weight': 1})
# ('Aidan Gillen', 'Seána Kerslake', {'weight': 1})
# ('Aidan Gillen', 'Jason Statham', {'weight': 1})
# ('Aidan Gillen', 'Cillian Murphy', {'weight': 1})
# ('Aidan Gillen', 'Andy Serkis', {'weight': 1})
# ('Jennifer Aniston', 'Michael Douglas', {'weight': 1})
# ('Jennifer Aniston', 'Kate McKinnon', {'weight': 1})
# ('Jennifer Aniston', 'Angela Bassett', {'weight': 1})
# ('Jennifer Aniston', 'Karan Soni', {'weight': 1})
# ('Jennifer Aniston', 'Jim Carrey', {'weight': 1})
# ('Jennifer Aniston', 'Ben Stiller', {'weight': 1})
# ('Jennifer Aniston', 'Anna Kendrick', {'weight': 1})
# ('Jennifer Aniston', 'Debra Messing', {'weight': 1})
# ('Jennifer Aniston', 'Meryl Streep', {'weight': 1})
# ('Dolph Lundgren', 'F. Murray Abraham', {'weight': 1})
# ('Dolph Lundgren', 'Wesley Snipes', {'weight': 1})
# ('Dolph Lundgren', 'Jason Statham', {'weight': 3})
# ('Dolph Lundgren', 'Matt Lucas', {'weight': 1})
# ('Richard Dreyfuss', 'Michael Douglas', {'weight': 1})
# ('Richard Dreyfuss', 'F. Murray Abraham', {'weight': 1})
# ('Richard Dreyfuss', 'Bette Midler', {'weight': 1})
# ('Richard Dreyfuss', 'Kenneth Branagh', {'weight': 1})
# ('Richard Dreyfuss', 'James Gandolfini', {'weight': 1})
# ('Richard Dreyfuss', 'José Ferrer', {'weight': 1})
# ('Richard Dreyfuss', 'Laura Linney', {'weight': 1})
# ('Richard Dreyfuss', 'Demi Moore', {'weight': 1})
# ('Richard Dreyfuss', 'Mila Kunis', {'weight': 1})
# ('Richard Dreyfuss', 'Matt Lucas', {'weight': 1})
# ('Richard Dreyfuss', "Brían F. O'Byrne", {'weight': 1})
# ('Richard Dreyfuss', 'Meryl Streep', {'weight': 1})
# ('Robert De Niro', 'Michael Douglas', {'weight': 1})
# ('Robert De Niro', 'F. Murray Abraham', {'weight': 1})
# ('Robert De Niro', 'Wesley Snipes', {'weight': 1})
# ('Robert De Niro', 'Angela Bassett', {'weight': 1})
# ('Robert De Niro', 'Ray Milland', {'weight': 1})
# ('Robert De Niro', 'Jason Statham', {'weight': 1})
# ('Robert De Niro', 'Kenneth Branagh', {'weight': 1})
# ('Robert De Niro', 'Cillian Murphy', {'weight': 1})
# ('Robert De Niro', 'Natalie Portman', {'weight': 1})
# ('Robert De Niro', 'Michelle Pfeiffer', {'weight': 3})
# ('Robert De Niro', 'Ben Stiller', {'weight': 6})
# ('Robert De Niro', 'Demi Moore', {'weight': 1})
# ('Robert De Niro', 'Chris Tucker', {'weight': 2})
# ('Robert De Niro', 'Jonathan Pryce', {'weight': 2})
# ('Robert De Niro', 'Ian McKellen', {'weight': 1})
# ('Robert De Niro', 'Meryl Streep', {'weight': 3})
# ('Sam Neill', 'F. Murray Abraham', {'weight': 1})
# ('Sam Neill', 'Joan Allen', {'weight': 1})
# ('Sam Neill', 'Ian McKellen', {'weight': 2})
# ('Sam Neill', 'Meryl Streep', {'weight': 2})
# ('Debra Messing', 'Bette Midler', {'weight': 1})
# ('Debra Messing', 'Kenneth Branagh', {'weight': 1})
# ('Debra Messing', 'Laura Linney', {'weight': 1})
# ('Debra Messing', 'Ben Stiller', {'weight': 1})
# ('Meryl Streep', 'Michael Douglas', {'weight': 1})
# ('Meryl Streep', 'Angela Bassett', {'weight': 2})
# ('Meryl Streep', 'Bette Midler', {'weight': 1})
# ('Meryl Streep', 'Jim Carrey', {'weight': 1})
# ('Meryl Streep', 'Laura Linney', {'weight': 1})
# ('Meryl Streep', 'Anna Kendrick', {'weight': 1})
# ('Meryl Streep', 'Betty White', {'weight': 1})
# ('Meryl Streep', 'Marcia Gay Harden', {'weight': 1})
# ('Meryl Streep', 'Goldie Hawn', {'weight': 1})
# ('Meryl Streep', 'Ian McKellen', {'weight': 1})
# ('Meryl Streep', 'Jessica Tandy', {'weight': 1})
# ('Michael Douglas', 'Angela Bassett', {'weight': 2})
# ('Michael Douglas', 'Seth Rogen', {'weight': 1})
# ('Michael Douglas', 'Natalie Portman', {'weight': 1})
# ('Michael Douglas', 'Michelle Pfeiffer', {'weight': 2})
# ('Michael Douglas', 'Ben Stiller', {'weight': 1})
# ('Michael Douglas', 'Demi Moore', {'weight': 1})
# ('Michael Douglas', 'Tina Fey', {'weight': 1})
# ('Michael Douglas', 'Goldie Hawn', {'weight': 1})
# ('Kate McKinnon', 'Karan Soni', {'weight': 3})
# ('Kate McKinnon', 'Demi Moore', {'weight': 1})
# ('Kate McKinnon', 'Mila Kunis', {'weight': 1})
# ('Kate McKinnon', 'Tina Fey', {'weight': 1})
# ('Angela Bassett', 'Wesley Snipes', {'weight': 2})
# ('Angela Bassett', 'Natalie Portman', {'weight': 1})
# ('Angela Bassett', 'Michelle Pfeiffer', {'weight': 1})
# ('Angela Bassett', 'Chris Tucker', {'weight': 1})
# ('Angela Bassett', 'Tina Fey', {'weight': 1})
# ('Angela Bassett', 'Betty White', {'weight': 1})
# ('Angela Bassett', 'Andy Serkis', {'weight': 1})
# ('Karan Soni', 'Demi Moore', {'weight': 2})
# ('Karan Soni', 'Anna Kendrick', {'weight': 1})
# ('Jim Carrey', 'Seth Rogen', {'weight': 1})
# ('Jim Carrey', 'James Gandolfini', {'weight': 1})
# ('Jim Carrey', 'Laura Linney', {'weight': 1})
# ('Jim Carrey', 'Ben Stiller', {'weight': 1})
# ('Jim Carrey', 'Joan Allen', {'weight': 1})
# ('Jim Carrey', 'Tina Fey', {'weight': 1})
# ('Jim Carrey', 'Kati Outinen', {'weight': 1})
# ('Ben Stiller', 'Bette Midler', {'weight': 1})
# ('Ben Stiller', 'Seth Rogen', {'weight': 1})
# ('Ben Stiller', 'Natalie Portman', {'weight': 2})
# ('Ben Stiller', 'Anna Kendrick', {'weight': 1})
# ('Ben Stiller', 'Rachel Weisz', {'weight': 1})
# ('Ben Stiller', 'Tina Fey', {'weight': 2})
# ('Ben Stiller', 'Goldie Hawn', {'weight': 1})
# ('Anna Kendrick', 'Seth Rogen', {'weight': 1})
# ('Anna Kendrick', 'Marcia Gay Harden', {'weight': 1})
# ('Anna Kendrick', 'Jennifer Lopez', {'weight': 1})
# ('Audrey Tautou', 'Ian McKellen', {'weight': 1})
# ('Ian McKellen', 'F. Murray Abraham', {'weight': 1})
# ('Ian McKellen', 'Kenneth Branagh', {'weight': 1})
# ('Ian McKellen', 'Cleo King', {'weight': 1})
# ('Ian McKellen', 'Art Carney', {'weight': 1})
# ('Ian McKellen', 'Michelle Pfeiffer', {'weight': 1})
# ('Ian McKellen', 'Laura Linney', {'weight': 2})
# ('Ian McKellen', 'Rachel Weisz', {'weight': 2})
# ('Ian McKellen', 'Andy Serkis', {'weight': 6})
# ('Ian McKellen', 'Imelda Staunton', {'weight': 1})
# ('Kenneth Branagh', 'Cillian Murphy', {'weight': 1})
# ('Kenneth Branagh', 'Michelle Pfeiffer', {'weight': 1})
# ('Kenneth Branagh', 'Laura Linney', {'weight': 1})
# ('Kenneth Branagh', "Brían F. O'Byrne", {'weight': 1})
# ('Kenneth Branagh', 'Imelda Staunton', {'weight': 2})
# ('Cillian Murphy', 'Natalie Portman', {'weight': 1})
# ('Cillian Murphy', 'Andy Serkis', {'weight': 1})
# ('Cillian Murphy', "Brían F. O'Byrne", {'weight': 2})
# ('Natalie Portman', 'Michelle Pfeiffer', {'weight': 1})
# ('Natalie Portman', 'Rachel Weisz', {'weight': 1})
# ('Natalie Portman', 'Mila Kunis', {'weight': 1})
# ('Natalie Portman', 'Sally Field', {'weight': 1})
# ('Natalie Portman', 'Goldie Hawn', {'weight': 1})
# ('Laura Linney', 'Cleo King', {'weight': 1})
# ('Laura Linney', 'Joan Allen', {'weight': 1})
# ('Laura Linney', 'Tina Fey', {'weight': 1})
# ('Laura Linney', 'Andy Serkis', {'weight': 1})
# ('Laura Linney', "Brían F. O'Byrne", {'weight': 1})
# ('Laura Linney', 'Marcia Gay Harden', {'weight': 3})
# ('Laura Linney', 'Imelda Staunton', {'weight': 1})
# ('Jonathan Pryce', 'José Ferrer', {'weight': 1})
# ('Jonathan Pryce', 'Michelle Pfeiffer', {'weight': 1})
# ('Jonathan Pryce', "Brían F. O'Byrne", {'weight': 1})
# ('Jonathan Pryce', 'Imelda Staunton', {'weight': 1})
# ('Andy Serkis', 'Seth Rogen', {'weight': 2})
# ('Andy Serkis', 'Jason Segel', {'weight': 1})
# ('Andy Serkis', 'Mark Hamill', {'weight': 3})
# ('Andy Serkis', 'Imelda Staunton', {'weight': 1})
# ('Andy Serkis', 'Kelly Marie Tran', {'weight': 2})
# ('Seth Rogen', 'Cleo King', {'weight': 1})
# ('Seth Rogen', 'Elaine Kao', {'weight': 1})
# ('Seth Rogen', 'Jason Segel', {'weight': 3})
# ('Michelle Pfeiffer', 'F. Murray Abraham', {'weight': 1})
# ('Michelle Pfeiffer', 'Sandra Bullock', {'weight': 1})
# ('Michelle Pfeiffer', 'Betty White', {'weight': 1})
# ('Michelle Pfeiffer', 'Imelda Staunton', {'weight': 1})
# ('Demi Moore', 'James Gandolfini', {'weight': 1})
# ('Tina Fey', 'Mila Kunis', {'weight': 1})
# ('Tina Fey', 'Betty White', {'weight': 1})
# ('Tina Fey', 'Goldie Hawn', {'weight': 1})
# ('Goldie Hawn', 'Wesley Snipes', {'weight': 1})
# ('Goldie Hawn', 'Bette Midler', {'weight': 1})
# ('Goldie Hawn', 'Marcia Gay Harden', {'weight': 1})
# ('Goldie Hawn', 'Jessica Tandy', {'weight': 1})
# ('Imelda Staunton', 'Matt Lucas', {'weight': 2})
# ('Jason Segel', 'Mila Kunis', {'weight': 2})
# ('F. Murray Abraham', 'Art Carney', {'weight': 1})
# ('F. Murray Abraham', 'Mark Hamill', {'weight': 1})
# ('Jason Statham', 'Wesley Snipes', {'weight': 2})
# ('Jason Statham', 'Joan Allen', {'weight': 1})
# ('Jason Statham', 'Matt Lucas', {'weight': 1})
# ('Jason Statham', 'Jennifer Lopez', {'weight': 1})
# ('Joan Allen', 'Rachel Weisz', {'weight': 1})
# ('Rachel Weisz', 'Mila Kunis', {'weight': 1})
# ('Glenda Jackson', 'Art Carney', {'weight': 1})
# ('Art Carney', 'George C. Scott', {'weight': 2})
# ('Seána Kerslake', "Brían F. O'Byrne", {'weight': 1})
# ('Seána Kerslake', 'Kati Outinen', {'weight': 1})
# ('Cliff Robertson', 'Henry Fonda', {'weight': 1})
# ('Sandra Bullock', 'Wesley Snipes', {'weight': 1})
# ('Sandra Bullock', 'Betty White', {'weight': 1})
# ('Betty White', 'Bette Midler', {'weight': 1})
# ("Brían F. O'Byrne", 'Wesley Snipes', {'weight': 1})
# ('Mark Hamill', 'Peter Cushing', {'weight': 1})
# ('Mark Hamill', 'Kelly Marie Tran', {'weight': 2})
# ('Mark Hamill', 'Alec Guinness', {'weight': 5})
# ('Bette Midler', 'James Gandolfini', {'weight': 1})
# ('Bette Midler', 'Marcia Gay Harden', {'weight': 1})
# ('Wesley Snipes', 'Jennifer Lopez', {'weight': 1})
# ('Marcia Gay Harden', 'Jessica Tandy', {'weight': 1})
# ('Henry Fonda', 'José Ferrer', {'weight': 2})
# ('José Ferrer', 'Ray Milland', {'weight': 1})
# ('Matt Lucas', 'Elaine Kao', {'weight': 1})
# ('Elaine Kao', 'Kang Hye-jeong', {'weight': 1})
# ('Alec Guinness', 'Peter Cushing', {'weight': 1})
# ('Ray Milland', 'Peter Cushing', {'weight': 1})

# %%
drawGraph(g2)
networkSizes(g2)
# Out:
# Number of nodes: 160
# Number of edges: 1559

# %%
showEdges(g2)
# Out:
# ('Colm Meaney', 'Jason Isaacs', {'weight': 1})
# ('Colm Meaney', 'Al Pacino', {'weight': 1})
# ('Colm Meaney', 'Dustin Hoffman', {'weight': 1})
# ('Colm Meaney', 'Julie Walters', {'weight': 1})
# ('Colm Meaney', 'Michael Gambon', {'weight': 1})
# ('Colm Meaney', 'Kali Hawk', {'weight': 1})
# ('Colm Meaney', 'Owen Wilson', {'weight': 1})
# ('Colm Meaney', 'Jonah Hill', {'weight': 1})
# ('Colm Meaney', 'Gabriel Byrne', {'weight': 2})
# ('Colm Meaney', 'Ian Hart', {'weight': 3})
# ('Colm Meaney', 'Nicole Kidman', {'weight': 1})
# ('Colm Meaney', 'Ernest Borgnine', {'weight': 1})
# ('Colm Meaney', 'Woody Harrelson', {'weight': 1})
# ('Colm Meaney', 'Steven Seagal', {'weight': 1})
# ('Colm Meaney', 'Whoopi Goldberg', {'weight': 1})
# ('Colm Meaney', 'Stephen Rea', {'weight': 2})
# ('Jason Isaacs', 'Richard Griffiths', {'weight': 3})
# ('Jason Isaacs', 'Julie Walters', {'weight': 5})
# ('Jason Isaacs', 'Michael Gambon', {'weight': 5})
# ('Jason Isaacs', 'Jackie Chan', {'weight': 1})
# ('Jason Isaacs', 'Richard Harris', {'weight': 1})
# ('Jason Isaacs', 'Charlton Heston', {'weight': 1})
# ('Jason Isaacs', 'John Boyega', {'weight': 1})
# ('Jason Isaacs', 'Mark Williams', {'weight': 6})
# ('Jason Isaacs', 'Ralph Fiennes', {'weight': 6})
# ('Jason Isaacs', 'Owen Wilson', {'weight': 2})
# ('Jason Isaacs', 'Jennifer Garner', {'weight': 1})
# ('Jason Isaacs', 'Ian Hart', {'weight': 1})
# ('Jason Isaacs', 'Amy Ryan', {'weight': 2})
# ('Jason Isaacs', 'Dev Patel', {'weight': 1})
# ('Jason Isaacs', 'Domhnall Gleeson', {'weight': 2})
# ('Jason Isaacs', 'Emma Thompson', {'weight': 3})
# ('Jason Isaacs', 'Daniel Radcliffe', {'weight': 6})
# ('Jason Isaacs', 'Julianne Moore', {'weight': 1})
# ('Jason Isaacs', 'James Phelps', {'weight': 6})
# ('Jason Isaacs', 'Kurt Russell', {'weight': 2})
# ('Jason Isaacs', 'Charlize Theron', {'weight': 1})
# ('Jason Isaacs', 'Liv Tyler', {'weight': 1})
# ('Jason Isaacs', 'Saoirse Ronan', {'weight': 1})
# ('Jason Isaacs', 'Anamaria Marinca', {'weight': 1})
# ('Jason Isaacs', 'Mark Ruffalo', {'weight': 1})
# ('Jason Isaacs', 'Ewan McGregor', {'weight': 1})
# ('Jason Isaacs', 'Fiona Shaw', {'weight': 3})
# ('Jason Isaacs', 'Paul Rudd', {'weight': 1})
# ('Jason Isaacs', 'Chris Rankin', {'weight': 3})
# ('Jason Isaacs', 'Stephen Rea', {'weight': 1})
# ('Al Pacino', 'Leonardo DiCaprio', {'weight': 1})
# ('Al Pacino', 'Dustin Hoffman', {'weight': 1})
# ('Al Pacino', 'Matthew McConaughey', {'weight': 1})
# ('Al Pacino', 'Michael Gambon', {'weight': 2})
# ('Al Pacino', 'Charlton Heston', {'weight': 1})
# ('Al Pacino', 'Philip Seymour Hoffman', {'weight': 1})
# ('Al Pacino', 'Jennifer Garner', {'weight': 1})
# ('Al Pacino', 'Diane Keaton', {'weight': 2})
# ('Al Pacino', 'Hilary Swank', {'weight': 1})
# ('Al Pacino', 'Marlon Brando', {'weight': 1})
# ('Al Pacino', 'Emma Thompson', {'weight': 1})
# ('Al Pacino', 'Cameron Diaz', {'weight': 1})
# ('Al Pacino', 'Kurt Russell', {'weight': 1})
# ('Al Pacino', 'Charlize Theron', {'weight': 1})
# ('Al Pacino', 'Kim Basinger', {'weight': 1})
# ('Al Pacino', 'Robert Duvall', {'weight': 1})
# ('Al Pacino', 'Julia Stiles', {'weight': 1})
# ('Al Pacino', 'Jack Lemmon', {'weight': 1})
# ('Dustin Hoffman', 'Julia Roberts', {'weight': 1})
# ('Dustin Hoffman', 'Jessica Lange', {'weight': 1})
# ('Dustin Hoffman', 'Scarlett Johansson', {'weight': 1})
# ('Dustin Hoffman', 'Jackie Chan', {'weight': 3})
# ('Dustin Hoffman', 'Owen Wilson', {'weight': 3})
# ('Dustin Hoffman', 'Naomi Watts', {'weight': 1})
# ('Dustin Hoffman', 'Jonah Hill', {'weight': 1})
# ('Dustin Hoffman', 'Ian Hart', {'weight': 1})
# ('Dustin Hoffman', 'Geena Davis', {'weight': 3})
# ('Dustin Hoffman', 'Emma Thompson', {'weight': 3})
# ('Dustin Hoffman', 'Cameron Diaz', {'weight': 1})
# ('Dustin Hoffman', 'Nicole Kidman', {'weight': 1})
# ('Dustin Hoffman', 'Judi Dench', {'weight': 1})
# ('Dustin Hoffman', 'Barbra Streisand', {'weight': 3})
# ('Dustin Hoffman', 'Kate Winslet', {'weight': 2})
# ('Dustin Hoffman', 'Laura Dern', {'weight': 2})
# ('Dustin Hoffman', 'Will Ferrell', {'weight': 1})
# ('Dustin Hoffman', 'Gwyneth Paltrow', {'weight': 1})
# ('Dustin Hoffman', 'Woody Harrelson', {'weight': 2})
# ('Dustin Hoffman', 'Whoopi Goldberg', {'weight': 1})
# ('Dustin Hoffman', 'Sharon Stone', {'weight': 1})
# ('Dustin Hoffman', 'Maggie Gyllenhaal', {'weight': 1})
# ('Dustin Hoffman', 'Kate Hudson', {'weight': 1})
# ('Dustin Hoffman', 'Kirsten Dunst', {'weight': 1})
# ('Dustin Hoffman', 'Jack Lemmon', {'weight': 1})
# ('Julie Walters', 'Liza Minnelli', {'weight': 1})
# ('Julie Walters', 'Antonio Banderas', {'weight': 1})
# ('Julie Walters', 'Richard Griffiths', {'weight': 6})
# ('Julie Walters', 'Michael Gambon', {'weight': 8})
# ('Julie Walters', 'Richard Harris', {'weight': 3})
# ('Julie Walters', 'Mark Williams', {'weight': 6})
# ('Julie Walters', 'Ralph Fiennes', {'weight': 3})
# ('Julie Walters', 'Gabriel Byrne', {'weight': 1})
# ('Julie Walters', 'Ian Hart', {'weight': 1})
# ('Julie Walters', 'Anne Hathaway', {'weight': 1})
# ('Julie Walters', 'Domhnall Gleeson', {'weight': 3})
# ('Julie Walters', 'Emma Thompson', {'weight': 5})
# ('Julie Walters', 'Daniel Radcliffe', {'weight': 7})
# ('Julie Walters', 'Nicole Kidman', {'weight': 1})
# ('Julie Walters', 'Cher', {'weight': 1})
# ('Julie Walters', 'Judi Dench', {'weight': 1})
# ('Julie Walters', 'James Phelps', {'weight': 7})
# ('Julie Walters', 'Emily Blunt', {'weight': 3})
# ('Julie Walters', 'Saoirse Ronan', {'weight': 2})
# ('Julie Walters', 'Fiona Shaw', {'weight': 5})
# ('Julie Walters', 'Chris Rankin', {'weight': 5})
# ('Julie Walters', 'Kirsten Dunst', {'weight': 1})
# ('Michael Gambon', 'Halle Berry', {'weight': 1})
# ('Michael Gambon', 'Jonathan Rhys Meyers', {'weight': 2})
# ('Michael Gambon', 'Julia Roberts', {'weight': 1})
# ('Michael Gambon', 'Penélope Cruz', {'weight': 1})
# ('Michael Gambon', 'Richard Griffiths', {'weight': 5})
# ('Michael Gambon', 'Scarlett Johansson', {'weight': 1})
# ('Michael Gambon', 'Brian Caspe', {'weight': 1})
# ('Michael Gambon', 'Mark Williams', {'weight': 7})
# ('Michael Gambon', 'Ralph Fiennes', {'weight': 5})
# ('Michael Gambon', 'Owen Wilson', {'weight': 2})
# ('Michael Gambon', 'Jonah Hill', {'weight': 1})
# ('Michael Gambon', 'Gabriel Byrne', {'weight': 2})
# ('Michael Gambon', 'Adrien Brody', {'weight': 1})
# ('Michael Gambon', 'Ian Hart', {'weight': 1})
# ('Michael Gambon', 'Marlon Brando', {'weight': 1})
# ('Michael Gambon', 'Domhnall Gleeson', {'weight': 2})
# ('Michael Gambon', 'Emma Thompson', {'weight': 6})
# ('Michael Gambon', 'Daniel Radcliffe', {'weight': 7})
# ('Michael Gambon', 'Nicole Kidman', {'weight': 1})
# ('Michael Gambon', 'Julianne Moore', {'weight': 1})
# ('Michael Gambon', 'Judi Dench', {'weight': 2})
# ('Michael Gambon', 'James Phelps', {'weight': 7})
# ('Michael Gambon', 'William Hurt', {'weight': 1})
# ('Michael Gambon', 'Denzel Washington', {'weight': 1})
# ('Michael Gambon', 'Liv Tyler', {'weight': 1})
# ('Michael Gambon', 'Kate Winslet', {'weight': 1})
# ('Michael Gambon', 'Gwyneth Paltrow', {'weight': 3})
# ('Michael Gambon', 'Robert Duvall', {'weight': 1})
# ('Michael Gambon', 'Fiona Shaw', {'weight': 4})
# ('Michael Gambon', 'Chris Rankin', {'weight': 3})
# ('Michael Gambon', 'Julia Stiles', {'weight': 1})
# ('Michael Gambon', 'Jeff Bridges', {'weight': 1})
# ('Kali Hawk', 'Leonardo DiCaprio', {'weight': 1})
# ('Kali Hawk', 'Tom Yi', {'weight': 1})
# ('Kali Hawk', 'Jonah Hill', {'weight': 1})
# ('Kali Hawk', 'Hilary Swank', {'weight': 1})
# ('Kali Hawk', 'Maya Rudolph', {'weight': 1})
# ('Kali Hawk', 'Michael Hitchcock', {'weight': 1})
# ('Kali Hawk', 'Jon Hamm', {'weight': 1})
# ('Kali Hawk', 'Kristen Wiig', {'weight': 1})
# ('Kali Hawk', 'Charlize Theron', {'weight': 1})
# ('Kali Hawk', 'Melissa McCarthy', {'weight': 1})
# ('Owen Wilson', 'Julia Roberts', {'weight': 1})
# ('Owen Wilson', 'Jena Malone', {'weight': 1})
# ('Owen Wilson', 'Penélope Cruz', {'weight': 1})
# ('Owen Wilson', 'Jackie Chan', {'weight': 3})
# ('Owen Wilson', 'Charlton Heston', {'weight': 1})
# ('Owen Wilson', 'Judy Greer', {'weight': 1})
# ('Owen Wilson', 'Liam Neeson', {'weight': 1})
# ('Owen Wilson', 'Jack Nicholson', {'weight': 1})
# ('Owen Wilson', 'Ralph Fiennes', {'weight': 1})
# ('Owen Wilson', 'Jonah Hill', {'weight': 1})
# ('Owen Wilson', 'Adrien Brody', {'weight': 4})
# ('Owen Wilson', 'Mindy Kaling', {'weight': 1})
# ('Owen Wilson', 'Maya Rudolph', {'weight': 1})
# ('Owen Wilson', 'Paul Newman', {'weight': 2})
# ('Owen Wilson', 'Vinnie Jones', {'weight': 1})
# ('Owen Wilson', 'Leslie Mann', {'weight': 2})
# ('Owen Wilson', 'Daniel Radcliffe', {'weight': 1})
# ('Owen Wilson', 'Kristen Wiig', {'weight': 2})
# ('Owen Wilson', 'Barbra Streisand', {'weight': 3})
# ('Owen Wilson', 'Liv Tyler', {'weight': 1})
# ('Owen Wilson', 'Saoirse Ronan', {'weight': 1})
# ('Owen Wilson', 'Laura Dern', {'weight': 2})
# ('Owen Wilson', 'Will Ferrell', {'weight': 6})
# ('Owen Wilson', 'Gwyneth Paltrow', {'weight': 1})
# ('Owen Wilson', 'Woody Harrelson', {'weight': 2})
# ('Owen Wilson', 'Eddie Murphy', {'weight': 1})
# ('Owen Wilson', 'Rachel McAdams', {'weight': 2})
# ('Owen Wilson', 'Kate Hudson', {'weight': 1})
# ('Owen Wilson', 'Paul Rudd', {'weight': 2})
# ('Owen Wilson', 'Luke Wilson', {'weight': 5})
# ('Jonah Hill', 'Leonardo DiCaprio', {'weight': 2})
# ('Jonah Hill', 'Brie Larson', {'weight': 1})
# ('Jonah Hill', 'Matthew McConaughey', {'weight': 2})
# ('Jonah Hill', 'Scarlett Johansson', {'weight': 1})
# ('Jonah Hill', 'Liam Neeson', {'weight': 1})
# ('Jonah Hill', 'Philip Seymour Hoffman', {'weight': 2})
# ('Jonah Hill', 'Ralph Fiennes', {'weight': 3})
# ('Jonah Hill', 'Jennifer Garner', {'weight': 1})
# ('Jonah Hill', 'Naomi Watts', {'weight': 1})
# ('Jonah Hill', 'Gabriel Byrne', {'weight': 1})
# ('Jonah Hill', 'Anthony Daniels', {'weight': 1})
# ('Jonah Hill', 'Mindy Kaling', {'weight': 3})
# ('Jonah Hill', 'Maya Rudolph', {'weight': 1})
# ('Jonah Hill', 'Michael Hitchcock', {'weight': 1})
# ('Jonah Hill', 'Billy Dee Williams', {'weight': 3})
# ('Jonah Hill', 'Leslie Mann', {'weight': 3})
# ('Jonah Hill', 'Kristen Wiig', {'weight': 8})
# ('Jonah Hill', 'Ernest Borgnine', {'weight': 1})
# ('Jonah Hill', 'Will Ferrell', {'weight': 3})
# ('Jonah Hill', 'Anna Faris', {'weight': 1})
# ('Jonah Hill', 'Melissa McCarthy', {'weight': 1})
# ('Jonah Hill', 'Marisa Tomei', {'weight': 1})
# ('Jonah Hill', 'Martin Lawrence', {'weight': 1})
# ('Jonah Hill', 'Paul Rudd', {'weight': 6})
# ('Jonah Hill', 'Elizabeth Banks', {'weight': 3})
# ('Gabriel Byrne', 'Leonardo DiCaprio', {'weight': 1})
# ('Gabriel Byrne', 'Jonathan Rhys Meyers', {'weight': 1})
# ('Gabriel Byrne', 'Antonio Banderas', {'weight': 1})
# ('Gabriel Byrne', 'Richard Harris', {'weight': 3})
# ('Gabriel Byrne', 'Mark Williams', {'weight': 1})
# ('Gabriel Byrne', 'Liam Neeson', {'weight': 2})
# ('Gabriel Byrne', 'Andie MacDowell', {'weight': 1})
# ('Gabriel Byrne', 'Ralph Fiennes', {'weight': 1})
# ('Gabriel Byrne', 'Ian Hart', {'weight': 1})
# ('Gabriel Byrne', 'Marlon Brando', {'weight': 1})
# ('Gabriel Byrne', 'Vinnie Jones', {'weight': 1})
# ('Gabriel Byrne', 'Amy Ryan', {'weight': 2})
# ('Gabriel Byrne', 'Domhnall Gleeson', {'weight': 1})
# ('Gabriel Byrne', 'Rod Steiger', {'weight': 1})
# ('Gabriel Byrne', 'William Hurt', {'weight': 1})
# ('Gabriel Byrne', 'Will Smith', {'weight': 1})
# ('Gabriel Byrne', 'Kim Basinger', {'weight': 1})
# ('Gabriel Byrne', 'Jodie Foster', {'weight': 1})
# ('Gabriel Byrne', 'Maggie Gyllenhaal', {'weight': 1})
# ('Gabriel Byrne', 'Paul Rudd', {'weight': 1})
# ('Gabriel Byrne', 'Stephen Rea', {'weight': 2})
# ('Gabriel Byrne', 'Kirsten Dunst', {'weight': 1})
# ('Ian Hart', 'Jonathan Rhys Meyers', {'weight': 2})
# ('Ian Hart', 'Julia Roberts', {'weight': 1})
# ('Ian Hart', 'Richard Griffiths', {'weight': 2})
# ('Ian Hart', 'Richard Harris', {'weight': 1})
# ('Ian Hart', 'Mark Williams', {'weight': 1})
# ('Ian Hart', 'Liam Neeson', {'weight': 2})
# ('Ian Hart', 'Andie MacDowell', {'weight': 1})
# ('Ian Hart', 'Ralph Fiennes', {'weight': 1})
# ('Ian Hart', 'Daniel Radcliffe', {'weight': 2})
# ('Ian Hart', 'Jennifer Jason Leigh', {'weight': 1})
# ('Ian Hart', 'Julianne Moore', {'weight': 1})
# ('Ian Hart', 'James Phelps', {'weight': 1})
# ('Ian Hart', 'Will Smith', {'weight': 1})
# ('Ian Hart', 'Kate Winslet', {'weight': 1})
# ('Ian Hart', 'Saoirse Ronan', {'weight': 1})
# ('Ian Hart', 'Fiona Shaw', {'weight': 2})
# ('Ian Hart', 'Chris Rankin', {'weight': 1})
# ('Ian Hart', 'Stephen Rea', {'weight': 5})
# ('Nicole Kidman', 'Julia Roberts', {'weight': 1})
# ('Nicole Kidman', 'Shirley MacLaine', {'weight': 1})
# ('Nicole Kidman', 'Jena Malone', {'weight': 1})
# ('Nicole Kidman', 'Penélope Cruz', {'weight': 1})
# ('Nicole Kidman', 'Matthew McConaughey', {'weight': 1})
# ('Nicole Kidman', 'Golshifteh Farahani', {'weight': 1})
# ('Nicole Kidman', 'Philip Seymour Hoffman', {'weight': 1})
# ('Nicole Kidman', 'Naomi Watts', {'weight': 1})
# ('Nicole Kidman', 'Timothée Chalamet', {'weight': 1})
# ('Nicole Kidman', 'Dev Patel', {'weight': 1})
# ('Nicole Kidman', 'Jennifer Jason Leigh', {'weight': 1})
# ('Nicole Kidman', 'Julianne Moore', {'weight': 1})
# ('Nicole Kidman', 'Judi Dench', {'weight': 1})
# ('Nicole Kidman', 'Charlize Theron', {'weight': 1})
# ('Nicole Kidman', 'Drew Barrymore', {'weight': 1})
# ('Nicole Kidman', 'Saoirse Ronan', {'weight': 1})
# ('Nicole Kidman', 'Will Ferrell', {'weight': 1})
# ('Nicole Kidman', 'Gwyneth Paltrow', {'weight': 1})
# ('Nicole Kidman', 'Ewan McGregor', {'weight': 1})
# ('Nicole Kidman', 'Robert Duvall', {'weight': 1})
# ('Nicole Kidman', 'Jodie Foster', {'weight': 1})
# ('Nicole Kidman', 'Kate Hudson', {'weight': 1})
# ('Nicole Kidman', 'Daniel Kaluuya', {'weight': 1})
# ('Nicole Kidman', 'Luke Wilson', {'weight': 1})
# ('Nicole Kidman', 'John Lithgow', {'weight': 1})
# ('Nicole Kidman', 'Kirsten Dunst', {'weight': 1})
# ('Ernest Borgnine', 'Rex Harrison', {'weight': 1})
# ('Ernest Borgnine', 'Richard Harris', {'weight': 1})
# ('Ernest Borgnine', 'Charlton Heston', {'weight': 1})
# ('Ernest Borgnine', 'William Holden', {'weight': 1})
# ('Ernest Borgnine', 'Maya Rudolph', {'weight': 1})
# ('Ernest Borgnine', 'Paul Newman', {'weight': 1})
# ('Ernest Borgnine', 'Louise Fletcher', {'weight': 1})
# ('Ernest Borgnine', 'Rod Steiger', {'weight': 1})
# ('Ernest Borgnine', 'Kurt Russell', {'weight': 1})
# ('Ernest Borgnine', 'Jamie Lee Curtis', {'weight': 1})
# ('Ernest Borgnine', 'Robert Duvall', {'weight': 1})
# ('Ernest Borgnine', 'Sharon Stone', {'weight': 1})
# ('Ernest Borgnine', 'Maximilian Schell', {'weight': 1})
# ('Ernest Borgnine', 'Kirsten Dunst', {'weight': 1})
# ('Woody Harrelson', 'Halle Berry', {'weight': 1})
# ('Woody Harrelson', 'Michelle Williams', {'weight': 1})
# ('Woody Harrelson', 'Antonio Banderas', {'weight': 1})
# ('Woody Harrelson', 'Jena Malone', {'weight': 4})
# ('Woody Harrelson', 'Penélope Cruz', {'weight': 1})
# ('Woody Harrelson', 'Brie Larson', {'weight': 2})
# ('Woody Harrelson', 'Matthew McConaughey', {'weight': 3})
# ('Woody Harrelson', 'Judy Greer', {'weight': 3})
# ('Woody Harrelson', 'Jack Nicholson', {'weight': 1})
# ('Woody Harrelson', 'Philip Seymour Hoffman', {'weight': 3})
# ('Woody Harrelson', 'Naomi Watts', {'weight': 1})
# ('Woody Harrelson', 'Michelle Monaghan', {'weight': 1})
# ('Woody Harrelson', 'Adrien Brody', {'weight': 1})
# ('Woody Harrelson', 'Gwendoline Christie', {'weight': 1})
# ('Woody Harrelson', 'Anthony Daniels', {'weight': 1})
# ('Woody Harrelson', 'Maya Rudolph', {'weight': 1})
# ('Woody Harrelson', 'Geena Davis', {'weight': 1})
# ('Woody Harrelson', 'Daniel Radcliffe', {'weight': 2})
# ('Woody Harrelson', 'Jennifer Jason Leigh', {'weight': 1})
# ('Woody Harrelson', 'Cameron Diaz', {'weight': 1})
# ('Woody Harrelson', 'Julianne Moore', {'weight': 4})
# ('Woody Harrelson', 'Kristen Wiig', {'weight': 1})
# ('Woody Harrelson', 'Will Smith', {'weight': 1})
# ('Woody Harrelson', 'Jennifer Lawrence', {'weight': 4})
# ('Woody Harrelson', 'Charlize Theron', {'weight': 3})
# ('Woody Harrelson', 'Kate Winslet', {'weight': 1})
# ('Woody Harrelson', 'Laura Dern', {'weight': 2})
# ('Woody Harrelson', 'Will Ferrell', {'weight': 3})
# ('Woody Harrelson', 'Mark Ruffalo', {'weight': 2})
# ('Woody Harrelson', 'Whoopi Goldberg', {'weight': 1})
# ('Woody Harrelson', 'Ewan McGregor', {'weight': 1})
# ('Woody Harrelson', 'Marisa Tomei', {'weight': 3})
# ('Woody Harrelson', 'Miranda Otto', {'weight': 1})
# ('Woody Harrelson', 'Luke Wilson', {'weight': 1})
# ('Woody Harrelson', 'Elizabeth Banks', {'weight': 4})
# ('Woody Harrelson', 'John Lithgow', {'weight': 1})
# ('Woody Harrelson', 'Kirsten Dunst', {'weight': 1})
# ('Woody Harrelson', 'Jack Lemmon', {'weight': 1})
# ('Steven Seagal', 'Halle Berry', {'weight': 1})
# ('Steven Seagal', 'Vinnie Jones', {'weight': 3})
# ('Steven Seagal', 'Louise Fletcher', {'weight': 1})
# ('Steven Seagal', 'Kurt Russell', {'weight': 1})
# ('Steven Seagal', 'Sharon Stone', {'weight': 1})
# ('Whoopi Goldberg', 'Julia Roberts', {'weight': 2})
# ('Whoopi Goldberg', 'Brie Larson', {'weight': 1})
# ('Whoopi Goldberg', 'Matthew McConaughey', {'weight': 2})
# ('Whoopi Goldberg', 'Jackie Chan', {'weight': 1})
# ('Whoopi Goldberg', 'Andie MacDowell', {'weight': 1})
# ('Whoopi Goldberg', 'Ralph Fiennes', {'weight': 1})
# ('Whoopi Goldberg', 'Megan Fox', {'weight': 1})
# ('Whoopi Goldberg', 'Maya Rudolph', {'weight': 1})
# ('Whoopi Goldberg', 'Paul Newman', {'weight': 1})
# ('Whoopi Goldberg', 'Billy Dee Williams', {'weight': 1})
# ('Whoopi Goldberg', 'Louise Fletcher', {'weight': 2})
# ('Whoopi Goldberg', 'Jon Hamm', {'weight': 2})
# ('Whoopi Goldberg', 'Rod Steiger', {'weight': 2})
# ('Whoopi Goldberg', 'Cher', {'weight': 1})
# ('Whoopi Goldberg', 'Judi Dench', {'weight': 1})
# ('Whoopi Goldberg', 'William Hurt', {'weight': 1})
# ('Whoopi Goldberg', 'Kurt Russell', {'weight': 1})
# ('Whoopi Goldberg', 'Will Smith', {'weight': 1})
# ('Whoopi Goldberg', 'Emily Blunt', {'weight': 1})
# ('Whoopi Goldberg', 'Drew Barrymore', {'weight': 1})
# ('Whoopi Goldberg', 'Gwyneth Paltrow', {'weight': 1})
# ('Whoopi Goldberg', 'Jamie Lee Curtis', {'weight': 1})
# ('Whoopi Goldberg', 'Marisa Tomei', {'weight': 1})
# ('Whoopi Goldberg', 'Sharon Stone', {'weight': 3})
# ('Whoopi Goldberg', 'Martin Lawrence', {'weight': 1})
# ('Whoopi Goldberg', 'Kate Hudson', {'weight': 1})
# ('Whoopi Goldberg', 'Chris Rock', {'weight': 2})
# ('Whoopi Goldberg', 'John Lithgow', {'weight': 1})
# ('Whoopi Goldberg', 'Jack Lemmon', {'weight': 1})
# ('Stephen Rea', 'Jonathan Rhys Meyers', {'weight': 1})
# ('Stephen Rea', 'Julia Roberts', {'weight': 2})
# ('Stephen Rea', 'Antonio Banderas', {'weight': 1})
# ('Stephen Rea', 'Richard Harris', {'weight': 1})
# ('Stephen Rea', 'Liam Neeson', {'weight': 3})
# ('Stephen Rea', 'Andie MacDowell', {'weight': 1})
# ('Stephen Rea', 'Ralph Fiennes', {'weight': 1})
# ('Stephen Rea', 'Hilary Swank', {'weight': 1})
# ('Stephen Rea', 'Vinnie Jones', {'weight': 1})
# ('Stephen Rea', 'Geena Davis', {'weight': 1})
# ('Stephen Rea', 'Cher', {'weight': 1})
# ('Stephen Rea', 'Julianne Moore', {'weight': 1})
# ('Stephen Rea', 'Judi Dench', {'weight': 1})
# ('Stephen Rea', 'Kim Basinger', {'weight': 1})
# ('Stephen Rea', 'Fiona Shaw', {'weight': 1})
# ('Stephen Rea', 'Maggie Gyllenhaal', {'weight': 1})
# ('Stephen Rea', 'Julia Stiles', {'weight': 1})
# ('Stephen Rea', 'John Lithgow', {'weight': 1})
# ('Stephen Rea', 'Kirsten Dunst', {'weight': 1})
# ('Leonor Watling', 'Jonathan Rhys Meyers', {'weight': 1})
# ('Leonor Watling', 'Franka Potente', {'weight': 1})
# ('Leonor Watling', 'Mark Ruffalo', {'weight': 1})
# ('Leonor Watling', 'Maggie Gyllenhaal', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Michelle Williams', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Julia Roberts', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Antonio Banderas', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Richard Griffiths', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Jessica Lange', {'weight': 2})
# ('Jonathan Rhys Meyers', 'Scarlett Johansson', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Mark Williams', {'weight': 2})
# ('Jonathan Rhys Meyers', 'Liam Neeson', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Philip Seymour Hoffman', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Michelle Monaghan', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Julianne Moore', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Mark Ruffalo', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Ewan McGregor', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Fiona Shaw', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Maximilian Schell', {'weight': 1})
# ('Jonathan Rhys Meyers', 'Luke Wilson', {'weight': 1})
# ('Franka Potente', 'Penélope Cruz', {'weight': 1})
# ('Franka Potente', 'Judy Greer', {'weight': 1})
# ('Franka Potente', 'Michelle Monaghan', {'weight': 1})
# ('Franka Potente', 'Julia Stiles', {'weight': 2})
# ('Franka Potente', 'August Diehl', {'weight': 1})
# ('Mark Ruffalo', 'Leonardo DiCaprio', {'weight': 1})
# ('Mark Ruffalo', 'Michelle Williams', {'weight': 1})
# ('Mark Ruffalo', 'Shirley MacLaine', {'weight': 1})
# ('Mark Ruffalo', 'Chris Evans', {'weight': 5})
# ('Mark Ruffalo', 'Brie Larson', {'weight': 3})
# ('Mark Ruffalo', 'Scarlett Johansson', {'weight': 5})
# ('Mark Ruffalo', 'Judy Greer', {'weight': 1})
# ('Mark Ruffalo', 'Meg Ryan', {'weight': 1})
# ('Mark Ruffalo', 'Jennifer Garner', {'weight': 2})
# ('Mark Ruffalo', 'Naomi Watts', {'weight': 1})
# ('Mark Ruffalo', 'Adrien Brody', {'weight': 1})
# ('Mark Ruffalo', 'Anne Hathaway', {'weight': 1})
# ('Mark Ruffalo', 'Amy Ryan', {'weight': 2})
# ('Mark Ruffalo', 'Julie Delpy', {'weight': 1})
# ('Mark Ruffalo', 'Daniel Radcliffe', {'weight': 1})
# ('Mark Ruffalo', 'Jennifer Jason Leigh', {'weight': 1})
# ('Mark Ruffalo', 'Julianne Moore', {'weight': 2})
# ('Mark Ruffalo', 'William Hurt', {'weight': 2})
# ('Mark Ruffalo', 'Kristen Wiig', {'weight': 1})
# ('Mark Ruffalo', 'Kate Winslet', {'weight': 2})
# ('Mark Ruffalo', 'Laura Dern', {'weight': 1})
# ('Mark Ruffalo', 'Gwyneth Paltrow', {'weight': 6})
# ('Mark Ruffalo', 'Rachel McAdams', {'weight': 1})
# ('Mark Ruffalo', 'Marisa Tomei', {'weight': 1})
# ('Mark Ruffalo', 'Paul Rudd', {'weight': 1})
# ('Mark Ruffalo', 'Maximilian Schell', {'weight': 1})
# ('Mark Ruffalo', 'Luke Wilson', {'weight': 1})
# ('Mark Ruffalo', 'Kirsten Dunst', {'weight': 1})
# ('Maggie Gyllenhaal', 'Julia Roberts', {'weight': 2})
# ('Maggie Gyllenhaal', 'Jena Malone', {'weight': 1})
# ('Maggie Gyllenhaal', 'Judy Greer', {'weight': 2})
# ('Maggie Gyllenhaal', 'Ralph Fiennes', {'weight': 1})
# ('Maggie Gyllenhaal', 'Ginnifer Goodwin', {'weight': 1})
# ('Maggie Gyllenhaal', 'Maya Rudolph', {'weight': 1})
# ('Maggie Gyllenhaal', 'Domhnall Gleeson', {'weight': 1})
# ('Maggie Gyllenhaal', 'Emma Thompson', {'weight': 2})
# ('Maggie Gyllenhaal', 'Julianne Moore', {'weight': 1})
# ('Maggie Gyllenhaal', 'Oscar Isaac', {'weight': 1})
# ('Maggie Gyllenhaal', 'Drew Barrymore', {'weight': 3})
# ('Maggie Gyllenhaal', 'Laura Dern', {'weight': 1})
# ('Maggie Gyllenhaal', 'Will Ferrell', {'weight': 1})
# ('Maggie Gyllenhaal', 'Jamie Lee Curtis', {'weight': 1})
# ('Maggie Gyllenhaal', 'Ewan McGregor', {'weight': 1})
# ('Maggie Gyllenhaal', 'Robert Duvall', {'weight': 1})
# ('Maggie Gyllenhaal', 'Julia Stiles', {'weight': 1})
# ('Maggie Gyllenhaal', 'John Lithgow', {'weight': 1})
# ('Maggie Gyllenhaal', 'Kirsten Dunst', {'weight': 1})
# ('Maggie Gyllenhaal', 'Jeff Bridges', {'weight': 1})
# ('Halle Berry', 'Penélope Cruz', {'weight': 1})
# ('Halle Berry', 'Matthew McConaughey', {'weight': 1})
# ('Halle Berry', 'Jessica Lange', {'weight': 1})
# ('Halle Berry', 'Seann William Scott', {'weight': 1})
# ('Halle Berry', 'Naomi Watts', {'weight': 1})
# ('Halle Berry', 'Hilary Swank', {'weight': 1})
# ('Halle Berry', 'Vinnie Jones', {'weight': 2})
# ('Halle Berry', 'Cameron Diaz', {'weight': 1})
# ('Halle Berry', 'Julianne Moore', {'weight': 2})
# ('Halle Berry', 'Judi Dench', {'weight': 1})
# ('Halle Berry', 'Kurt Russell', {'weight': 1})
# ('Halle Berry', 'Jennifer Lawrence', {'weight': 1})
# ('Halle Berry', 'Kate Winslet', {'weight': 1})
# ('Halle Berry', 'Anna Faris', {'weight': 1})
# ('Halle Berry', 'Ashton Kutcher', {'weight': 1})
# ('Halle Berry', 'Eddie Murphy', {'weight': 1})
# ('Halle Berry', 'Ewan McGregor', {'weight': 2})
# ('Halle Berry', 'Sharon Stone', {'weight': 1})
# ('Halle Berry', 'Martin Lawrence', {'weight': 1})
# ('Halle Berry', 'Chris Rock', {'weight': 1})
# ('Halle Berry', 'Elizabeth Banks', {'weight': 1})
# ('Halle Berry', 'John Lithgow', {'weight': 1})
# ('Halle Berry', 'Jeff Bridges', {'weight': 1})
# ('Penélope Cruz', 'Liza Minnelli', {'weight': 1})
# ('Penélope Cruz', 'Olivia Colman', {'weight': 1})
# ('Penélope Cruz', 'Julia Roberts', {'weight': 1})
# ('Penélope Cruz', 'Antonio Banderas', {'weight': 3})
# ('Penélope Cruz', 'Richard Griffiths', {'weight': 1})
# ('Penélope Cruz', 'Matthew McConaughey', {'weight': 1})
# ('Penélope Cruz', 'Jessica Lange', {'weight': 1})
# ('Penélope Cruz', 'Scarlett Johansson', {'weight': 1})
# ('Penélope Cruz', 'Daisy Ridley', {'weight': 1})
# ('Penélope Cruz', 'Liam Neeson', {'weight': 1})
# ('Penélope Cruz', 'Jack Nicholson', {'weight': 1})
# ('Penélope Cruz', 'Ralph Fiennes', {'weight': 1})
# ('Penélope Cruz', 'Jennifer Garner', {'weight': 1})
# ('Penélope Cruz', 'Naomi Watts', {'weight': 1})
# ('Penélope Cruz', 'Adrien Brody', {'weight': 1})
# ('Penélope Cruz', "Lupita Nyong'o", {'weight': 1})
# ('Penélope Cruz', 'Jon Hamm', {'weight': 1})
# ('Penélope Cruz', 'Harrison Ford', {'weight': 1})
# ('Penélope Cruz', 'Cameron Diaz', {'weight': 2})
# ('Penélope Cruz', 'Julianne Moore', {'weight': 1})
# ('Penélope Cruz', 'Judi Dench', {'weight': 4})
# ('Penélope Cruz', 'Kristen Wiig', {'weight': 1})
# ('Penélope Cruz', 'Kurt Russell', {'weight': 1})
# ('Penélope Cruz', 'Charlize Theron', {'weight': 3})
# ('Penélope Cruz', 'Kate Winslet', {'weight': 1})
# ('Penélope Cruz', 'Will Ferrell', {'weight': 1})
# ('Penélope Cruz', 'Gwyneth Paltrow', {'weight': 1})
# ('Penélope Cruz', 'Sharon Stone', {'weight': 1})
# ('Penélope Cruz', 'Jennifer Hudson', {'weight': 1})
# ('Penélope Cruz', 'Kate Hudson', {'weight': 1})
# ('Penélope Cruz', 'Paul Rudd', {'weight': 1})
# ('Penélope Cruz', 'Luke Wilson', {'weight': 1})
# ('Penélope Cruz', 'Kirsten Dunst', {'weight': 1})
# ('Penélope Cruz', 'Jeff Bridges', {'weight': 1})
# ('Matthew McConaughey', 'Leonardo DiCaprio', {'weight': 1})
# ('Matthew McConaughey', 'Julia Roberts', {'weight': 1})
# ('Matthew McConaughey', 'Shirley MacLaine', {'weight': 1})
# ('Matthew McConaughey', 'Jena Malone', {'weight': 1})
# ('Matthew McConaughey', 'Brie Larson', {'weight': 1})
# ('Matthew McConaughey', 'Scarlett Johansson', {'weight': 1})
# ('Matthew McConaughey', 'Judy Greer', {'weight': 1})
# ('Matthew McConaughey', 'Philip Seymour Hoffman', {'weight': 1})
# ('Matthew McConaughey', 'Ralph Fiennes', {'weight': 2})
# ('Matthew McConaughey', 'Jennifer Garner', {'weight': 2})
# ('Matthew McConaughey', 'Naomi Watts', {'weight': 1})
# ('Matthew McConaughey', 'Timothée Chalamet', {'weight': 1})
# ('Matthew McConaughey', 'Adrien Brody', {'weight': 1})
# ('Matthew McConaughey', 'Paul Newman', {'weight': 2})
# ('Matthew McConaughey', 'Anne Hathaway', {'weight': 2})
# ('Matthew McConaughey', 'Jon Hamm', {'weight': 1})
# ('Matthew McConaughey', 'Jennifer Jason Leigh', {'weight': 1})
# ('Matthew McConaughey', 'Cameron Diaz', {'weight': 1})
# ('Matthew McConaughey', 'Julianne Moore', {'weight': 1})
# ('Matthew McConaughey', 'Charlize Theron', {'weight': 1})
# ('Matthew McConaughey', 'Zooey Deschanel', {'weight': 1})
# ('Matthew McConaughey', 'Drew Barrymore', {'weight': 1})
# ('Matthew McConaughey', 'Will Ferrell', {'weight': 1})
# ('Matthew McConaughey', 'Ewan McGregor', {'weight': 1})
# ('Matthew McConaughey', 'Jodie Foster', {'weight': 1})
# ('Matthew McConaughey', 'Marisa Tomei', {'weight': 1})
# ('Matthew McConaughey', 'Jennifer Hudson', {'weight': 1})
# ('Matthew McConaughey', 'Martin Lawrence', {'weight': 1})
# ('Matthew McConaughey', 'Kate Hudson', {'weight': 2})
# ('Matthew McConaughey', 'Paul Rudd', {'weight': 1})
# ('Matthew McConaughey', 'Chris Rock', {'weight': 1})
# ('Matthew McConaughey', 'John Lithgow', {'weight': 2})
# ('Jessica Lange', 'Michelle Williams', {'weight': 2})
# ('Jessica Lange', 'Shirley MacLaine', {'weight': 1})
# ('Jessica Lange', 'Brie Larson', {'weight': 1})
# ('Jessica Lange', 'Liam Neeson', {'weight': 1})
# ('Jessica Lange', 'Jack Nicholson', {'weight': 1})
# ('Jessica Lange', 'Diane Keaton', {'weight': 1})
# ('Jessica Lange', 'Julie Delpy', {'weight': 1})
# ('Jessica Lange', 'Geena Davis', {'weight': 1})
# ('Jessica Lange', 'Jennifer Jason Leigh', {'weight': 1})
# ('Jessica Lange', 'William Hurt', {'weight': 1})
# ('Jessica Lange', 'Oscar Isaac', {'weight': 1})
# ('Jessica Lange', 'Gwyneth Paltrow', {'weight': 1})
# ('Jessica Lange', 'Rachel McAdams', {'weight': 1})
# ('Jessica Lange', 'Ewan McGregor', {'weight': 1})
# ('Jessica Lange', 'Gregory Peck', {'weight': 1})
# ('Jessica Lange', 'Jodie Foster', {'weight': 1})
# ('Jessica Lange', 'Sharon Stone', {'weight': 2})
# ('Jessica Lange', 'Luke Wilson', {'weight': 1})
# ('Jessica Lange', 'John Lithgow', {'weight': 1})
# ('Jessica Lange', 'Jeff Bridges', {'weight': 2})
# ('Seann William Scott', 'Jennifer Garner', {'weight': 1})
# ('Seann William Scott', 'Naomi Watts', {'weight': 1})
# ('Seann William Scott', 'Julianne Moore', {'weight': 1})
# ('Seann William Scott', 'Kristen Wiig', {'weight': 1})
# ('Seann William Scott', 'Kate Winslet', {'weight': 1})
# ('Seann William Scott', 'Will Ferrell', {'weight': 2})
# ('Seann William Scott', 'Anna Faris', {'weight': 1})
# ('Seann William Scott', 'Ashton Kutcher', {'weight': 1})
# ('Seann William Scott', 'Paul Rudd', {'weight': 1})
# ('Seann William Scott', 'Chris Rock', {'weight': 1})
# ('Seann William Scott', 'Luke Wilson', {'weight': 1})
# ('Seann William Scott', 'Elizabeth Banks', {'weight': 2})
# ('Naomi Watts', 'Leonardo DiCaprio', {'weight': 1})
# ('Naomi Watts', 'Antonio Banderas', {'weight': 1})
# ('Naomi Watts', 'Brie Larson', {'weight': 1})
# ('Naomi Watts', 'Daisy Ridley', {'weight': 1})
# ('Naomi Watts', 'Jack Nicholson', {'weight': 1})
# ('Naomi Watts', 'Adrien Brody', {'weight': 1})
# ('Naomi Watts', 'Amy Ryan', {'weight': 1})
# ('Naomi Watts', 'Julianne Moore', {'weight': 1})
# ('Naomi Watts', 'Judi Dench', {'weight': 2})
# ('Naomi Watts', 'Kate Winslet', {'weight': 3})
# ('Naomi Watts', 'Laura Dern', {'weight': 2})
# ('Naomi Watts', 'Anna Faris', {'weight': 1})
# ('Naomi Watts', 'Ewan McGregor', {'weight': 2})
# ('Naomi Watts', 'Melissa McCarthy', {'weight': 1})
# ('Naomi Watts', 'Sharon Stone', {'weight': 1})
# ('Naomi Watts', 'Jennifer Hudson', {'weight': 1})
# ('Naomi Watts', 'Kate Hudson', {'weight': 1})
# ('Naomi Watts', 'Elizabeth Banks', {'weight': 1})
# ('Naomi Watts', 'Kirsten Dunst', {'weight': 1})
# ('Hilary Swank', 'Clint Eastwood', {'weight': 1})
# ('Hilary Swank', 'Scarlett Johansson', {'weight': 1})
# ('Hilary Swank', 'Adrien Brody', {'weight': 1})
# ('Hilary Swank', 'Ginnifer Goodwin', {'weight': 1})
# ('Hilary Swank', 'Matthew Perry', {'weight': 1})
# ('Hilary Swank', 'Ashton Kutcher', {'weight': 1})
# ('Hilary Swank', 'Ewan McGregor', {'weight': 1})
# ('Hilary Swank', 'Fiona Shaw', {'weight': 1})
# ('Hilary Swank', 'Miranda Otto', {'weight': 1})
# ('Hilary Swank', 'John Lithgow', {'weight': 2})
# ('Vinnie Jones', 'Amy Ryan', {'weight': 1})
# ('Vinnie Jones', 'Julianne Moore', {'weight': 1})
# ('Vinnie Jones', 'Denzel Washington', {'weight': 1})
# ('Vinnie Jones', 'Robert Duvall', {'weight': 1})
# ('Vinnie Jones', 'Paul Rudd', {'weight': 1})
# ('Vinnie Jones', 'Chris Rock', {'weight': 1})
# ('Cameron Diaz', 'Leonardo DiCaprio', {'weight': 1})
# ('Cameron Diaz', 'Julia Roberts', {'weight': 1})
# ('Cameron Diaz', 'Shirley MacLaine', {'weight': 1})
# ('Cameron Diaz', 'Antonio Banderas', {'weight': 6})
# ('Cameron Diaz', 'Charlton Heston', {'weight': 1})
# ('Cameron Diaz', 'Liam Neeson', {'weight': 1})
# ('Cameron Diaz', 'Maya Rudolph', {'weight': 1})
# ('Cameron Diaz', 'Leslie Mann', {'weight': 2})
# ('Cameron Diaz', 'Geena Davis', {'weight': 1})
# ('Cameron Diaz', 'Jon Hamm', {'weight': 2})
# ('Cameron Diaz', 'Julianne Moore', {'weight': 1})
# ('Cameron Diaz', 'Kurt Russell', {'weight': 1})
# ('Cameron Diaz', 'Drew Barrymore', {'weight': 2})
# ('Cameron Diaz', 'Kate Winslet', {'weight': 1})
# ('Cameron Diaz', 'Ashton Kutcher', {'weight': 2})
# ('Cameron Diaz', 'Eddie Murphy', {'weight': 10})
# ('Cameron Diaz', 'Ewan McGregor', {'weight': 2})
# ('Cameron Diaz', 'Melissa McCarthy', {'weight': 1})
# ('Cameron Diaz', 'Chris Rock', {'weight': 1})
# ('Cameron Diaz', 'Luke Wilson', {'weight': 2})
# ('Cameron Diaz', 'Elizabeth Banks', {'weight': 1})
# ('Cameron Diaz', 'John Lithgow', {'weight': 4})
# ('Julianne Moore', 'Michelle Williams', {'weight': 3})
# ('Julianne Moore', 'Antonio Banderas', {'weight': 1})
# ('Julianne Moore', 'Jena Malone', {'weight': 2})
# ('Julianne Moore', 'Brie Larson', {'weight': 1})
# ('Julianne Moore', 'Scarlett Johansson', {'weight': 1})
# ('Julianne Moore', 'Judy Greer', {'weight': 1})
# ('Julianne Moore', 'Liam Neeson', {'weight': 2})
# ('Julianne Moore', 'Jack Nicholson', {'weight': 1})
# ('Julianne Moore', 'Andie MacDowell', {'weight': 1})
# ('Julianne Moore', 'Philip Seymour Hoffman', {'weight': 6})
# ('Julianne Moore', 'Ralph Fiennes', {'weight': 1})
# ('Julianne Moore', 'Michelle Monaghan', {'weight': 1})
# ('Julianne Moore', 'Ginnifer Goodwin', {'weight': 1})
# ('Julianne Moore', 'Gwendoline Christie', {'weight': 1})
# ('Julianne Moore', 'Maya Rudolph', {'weight': 1})
# ('Julianne Moore', "Lupita Nyong'o", {'weight': 1})
# ('Julianne Moore', 'Billy Dee Williams', {'weight': 1})
# ('Julianne Moore', 'Anne Hathaway', {'weight': 1})
# ('Julianne Moore', 'Louise Fletcher', {'weight': 1})
# ('Julianne Moore', 'Jon Hamm', {'weight': 1})
# ('Julianne Moore', 'Harrison Ford', {'weight': 1})
# ('Julianne Moore', 'Jennifer Jason Leigh', {'weight': 1})
# ('Julianne Moore', 'Judi Dench', {'weight': 2})
# ('Julianne Moore', 'Jennifer Lawrence', {'weight': 2})
# ('Julianne Moore', 'Oscar Isaac', {'weight': 1})
# ('Julianne Moore', 'Liv Tyler', {'weight': 1})
# ('Julianne Moore', 'Kate Winslet', {'weight': 1})
# ('Julianne Moore', 'Laura Dern', {'weight': 2})
# ('Julianne Moore', 'Will Ferrell', {'weight': 1})
# ('Julianne Moore', 'Ewan McGregor', {'weight': 1})
# ('Julianne Moore', 'Marisa Tomei', {'weight': 1})
# ('Julianne Moore', 'Sharon Stone', {'weight': 1})
# ('Julianne Moore', 'Jennifer Hudson', {'weight': 1})
# ('Julianne Moore', 'Fiona Shaw', {'weight': 1})
# ('Julianne Moore', 'Elizabeth Banks', {'weight': 2})
# ('Julianne Moore', 'John Lithgow', {'weight': 1})
# ('Julianne Moore', 'Kirsten Dunst', {'weight': 1})
# ('Julianne Moore', 'Jeff Bridges', {'weight': 3})
# ('Julianne Moore', 'Jack Lemmon', {'weight': 1})
# ('Judi Dench', 'Leonardo DiCaprio', {'weight': 1})
# ('Judi Dench', 'Michelle Williams', {'weight': 1})
# ('Judi Dench', 'Olivia Colman', {'weight': 1})
# ('Judi Dench', 'Jena Malone', {'weight': 1})
# ('Judi Dench', 'Richard Griffiths', {'weight': 2})
# ('Judi Dench', 'Charlton Heston', {'weight': 1})
# ('Judi Dench', 'Daisy Ridley', {'weight': 1})
# ('Judi Dench', 'Mark Williams', {'weight': 1})
# ('Judi Dench', 'Liam Neeson', {'weight': 1})
# ('Judi Dench', 'Jack Nicholson', {'weight': 1})
# ('Judi Dench', 'Ralph Fiennes', {'weight': 3})
# ('Judi Dench', 'Leslie Mann', {'weight': 1})
# ('Judi Dench', 'Dev Patel', {'weight': 2})
# ('Judi Dench', 'Emma Thompson', {'weight': 1})
# ('Judi Dench', 'Cher', {'weight': 1})
# ('Judi Dench', 'Kate Winslet', {'weight': 3})
# ('Judi Dench', 'Gwyneth Paltrow', {'weight': 1})
# ('Judi Dench', 'Sharon Stone', {'weight': 1})
# ('Judi Dench', 'Jennifer Hudson', {'weight': 2})
# ('Judi Dench', 'Kate Hudson', {'weight': 1})
# ('Judi Dench', 'Kirsten Dunst', {'weight': 1})
# ('Judi Dench', 'Jack Lemmon', {'weight': 1})
# ('Kurt Russell', 'Leonardo DiCaprio', {'weight': 1})
# ('Kurt Russell', 'Charlton Heston', {'weight': 1})
# ('Kurt Russell', 'Jennifer Jason Leigh', {'weight': 2})
# ('Kurt Russell', 'Cher', {'weight': 1})
# ('Kurt Russell', 'Charlize Theron', {'weight': 1})
# ('Kurt Russell', 'Jamie Lee Curtis', {'weight': 1})
# ('Kurt Russell', 'Sharon Stone', {'weight': 1})
# ('Kurt Russell', 'Kate Hudson', {'weight': 1})
# ('Jennifer Lawrence', 'Jena Malone', {'weight': 3})
# ('Jennifer Lawrence', 'Philip Seymour Hoffman', {'weight': 3})
# ('Jennifer Lawrence', 'Gwendoline Christie', {'weight': 1})
# ('Jennifer Lawrence', 'Domhnall Gleeson', {'weight': 1})
# ('Jennifer Lawrence', 'Kristen Wiig', {'weight': 1})
# ('Jennifer Lawrence', 'Charlize Theron', {'weight': 1})
# ('Jennifer Lawrence', 'Oscar Isaac', {'weight': 1})
# ('Jennifer Lawrence', 'Kim Basinger', {'weight': 1})
# ('Jennifer Lawrence', 'Jodie Foster', {'weight': 1})
# ('Jennifer Lawrence', 'Julia Stiles', {'weight': 1})
# ('Jennifer Lawrence', 'Elizabeth Banks', {'weight': 4})
# ('Kate Winslet', 'Leonardo DiCaprio', {'weight': 2})
# ('Kate Winslet', 'Charlton Heston', {'weight': 1})
# ('Kate Winslet', 'Daisy Ridley', {'weight': 1})
# ('Kate Winslet', 'Jack Nicholson', {'weight': 1})
# ('Kate Winslet', 'Ralph Fiennes', {'weight': 1})
# ('Kate Winslet', 'Megan Fox', {'weight': 1})
# ('Kate Winslet', 'Emma Thompson', {'weight': 1})
# ('Kate Winslet', 'Will Smith', {'weight': 1})
# ('Kate Winslet', 'Saoirse Ronan', {'weight': 1})
# ('Kate Winslet', 'Gwyneth Paltrow', {'weight': 1})
# ('Kate Winslet', 'Anna Faris', {'weight': 1})
# ('Kate Winslet', 'Jodie Foster', {'weight': 1})
# ('Kate Winslet', 'Melissa McCarthy', {'weight': 1})
# ('Kate Winslet', 'Sharon Stone', {'weight': 1})
# ('Kate Winslet', 'Jennifer Hudson', {'weight': 2})
# ('Kate Winslet', 'Fiona Shaw', {'weight': 1})
# ('Kate Winslet', 'Elizabeth Banks', {'weight': 1})
# ('Kate Winslet', 'Kirsten Dunst', {'weight': 3})
# ('Kate Winslet', 'Jeff Bridges', {'weight': 1})
# ('Kate Winslet', 'Jack Lemmon', {'weight': 1})
# ('Anna Faris', 'Michelle Williams', {'weight': 1})
# ('Anna Faris', 'Olivia Colman', {'weight': 1})
# ('Anna Faris', 'Chris Evans', {'weight': 1})
# ('Anna Faris', 'Scarlett Johansson', {'weight': 1})
# ('Anna Faris', 'Megan Fox', {'weight': 1})
# ('Anna Faris', 'Ginnifer Goodwin', {'weight': 1})
# ('Anna Faris', 'Diane Keaton', {'weight': 1})
# ('Anna Faris', 'Maya Rudolph', {'weight': 1})
# ('Anna Faris', 'Michael Hitchcock', {'weight': 1})
# ('Anna Faris', 'Anne Hathaway', {'weight': 1})
# ('Anna Faris', 'Julie Delpy', {'weight': 1})
# ('Anna Faris', 'Rachel McAdams', {'weight': 1})
# ('Anna Faris', 'Luke Wilson', {'weight': 1})
# ('Anna Faris', 'Elizabeth Banks', {'weight': 1})
# ('Ashton Kutcher', 'Julia Roberts', {'weight': 1})
# ('Ashton Kutcher', 'Shirley MacLaine', {'weight': 1})
# ('Ashton Kutcher', 'Jennifer Garner', {'weight': 2})
# ('Ashton Kutcher', 'Mindy Kaling', {'weight': 1})
# ('Ashton Kutcher', 'Anne Hathaway', {'weight': 1})
# ('Ashton Kutcher', 'Charlize Theron', {'weight': 1})
# ('Ashton Kutcher', 'Sharon Stone', {'weight': 1})
# ('Ashton Kutcher', 'Martin Lawrence', {'weight': 2})
# ('Ashton Kutcher', 'Luke Wilson', {'weight': 1})
# ('Ashton Kutcher', 'Julia Stiles', {'weight': 1})
# ('Ashton Kutcher', 'John Lithgow', {'weight': 1})
# ('Eddie Murphy', 'Antonio Banderas', {'weight': 6})
# ('Eddie Murphy', 'Maya Rudolph', {'weight': 1})
# ('Eddie Murphy', 'Jon Hamm', {'weight': 2})
# ('Eddie Murphy', 'Jamie Lee Curtis', {'weight': 1})
# ('Eddie Murphy', 'Jennifer Hudson', {'weight': 1})
# ('Eddie Murphy', 'Martin Lawrence', {'weight': 2})
# ('Eddie Murphy', 'Chris Rock', {'weight': 4})
# ('Eddie Murphy', 'Elizabeth Banks', {'weight': 1})
# ('Eddie Murphy', 'John Lithgow', {'weight': 5})
# ('Ewan McGregor', 'Michelle Williams', {'weight': 2})
# ('Ewan McGregor', 'Julia Roberts', {'weight': 1})
# ('Ewan McGregor', 'Antonio Banderas', {'weight': 1})
# ('Ewan McGregor', 'Richard Griffiths', {'weight': 1})
# ('Ewan McGregor', 'Scarlett Johansson', {'weight': 1})
# ('Ewan McGregor', 'Daisy Ridley', {'weight': 2})
# ('Ewan McGregor', 'John Boyega', {'weight': 2})
# ('Ewan McGregor', 'Liam Neeson', {'weight': 3})
# ('Ewan McGregor', 'Ralph Fiennes', {'weight': 1})
# ('Ewan McGregor', 'Gwendoline Christie', {'weight': 1})
# ('Ewan McGregor', 'Anthony Daniels', {'weight': 5})
# ('Ewan McGregor', "Lupita Nyong'o", {'weight': 2})
# ('Ewan McGregor', 'Billy Dee Williams', {'weight': 1})
# ('Ewan McGregor', 'Leslie Mann', {'weight': 1})
# ('Ewan McGregor', 'Domhnall Gleeson', {'weight': 2})
# ('Ewan McGregor', 'Emma Thompson', {'weight': 2})
# ('Ewan McGregor', 'Harrison Ford', {'weight': 2})
# ('Ewan McGregor', 'Charlize Theron', {'weight': 1})
# ('Ewan McGregor', 'Emily Blunt', {'weight': 1})
# ('Ewan McGregor', 'Oscar Isaac', {'weight': 2})
# ('Ewan McGregor', 'Gwyneth Paltrow', {'weight': 2})
# ('Ewan McGregor', 'Anamaria Marinca', {'weight': 1})
# ('Ewan McGregor', 'Miranda Otto', {'weight': 1})
# ('Ewan McGregor', 'Peter Mayhew', {'weight': 2})
# ('Ewan McGregor', 'Jeff Bridges', {'weight': 1})
# ('Sharon Stone', 'Leonardo DiCaprio', {'weight': 1})
# ('Sharon Stone', 'Antonio Banderas', {'weight': 1})
# ('Sharon Stone', 'Jack Nicholson', {'weight': 1})
# ('Sharon Stone', 'Andie MacDowell', {'weight': 1})
# ('Sharon Stone', 'Julie Delpy', {'weight': 1})
# ('Sharon Stone', 'Rod Steiger', {'weight': 1})
# ('Sharon Stone', 'Drew Barrymore', {'weight': 2})
# ('Sharon Stone', 'Katharine Hepburn', {'weight': 1})
# ('Sharon Stone', 'Jodie Foster', {'weight': 1})
# ('Sharon Stone', 'Jennifer Hudson', {'weight': 1})
# ('Sharon Stone', 'Kirsten Dunst', {'weight': 1})
# ('Sharon Stone', 'Jeff Bridges', {'weight': 2})
# ('Martin Lawrence', 'Megan Fox', {'weight': 1})
# ('Martin Lawrence', 'Michael Hitchcock', {'weight': 1})
# ('Martin Lawrence', 'Will Smith', {'weight': 4})
# ('Martin Lawrence', 'Marisa Tomei', {'weight': 1})
# ('Martin Lawrence', 'Chris Rock', {'weight': 2})
# ('Martin Lawrence', 'Luke Wilson', {'weight': 2})
# ('Chris Rock', 'Maya Rudolph', {'weight': 3})
# ('Chris Rock', 'Anne Hathaway', {'weight': 1})
# ('Chris Rock', 'Julie Delpy', {'weight': 1})
# ('Chris Rock', 'William Hurt', {'weight': 1})
# ('Chris Rock', 'Will Ferrell', {'weight': 1})
# ('Chris Rock', 'Gwyneth Paltrow', {'weight': 1})
# ('Chris Rock', 'Jennifer Hudson', {'weight': 1})
# ('Chris Rock', 'Luke Wilson', {'weight': 1})
# ('Chris Rock', 'Elizabeth Banks', {'weight': 1})
# ('Elizabeth Banks', 'Leonardo DiCaprio', {'weight': 1})
# ('Elizabeth Banks', 'Michelle Williams', {'weight': 1})
# ('Elizabeth Banks', 'Jena Malone', {'weight': 3})
# ('Elizabeth Banks', 'Liam Neeson', {'weight': 2})
# ('Elizabeth Banks', 'Andie MacDowell', {'weight': 1})
# ('Elizabeth Banks', 'Philip Seymour Hoffman', {'weight': 3})
# ('Elizabeth Banks', 'Ralph Fiennes', {'weight': 1})
# ('Elizabeth Banks', 'Jennifer Garner', {'weight': 1})
# ('Elizabeth Banks', 'Gwendoline Christie', {'weight': 1})
# ('Elizabeth Banks', 'Anthony Daniels', {'weight': 1})
# ('Elizabeth Banks', 'Mindy Kaling', {'weight': 1})
# ('Elizabeth Banks', 'Maya Rudolph', {'weight': 2})
# ('Elizabeth Banks', 'Billy Dee Williams', {'weight': 1})
# ('Elizabeth Banks', 'Leslie Mann', {'weight': 1})
# ('Elizabeth Banks', 'Kristen Wiig', {'weight': 2})
# ('Elizabeth Banks', 'Zooey Deschanel', {'weight': 1})
# ('Elizabeth Banks', 'Will Ferrell', {'weight': 2})
# ('Elizabeth Banks', 'Melissa McCarthy', {'weight': 1})
# ('Elizabeth Banks', 'Paul Rudd', {'weight': 7})
# ('Elizabeth Banks', 'John Lithgow', {'weight': 1})
# ('Elizabeth Banks', 'Kirsten Dunst', {'weight': 3})
# ('Elizabeth Banks', 'Jeff Bridges', {'weight': 1})
# ('John Lithgow', 'Julia Roberts', {'weight': 2})
# ('John Lithgow', 'Shirley MacLaine', {'weight': 1})
# ('John Lithgow', 'Geraldine Page', {'weight': 1})
# ('John Lithgow', 'Tom Yi', {'weight': 1})
# ('John Lithgow', 'Liam Neeson', {'weight': 2})
# ('John Lithgow', 'Jack Nicholson', {'weight': 1})
# ('John Lithgow', 'Ralph Fiennes', {'weight': 1})
# ('John Lithgow', 'Megan Fox', {'weight': 1})
# ('John Lithgow', 'Timothée Chalamet', {'weight': 1})
# ('John Lithgow', 'Mindy Kaling', {'weight': 1})
# ('John Lithgow', 'Paul Newman', {'weight': 1})
# ('John Lithgow', 'Anne Hathaway', {'weight': 1})
# ('John Lithgow', 'Leslie Mann', {'weight': 2})
# ('John Lithgow', 'Amy Ryan', {'weight': 1})
# ('John Lithgow', 'Emma Thompson', {'weight': 1})
# ('John Lithgow', 'Denzel Washington', {'weight': 2})
# ('John Lithgow', 'Charlize Theron', {'weight': 2})
# ('John Lithgow', 'Liv Tyler', {'weight': 1})
# ('John Lithgow', 'Laura Dern', {'weight': 1})
# ('John Lithgow', 'Will Ferrell', {'weight': 2})
# ('John Lithgow', 'Jamie Lee Curtis', {'weight': 2})
# ('John Lithgow', 'Robert Duvall', {'weight': 1})
# ('John Lithgow', 'Jodie Foster', {'weight': 1})
# ('John Lithgow', 'Melissa McCarthy', {'weight': 1})
# ('John Lithgow', 'Marisa Tomei', {'weight': 1})
# ('John Lithgow', 'Jennifer Hudson', {'weight': 1})
# ('John Lithgow', 'Paul Rudd', {'weight': 1})
# ('John Lithgow', 'Miranda Otto', {'weight': 1})
# ('Jeff Bridges', 'Judy Greer', {'weight': 1})
# ('Jeff Bridges', 'Andie MacDowell', {'weight': 2})
# ('Jeff Bridges', 'Philip Seymour Hoffman', {'weight': 1})
# ('Jeff Bridges', 'Megan Fox', {'weight': 1})
# ('Jeff Bridges', 'Domhnall Gleeson', {'weight': 2})
# ('Jeff Bridges', 'Jon Hamm', {'weight': 1})
# ('Jeff Bridges', 'Barbra Streisand', {'weight': 2})
# ('Jeff Bridges', 'Zooey Deschanel', {'weight': 1})
# ('Jeff Bridges', 'Drew Barrymore', {'weight': 1})
# ('Jeff Bridges', 'Gwyneth Paltrow', {'weight': 1})
# ('Jeff Bridges', 'Kim Basinger', {'weight': 2})
# ('Jeff Bridges', 'Rachel McAdams', {'weight': 1})
# ('Jeff Bridges', 'Robert Duvall', {'weight': 1})
# ('Jeff Bridges', 'Paul Rudd', {'weight': 1})
# ('Jeff Bridges', 'Luke Wilson', {'weight': 1})
# ('Jeff Bridges', 'Kirsten Dunst', {'weight': 1})
# ('Leonardo DiCaprio', 'Michelle Williams', {'weight': 1})
# ('Leonardo DiCaprio', 'Jackie Chan', {'weight': 1})
# ('Leonardo DiCaprio', 'Golshifteh Farahani', {'weight': 1})
# ('Leonardo DiCaprio', 'Liam Neeson', {'weight': 1})
# ('Leonardo DiCaprio', 'Jack Nicholson', {'weight': 1})
# ('Leonardo DiCaprio', 'Jennifer Garner', {'weight': 1})
# ('Leonardo DiCaprio', 'Diane Keaton', {'weight': 1})
# ('Leonardo DiCaprio', 'Domhnall Gleeson', {'weight': 1})
# ('Leonardo DiCaprio', 'Charlize Theron', {'weight': 1})
# ('Leonardo DiCaprio', 'Oscar Isaac', {'weight': 1})
# ('Leonardo DiCaprio', 'Drew Barrymore', {'weight': 1})
# ('Leonardo DiCaprio', 'Paul Rudd', {'weight': 1})
# ('Michelle Williams', 'Jena Malone', {'weight': 1})
# ('Michelle Williams', 'Philip Seymour Hoffman', {'weight': 1})
# ('Michelle Williams', 'Michelle Monaghan', {'weight': 1})
# ('Michelle Williams', 'Anne Hathaway', {'weight': 1})
# ('Michelle Williams', 'Leslie Mann', {'weight': 1})
# ('Michelle Williams', 'Julie Delpy', {'weight': 1})
# ('Michelle Williams', 'Jennifer Jason Leigh', {'weight': 2})
# ('Michelle Williams', 'Laura Dern', {'weight': 1})
# ('Michelle Williams', 'Will Ferrell', {'weight': 1})
# ('Michelle Williams', 'Jamie Lee Curtis', {'weight': 1})
# ('Michelle Williams', 'Paul Rudd', {'weight': 1})
# ('Michelle Williams', 'Kirsten Dunst', {'weight': 1})
# ('Jackie Chan', 'Shirley MacLaine', {'weight': 1})
# ('Jackie Chan', 'Adrien Brody', {'weight': 1})
# ('Jackie Chan', 'Maya Rudolph', {'weight': 1})
# ('Jackie Chan', 'Ziyi Zhang', {'weight': 3})
# ('Jackie Chan', 'Kate Hudson', {'weight': 1})
# ('Jackie Chan', 'Luke Wilson', {'weight': 1})
# ('Golshifteh Farahani', 'Antonio Banderas', {'weight': 1})
# ('Golshifteh Farahani', 'Taraneh Alidoosti', {'weight': 3})
# ('Golshifteh Farahani', 'Oscar Isaac', {'weight': 1})
# ('Liam Neeson', 'Clint Eastwood', {'weight': 1})
# ('Liam Neeson', 'Julia Roberts', {'weight': 3})
# ('Liam Neeson', 'Antonio Banderas', {'weight': 1})
# ('Liam Neeson', 'Daisy Ridley', {'weight': 1})
# ('Liam Neeson', 'Judy Greer', {'weight': 1})
# ('Liam Neeson', 'John Boyega', {'weight': 1})
# ('Liam Neeson', 'Andie MacDowell', {'weight': 1})
# ('Liam Neeson', 'Philip Seymour Hoffman', {'weight': 1})
# ('Liam Neeson', 'Ralph Fiennes', {'weight': 5})
# ('Liam Neeson', 'Adrien Brody', {'weight': 1})
# ('Liam Neeson', 'Diane Keaton', {'weight': 1})
# ('Liam Neeson', 'Anthony Daniels', {'weight': 3})
# ('Liam Neeson', 'Maya Rudolph', {'weight': 1})
# ('Liam Neeson', "Lupita Nyong'o", {'weight': 3})
# ('Liam Neeson', 'Billy Dee Williams', {'weight': 2})
# ('Liam Neeson', 'Anne Hathaway', {'weight': 1})
# ('Liam Neeson', 'Domhnall Gleeson', {'weight': 1})
# ('Liam Neeson', 'Jon Hamm', {'weight': 1})
# ('Liam Neeson', 'Emma Thompson', {'weight': 2})
# ('Liam Neeson', 'Harrison Ford', {'weight': 4})
# ('Liam Neeson', 'Cher', {'weight': 1})
# ('Liam Neeson', 'Kristen Wiig', {'weight': 1})
# ('Liam Neeson', 'Will Smith', {'weight': 1})
# ('Liam Neeson', 'Charlize Theron', {'weight': 2})
# ('Liam Neeson', 'Emily Blunt', {'weight': 1})
# ('Liam Neeson', 'Oscar Isaac', {'weight': 1})
# ('Liam Neeson', 'Laura Dern', {'weight': 1})
# ('Liam Neeson', 'Will Ferrell', {'weight': 3})
# ('Liam Neeson', 'Kim Basinger', {'weight': 1})
# ('Liam Neeson', 'Anamaria Marinca', {'weight': 1})
# ('Liam Neeson', 'Robert Duvall', {'weight': 1})
# ('Liam Neeson', 'Jodie Foster', {'weight': 1})
# ('Liam Neeson', 'Paul Rudd', {'weight': 1})
# ('Liam Neeson', 'Daniel Kaluuya', {'weight': 1})
# ('Liam Neeson', 'Kirsten Dunst', {'weight': 1})
# ('Jack Nicholson', 'Shirley MacLaine', {'weight': 2})
# ('Jack Nicholson', 'Diane Keaton', {'weight': 2})
# ('Jack Nicholson', 'Maya Rudolph', {'weight': 1})
# ('Jack Nicholson', 'Marlon Brando', {'weight': 1})
# ('Jack Nicholson', 'Billy Dee Williams', {'weight': 1})
# ('Jack Nicholson', 'Louise Fletcher', {'weight': 1})
# ...
# ('Philip Seymour Hoffman', 'Michelle Monaghan', {'weight': 1})
# ('Philip Seymour Hoffman', 'Gwendoline Christie', {'weight': 1})
# ('Philip Seymour Hoffman', 'Jennifer Jason Leigh', {'weight': 1})
# ('Philip Seymour Hoffman', 'Emily Blunt', {'weight': 1})
# ('Philip Seymour Hoffman', 'Zooey Deschanel', {'weight': 1})
# ('Philip Seymour Hoffman', 'Laura Dern', {'weight': 2})
# ('Philip Seymour Hoffman', 'Gwyneth Paltrow', {'weight': 2})
# ('Philip Seymour Hoffman', 'Kim Basinger', {'weight': 1})
# ('Philip Seymour Hoffman', 'Rachel McAdams', {'weight': 1})
# ('Philip Seymour Hoffman', 'Marisa Tomei', {'weight': 2})
# ('Philip Seymour Hoffman', 'Kate Hudson', {'weight': 1})
# ('Philip Seymour Hoffman', 'Julia Stiles', {'weight': 1})
# ('Michelle Monaghan', 'Chris Evans', {'weight': 1})
# ('Michelle Monaghan', 'Brian Caspe', {'weight': 1})
# ('Michelle Monaghan', 'Leslie Mann', {'weight': 1})
# ('Michelle Monaghan', 'Luke Wilson', {'weight': 1})
# ('Michelle Monaghan', 'Julia Stiles', {'weight': 1})
# ('Anne Hathaway', 'Julia Roberts', {'weight': 1})
# ('Anne Hathaway', 'Shirley MacLaine', {'weight': 1})
# ('Anne Hathaway', 'Brie Larson', {'weight': 2})
# ('Anne Hathaway', 'Scarlett Johansson', {'weight': 1})
# ('Anne Hathaway', 'Judy Greer', {'weight': 2})
# ('Anne Hathaway', 'Timothée Chalamet', {'weight': 1})
# ('Anne Hathaway', 'Mindy Kaling', {'weight': 1})
# ('Anne Hathaway', 'Leslie Mann', {'weight': 2})
# ('Anne Hathaway', 'Emily Blunt', {'weight': 1})
# ('Anne Hathaway', 'Kate Hudson', {'weight': 1})
# ('Leslie Mann', 'Tom Yi', {'weight': 1})
# ('Leslie Mann', 'Megan Fox', {'weight': 1})
# ('Leslie Mann', 'Gwendoline Christie', {'weight': 1})
# ('Leslie Mann', 'Mindy Kaling', {'weight': 1})
# ('Leslie Mann', 'Matthew Perry', {'weight': 1})
# ('Leslie Mann', 'Kristen Wiig', {'weight': 1})
# ('Leslie Mann', 'Jamie Lee Curtis', {'weight': 1})
# ('Leslie Mann', 'Melissa McCarthy', {'weight': 1})
# ('Leslie Mann', 'Kirsten Dunst', {'weight': 1})
# ('Julie Delpy', 'Chris Evans', {'weight': 1})
# ('Julie Delpy', 'Scarlett Johansson', {'weight': 1})
# ('Julie Delpy', 'William Hurt', {'weight': 2})
# ('Jennifer Jason Leigh', 'Brie Larson', {'weight': 2})
# ('Jennifer Jason Leigh', 'Scarlett Johansson', {'weight': 1})
# ('Jennifer Jason Leigh', 'Tom Yi', {'weight': 1})
# ('Jennifer Jason Leigh', 'Andie MacDowell', {'weight': 1})
# ('Jennifer Jason Leigh', 'Meg Ryan', {'weight': 1})
# ('Jennifer Jason Leigh', 'Adrien Brody', {'weight': 1})
# ('Jennifer Jason Leigh', 'Kristen Wiig', {'weight': 2})
# ('Jennifer Jason Leigh', 'Laura Dern', {'weight': 1})
# ('Jennifer Jason Leigh', 'Gwyneth Paltrow', {'weight': 2})
# ('Jennifer Jason Leigh', 'Jamie Lee Curtis', {'weight': 1})
# ('Jennifer Jason Leigh', 'Jack Lemmon', {'weight': 1})
# ('Laura Dern', 'Clint Eastwood', {'weight': 1})
# ('Laura Dern', 'Scarlett Johansson', {'weight': 1})
# ('Laura Dern', 'Daisy Ridley', {'weight': 1})
# ('Laura Dern', 'Judy Greer', {'weight': 1})
# ('Laura Dern', 'Timothée Chalamet', {'weight': 1})
# ('Laura Dern', 'Gwendoline Christie', {'weight': 1})
# ('Laura Dern', 'Anthony Daniels', {'weight': 1})
# ('Laura Dern', 'Maya Rudolph', {'weight': 1})
# ('Laura Dern', "Lupita Nyong'o", {'weight': 1})
# ('Laura Dern', 'Louise Fletcher', {'weight': 1})
# ('Laura Dern', 'Cher', {'weight': 1})
# ('Laura Dern', 'Kristen Wiig', {'weight': 1})
# ('Laura Dern', 'Barbra Streisand', {'weight': 2})
# ('Laura Dern', 'Will Ferrell', {'weight': 2})
# ('Laura Dern', 'Jamie Lee Curtis', {'weight': 1})
# ('Laura Dern', 'Robert Duvall', {'weight': 1})
# ('Laura Dern', 'Jodie Foster', {'weight': 1})
# ('Laura Dern', 'Kate Hudson', {'weight': 1})
# ('Laura Dern', 'Kirsten Dunst', {'weight': 1})
# ('Will Ferrell', 'Shirley MacLaine', {'weight': 1})
# ('Will Ferrell', 'Brie Larson', {'weight': 1})
# ('Will Ferrell', 'Megan Fox', {'weight': 1})
# ('Will Ferrell', 'Anthony Daniels', {'weight': 1})
# ('Will Ferrell', 'Maya Rudolph', {'weight': 6})
# ('Will Ferrell', 'Billy Dee Williams', {'weight': 2})
# ('Will Ferrell', 'Jon Hamm', {'weight': 1})
# ('Will Ferrell', 'Harrison Ford', {'weight': 1})
# ('Will Ferrell', 'Kristen Wiig', {'weight': 4})
# ('Will Ferrell', 'Will Smith', {'weight': 1})
# ('Will Ferrell', 'Zooey Deschanel', {'weight': 3})
# ('Will Ferrell', 'Jamie Lee Curtis', {'weight': 1})
# ('Will Ferrell', 'Rachel McAdams', {'weight': 2})
# ('Will Ferrell', 'Robert Duvall', {'weight': 1})
# ('Will Ferrell', 'Melissa McCarthy', {'weight': 1})
# ('Will Ferrell', 'Marisa Tomei', {'weight': 1})
# ('Will Ferrell', 'Miranda Otto', {'weight': 1})
# ('Will Ferrell', 'Luke Wilson', {'weight': 5})
# ('Will Ferrell', 'Kirsten Dunst', {'weight': 4})
# ('Jamie Lee Curtis', 'Chris Evans', {'weight': 1})
# ('Jamie Lee Curtis', 'Judy Greer', {'weight': 1})
# ('Jamie Lee Curtis', 'Michael Hitchcock', {'weight': 1})
# ('Jamie Lee Curtis', 'Louise Fletcher', {'weight': 1})
# ('Jamie Lee Curtis', 'Gregory Peck', {'weight': 1})
# ('Jamie Lee Curtis', 'Melissa McCarthy', {'weight': 1})
# ('Jamie Lee Curtis', 'Marisa Tomei', {'weight': 1})
# ('Kirsten Dunst', 'Julia Roberts', {'weight': 1})
# ('Kirsten Dunst', 'Antonio Banderas', {'weight': 1})
# ('Kirsten Dunst', 'Judy Greer', {'weight': 1})
# ('Kirsten Dunst', 'Meg Ryan', {'weight': 1})
# ('Kirsten Dunst', 'Megan Fox', {'weight': 1})
# ('Kirsten Dunst', 'Adrien Brody', {'weight': 1})
# ('Kirsten Dunst', 'Ginnifer Goodwin', {'weight': 1})
# ('Kirsten Dunst', 'Maya Rudolph', {'weight': 2})
# ('Kirsten Dunst', 'Jamie Dornan', {'weight': 1})
# ('Kirsten Dunst', 'Harrison Ford', {'weight': 1})
# ('Kirsten Dunst', 'Kristen Wiig', {'weight': 2})
# ('Kirsten Dunst', 'Will Smith', {'weight': 1})
# ('Kirsten Dunst', 'Jennifer Hudson', {'weight': 1})
# ('Kirsten Dunst', 'Julia Stiles', {'weight': 1})
# ('Clint Eastwood', 'Jon Hamm', {'weight': 1})
# ('Jon Hamm', 'Antonio Banderas', {'weight': 2})
# ('Jon Hamm', 'Brie Larson', {'weight': 1})
# ('Jon Hamm', 'Tom Yi', {'weight': 1})
# ('Jon Hamm', 'Megan Fox', {'weight': 1})
# ('Jon Hamm', 'Ginnifer Goodwin', {'weight': 1})
# ('Jon Hamm', 'Gwendoline Christie', {'weight': 1})
# ('Jon Hamm', 'Maya Rudolph', {'weight': 3})
# ('Jon Hamm', 'Jamie Dornan', {'weight': 1})
# ('Jon Hamm', 'Michael Hitchcock', {'weight': 1})
# ('Jon Hamm', 'Geena Davis', {'weight': 1})
# ('Jon Hamm', 'William Hurt', {'weight': 1})
# ('Jon Hamm', 'Kristen Wiig', {'weight': 2})
# ('Jon Hamm', 'Emily Blunt', {'weight': 1})
# ('Jon Hamm', 'Melissa McCarthy', {'weight': 1})
# ('Jon Hamm', 'Marisa Tomei', {'weight': 1})
# ('Olivia Colman', 'Julia Roberts', {'weight': 1})
# ('Olivia Colman', 'Daisy Ridley', {'weight': 1})
# ('Olivia Colman', 'Daniel Kaluuya', {'weight': 1})
# ('Julia Roberts', 'Shirley MacLaine', {'weight': 2})
# ('Julia Roberts', 'Andie MacDowell', {'weight': 1})
# ('Julia Roberts', 'Ginnifer Goodwin', {'weight': 1})
# ('Julia Roberts', "Lupita Nyong'o", {'weight': 1})
# ('Julia Roberts', 'Louise Fletcher', {'weight': 1})
# ('Julia Roberts', 'Rod Steiger', {'weight': 1})
# ('Julia Roberts', 'Harrison Ford', {'weight': 1})
# ('Julia Roberts', 'Cher', {'weight': 2})
# ('Julia Roberts', 'Denzel Washington', {'weight': 1})
# ('Julia Roberts', 'Emily Blunt', {'weight': 1})
# ('Julia Roberts', 'Gwyneth Paltrow', {'weight': 1})
# ('Julia Roberts', 'Kim Basinger', {'weight': 1})
# ('Julia Roberts', 'Robert Duvall', {'weight': 1})
# ('Julia Roberts', 'Kate Hudson', {'weight': 1})
# ('Julia Roberts', 'Julia Stiles', {'weight': 1})
# ('Julia Roberts', 'Jack Lemmon', {'weight': 1})
# ('Daisy Ridley', 'Gwendoline Christie', {'weight': 2})
# ('Daisy Ridley', 'Anthony Daniels', {'weight': 3})
# ('Daisy Ridley', "Lupita Nyong'o", {'weight': 3})
# ('Daisy Ridley', 'Billy Dee Williams', {'weight': 1})
# ('Daisy Ridley', 'Harrison Ford', {'weight': 2})
# ('Daisy Ridley', 'Jennifer Hudson', {'weight': 1})
# ('Daisy Ridley', 'Peter Mayhew', {'weight': 1})
# ('Daniel Kaluuya', 'Timothée Chalamet', {'weight': 1})
# ('Daniel Kaluuya', "Lupita Nyong'o", {'weight': 1})
# ('Daniel Kaluuya', 'Emily Blunt', {'weight': 1})
# ('Daniel Kaluuya', 'Robert Duvall', {'weight': 1})
# ('Antonio Banderas', 'Meg Ryan', {'weight': 1})
# ('Antonio Banderas', 'Adrien Brody', {'weight': 1})
# ('Antonio Banderas', 'Maya Rudolph', {'weight': 1})
# ('Antonio Banderas', 'Harrison Ford', {'weight': 1})
# ('Antonio Banderas', 'Denzel Washington', {'weight': 1})
# ('Antonio Banderas', 'Marisa Tomei', {'weight': 1})
# ('Scarlett Johansson', 'Chris Evans', {'weight': 9})
# ('Scarlett Johansson', 'Brie Larson', {'weight': 3})
# ('Scarlett Johansson', 'Brian Caspe', {'weight': 1})
# ('Scarlett Johansson', 'Ginnifer Goodwin', {'weight': 1})
# ('Scarlett Johansson', "Lupita Nyong'o", {'weight': 1})
# ('Scarlett Johansson', 'William Hurt', {'weight': 3})
# ('Scarlett Johansson', 'Kristen Wiig', {'weight': 1})
# ('Scarlett Johansson', 'Gwyneth Paltrow', {'weight': 4})
# ('Scarlett Johansson', 'Marisa Tomei', {'weight': 2})
# ('Scarlett Johansson', 'Jennifer Hudson', {'weight': 1})
# ('Maximilian Schell', 'Shirley MacLaine', {'weight': 1})
# ('Maximilian Schell', 'Adrien Brody', {'weight': 1})
# ('Maximilian Schell', 'Marlon Brando', {'weight': 1})
# ('Maximilian Schell', 'Rod Steiger', {'weight': 1})
# ('Maximilian Schell', 'Robert Duvall', {'weight': 1})
# ('Maximilian Schell', 'Lee Marvin', {'weight': 1})
# ('Maximilian Schell', 'Luke Wilson', {'weight': 1})
# ('Luke Wilson', 'Chris Evans', {'weight': 2})
# ('Luke Wilson', 'Brie Larson', {'weight': 1})
# ('Luke Wilson', 'Judy Greer', {'weight': 2})
# ('Luke Wilson', 'Maya Rudolph', {'weight': 2})
# ('Luke Wilson', 'Cher', {'weight': 2})
# ('Luke Wilson', 'Kristen Wiig', {'weight': 1})
# ('Luke Wilson', 'Will Smith', {'weight': 1})
# ('Luke Wilson', 'Gwyneth Paltrow', {'weight': 1})
# ('Luke Wilson', 'Rachel McAdams', {'weight': 1})
# ('Luke Wilson', 'Melissa McCarthy', {'weight': 2})
# ('Luke Wilson', 'Kate Hudson', {'weight': 1})
# ('Marlon Brando', 'Harrison Ford', {'weight': 1})
# ('Marlon Brando', 'Robert Duvall', {'weight': 2})
# ('Kim Basinger', 'Chris Evans', {'weight': 1})
# ('Kim Basinger', 'Adrien Brody', {'weight': 1})
# ('Kim Basinger', 'Jamie Dornan', {'weight': 2})
# ('Kim Basinger', 'Billy Dee Williams', {'weight': 1})
# ('Kim Basinger', 'Cher', {'weight': 1})
# ('Kim Basinger', 'Robert Duvall', {'weight': 1})
# ('Robert Duvall', 'Shirley MacLaine', {'weight': 1})
# ('Robert Duvall', 'Brian Caspe', {'weight': 1})
# ('Robert Duvall', 'William Holden', {'weight': 1})
# ('Robert Duvall', 'Harrison Ford', {'weight': 1})
# ('Robert Duvall', 'William Hurt', {'weight': 1})
# ('Robert Duvall', 'Denzel Washington', {'weight': 1})
# ('Robert Duvall', 'Marisa Tomei', {'weight': 1})
# ('Julia Stiles', 'Shirley MacLaine', {'weight': 1})
# ('Julia Stiles', 'Ginnifer Goodwin', {'weight': 1})
# ('Julia Stiles', 'Harrison Ford', {'weight': 1})
# ('Julia Stiles', 'Kristen Wiig', {'weight': 1})
# ('Jack Lemmon', 'Andie MacDowell', {'weight': 2})
# ('Jack Lemmon', 'Louise Fletcher', {'weight': 1})
# ('Jack Lemmon', 'Geena Davis', {'weight': 1})
# ('Jack Lemmon', 'Rod Steiger', {'weight': 1})
# ('Jack Lemmon', 'Cher', {'weight': 1})
# ('Jack Lemmon', 'Will Smith', {'weight': 1})
# ('Geena Davis', 'William Hurt', {'weight': 1})
# ('Barbra Streisand', 'Jennifer Hudson', {'weight': 1})
# ('Gwyneth Paltrow', 'Chris Evans', {'weight': 4})
# ('Gwyneth Paltrow', 'Brie Larson', {'weight': 1})
# ('Gwyneth Paltrow', 'Meg Ryan', {'weight': 1})
# ('Gwyneth Paltrow', 'Maya Rudolph', {'weight': 1})
# ('Gwyneth Paltrow', 'William Hurt', {'weight': 2})
# ('Gwyneth Paltrow', 'Marisa Tomei', {'weight': 2})
# ('Gwyneth Paltrow', 'Kate Hudson', {'weight': 1})
# ('Kate Hudson', 'Ginnifer Goodwin', {'weight': 1})
# ('Kate Hudson', 'Zooey Deschanel', {'weight': 2})
# ('Shirley MacLaine', 'Kristen Wiig', {'weight': 1})
# ('Andie MacDowell', 'Adrien Brody', {'weight': 1})
# ('Andie MacDowell', 'Louise Fletcher', {'weight': 1})
# ('Andie MacDowell', 'Rod Steiger', {'weight': 1})
# ('Andie MacDowell', 'Cher', {'weight': 1})
# ('Andie MacDowell', 'William Hurt', {'weight': 1})
# ('Ginnifer Goodwin', 'Meg Ryan', {'weight': 1})
# ('Ginnifer Goodwin', 'Matthew Perry', {'weight': 1})
# ("Lupita Nyong'o", 'Gwendoline Christie', {'weight': 2})
# ("Lupita Nyong'o", 'Anthony Daniels', {'weight': 4})
# ("Lupita Nyong'o", 'Mindy Kaling', {'weight': 1})
# ("Lupita Nyong'o", 'Billy Dee Williams', {'weight': 2})
# ("Lupita Nyong'o", 'Harrison Ford', {'weight': 3})
# ("Lupita Nyong'o", 'Peter Mayhew', {'weight': 1})
# ('Louise Fletcher', 'Rod Steiger', {'weight': 2})
# ('Louise Fletcher', 'Cher', {'weight': 1})
# ('Louise Fletcher', 'Denzel Washington', {'weight': 1})
# ('Rod Steiger', 'Cher', {'weight': 1})
# ('Rod Steiger', 'Denzel Washington', {'weight': 1})
# ('Rod Steiger', 'Burt Lancaster', {'weight': 1})
# ('Harrison Ford', 'Gwendoline Christie', {'weight': 1})
# ('Harrison Ford', 'Anthony Daniels', {'weight': 8})
# ('Harrison Ford', 'Billy Dee Williams', {'weight': 3})
# ('Harrison Ford', 'Kristen Wiig', {'weight': 1})
# ('Harrison Ford', 'Will Smith', {'weight': 1})
# ('Harrison Ford', 'Rachel McAdams', {'weight': 1})
# ('Harrison Ford', 'Miranda Otto', {'weight': 1})
# ('Harrison Ford', 'Peter Mayhew', {'weight': 6})
# ('Cher', 'Maya Rudolph', {'weight': 1})
# ('Denzel Washington', 'Meg Ryan', {'weight': 1})
# ('Denzel Washington', 'Jodie Foster', {'weight': 1})
# ('Emily Blunt', 'Mindy Kaling', {'weight': 1})
# ('Emily Blunt', 'Jamie Dornan', {'weight': 1})
# ('Kristen Wiig', 'Brian Caspe', {'weight': 1})
# ('Kristen Wiig', 'Tom Yi', {'weight': 2})
# ('Kristen Wiig', 'Judy Greer', {'weight': 1})
# ('Kristen Wiig', 'Megan Fox', {'weight': 1})
# ('Kristen Wiig', 'Mindy Kaling', {'weight': 2})
# ('Kristen Wiig', 'Maya Rudolph', {'weight': 5})
# ('Kristen Wiig', 'Michael Hitchcock', {'weight': 1})
# ('Kristen Wiig', 'Will Smith', {'weight': 1})
# ('Kristen Wiig', 'Melissa McCarthy', {'weight': 3})
# ('Adrien Brody', 'Judy Greer', {'weight': 1})
# ('Adrien Brody', 'William Hurt', {'weight': 1})
# ('Adrien Brody', 'Rachel McAdams', {'weight': 1})
# ('Adrien Brody', 'Miranda Otto', {'weight': 1})
# ('Adrien Brody', 'August Diehl', {'weight': 1})
# ('Maya Rudolph', 'Tom Yi', {'weight': 1})
# ('Maya Rudolph', 'Megan Fox', {'weight': 1})
# ('Maya Rudolph', 'Michael Hitchcock', {'weight': 1})
# ('Maya Rudolph', 'Melissa McCarthy', {'weight': 3})
# ('Maya Rudolph', 'Marisa Tomei', {'weight': 1})
# ('Marisa Tomei', 'Chris Evans', {'weight': 3})
# ('Marisa Tomei', 'Brie Larson', {'weight': 2})
# ('Marisa Tomei', 'Judy Greer', {'weight': 1})
# ('Marisa Tomei', 'Timothée Chalamet', {'weight': 1})
# ('Marisa Tomei', 'Michael Hitchcock', {'weight': 1})
# ('Marisa Tomei', 'William Hurt', {'weight': 2})
# ('Brian Caspe', 'Jamie Dornan', {'weight': 1})
# ('Judy Greer', 'Chris Evans', {'weight': 1})
# ('Judy Greer', 'Brie Larson', {'weight': 1})
# ('Judy Greer', 'Timothée Chalamet', {'weight': 1})
# ('Judy Greer', 'Michael Hitchcock', {'weight': 1})
# ('Judy Greer', 'Billy Dee Williams', {'weight': 1})
# ('Judy Greer', 'William Hurt', {'weight': 1})
# ('Judy Greer', 'Zooey Deschanel', {'weight': 1})
# ('Gwendoline Christie', 'Anthony Daniels', {'weight': 2})
# ('Gwendoline Christie', 'Peter Mayhew', {'weight': 1})
# ('Michael Hitchcock', 'Tom Yi', {'weight': 1})
# ('Michael Hitchcock', 'Melissa McCarthy', {'weight': 3})
# ('William Hurt', 'Chris Evans', {'weight': 3})
# ('William Hurt', 'Brie Larson', {'weight': 1})
# ('William Hurt', 'Will Smith', {'weight': 1})
# ('William Hurt', 'Lee Marvin', {'weight': 1})
# ('Zooey Deschanel', 'Jamie Dornan', {'weight': 1})
# ('Jodie Foster', 'David Niven', {'weight': 1})
# ('Chris Evans', 'Brie Larson', {'weight': 3})
# ('Chris Evans', 'Ziyi Zhang', {'weight': 1})
# ('Brie Larson', 'Mindy Kaling', {'weight': 1})
# ('Rex Harrison', 'William Holden', {'weight': 1})
# ('William Holden', 'David Niven', {'weight': 1})
# ('Lee Marvin', 'Chuck Norris', {'weight': 1})
# ('Gregory Peck', 'Geraldine Page', {'weight': 1})
# ('Gregory Peck', 'David Niven', {'weight': 1})
# ('Burt Lancaster', 'Sidney Poitier', {'weight': 1})
# ('Billy Dee Williams', 'Anthony Daniels', {'weight': 6})
# ('Billy Dee Williams', 'Peter Mayhew', {'weight': 2})
# ('Anthony Daniels', 'Peter Mayhew', {'weight': 9})
# ('Tom Yi', 'Megan Fox', {'weight': 1})
# ('Tom Yi', 'Melissa McCarthy', {'weight': 3})
# ('Megan Fox', 'Will Smith', {'weight': 1})
# ('Megan Fox', 'Melissa McCarthy', {'weight': 1})
# ('Melissa McCarthy', 'Matthew Perry', {'weight': 1})
# ('August Diehl', 'Juliane Köhler', {'weight': 1})
# ('Juliane Köhler', 'Julia Jentsch', {'weight': 2})

# %% [markdown]
# ### Summary
# As you can see from the following visualizations and data, both the graphs do not contain any isolated nodes and are similarly sized, with graph 2 being slightly larger in size than graph 1. We can also see that our edges are weighted correctly.

# %% [markdown]
# ## 2. Network characterisation
# ###  Characterisation Statisitics

# %%
##Charachterising functions##
def components(graph):  #this function tells us how many divided graphs make up the network
    if nx.is_connected(graph):
        print("The whole network is one component, made up of",nx.number_connected_components(graph),"connected component")
    else:
        print("The network is made up of: ",nx.number_connected_components(graph),"connected components")
        
def networkDensity(graph,name): #Density is calculated numerically as the ratio of existing edges over the total number of potential edges between all pairs of nodes.
    n=graph.number_of_nodes()
    potential_edges=(n*(n-1))/2
    density=graph.number_of_edges()/potential_edges
    print(name,"has a network density of",round(density*100,2),"%")
    
def networkDiameter(graph): #he longest shortest path in the entire network
    return nx.diameter(graph)

def meanCluster(graph,name):
    print("The nodes in",name,"have and average clustering coefficient of",round(nx.average_clustering(graph),2))

# %%
components(g1)
# Out:
# The whole network is one component, made up of 1 connected component

# %%
components(g2)
# Out:
# The whole network is one component, made up of 1 connected component

# %%
networkDensity(g1,"g1")
# Out:
# g1 has a network density of 13.1 %

# %%
networkDensity(g2,"g2")
# Out:
# g2 has a network density of 12.26 %

# %%
print("g1 has a network diameter of",networkDiameter(g1))
# Out:
# g1 has a network diameter of 5

# %%
print("g2 has a network diameter of",networkDiameter(g2))
# Out:
# g2 has a network diameter of 7

# %%
meanCluster(g1,"g1")
# Out:
# The nodes in g1 have and average clustering coefficient of 0.29

# %%
meanCluster(g2,"g2")
# Out:
# The nodes in g2 have and average clustering coefficient of 0.29

# %%
#Weight distribution#
def createDF(graph):
    weights = {}
    for node1, node2, data in graph.edges(data=True):
        weights[(node1,node2)] = data["weight"]  
    return pd.Series(weights)

# %%
#histogram
def histogram(df,heading):
    ax = df.plot.hist(figsize=(11,6), fontsize=14, legend=None, color="darkcyan")
    ax.set_title(heading,fontsize=30, color="k")
    ax.set_ylabel("Number of Edges", fontsize=14)
    ax.set_xlabel("Weight", fontsize=14);

# %%
g1_weights=createDF(g1)
g1_weights
# Out:
# Russell Crowe  Diane Kruger            1
#                Christian Bale          1
#                Helena Bonham Carter    1
#                Gene Hackman            1
#                Jane Fonda              1
#                                       ..
# José Ferrer    Ray Milland             1
# Matt Lucas     Elaine Kao              1
# Elaine Kao     Kang Hye-jeong          1
# Alec Guinness  Peter Cushing           1
# Ray Milland    Peter Cushing           1
# Length: 1425, dtype: int64

# %%
g2_weights=createDF(g2)
g2_weights
# Out:
# Colm Meaney       Jason Isaacs        1
#                   Al Pacino           1
#                   Dustin Hoffman      1
#                   Julie Walters       1
#                   Michael Gambon      1
#                                      ..
# Megan Fox         Will Smith          1
#                   Melissa McCarthy    1
# Melissa McCarthy  Matthew Perry       1
# August Diehl      Juliane Köhler      1
# Juliane Köhler    Julia Jentsch       2
# Length: 1559, dtype: int64

# %%
histogram(g1_weights, "g1 weight distribution of node edges")

# %%
histogram(g2_weights,"g2 weight distribution of node edges")

# %%
g1_10_weights=g1_weights.sort_values(ascending=False).head( 10 )
g1_10_weights
# Out:
# Jack Black     Seth Rogen         10
# Emma Watson    Robbie Coltrane    10
# Jack Black     Ben Stiller         9
# Emma Watson    Tom Felton          9
# Tom Felton     Robbie Coltrane     9
# Alan Rickman   Robbie Coltrane     9
# Bonnie Wright  Robbie Coltrane     9
# Tom Felton     Bonnie Wright       9
# Emma Watson    Bonnie Wright       9
#                Alan Rickman        8
# dtype: int64

# %%
g2_10_weights=g2_weights.sort_values(ascending=False).head( 10 )
g2_10_weights
# Out:
# Cameron Diaz        Eddie Murphy        10
# Daniel Radcliffe    James Phelps         9
# Scarlett Johansson  Chris Evans          9
# Anthony Daniels     Peter Mayhew         9
# Julie Walters       Michael Gambon       8
# Harrison Ford       Anthony Daniels      8
# Jonah Hill          Kristen Wiig         8
# Michael Gambon      Mark Williams        7
# Julie Walters       Daniel Radcliffe     7
# Mark Williams       Daniel Radcliffe     7
# dtype: int64

# %%
g2_10_weights["Daniel Radcliffe"]
# Out:
# James Phelps    9
# dtype: int64

# %%
#Node Degrees- function that creates a dataframe of each node and the degrees
def degrees_df(graph):
    degrees = dict( graph.degree() )
    return pd.Series(degrees)

def degreeData(df):
    print('Degree range: [%d, %d]' % (df.min(), df.max() ) )
    print('Mean degree: %.2f' % df.mean() )
    print('Median degree: %d' % df.median() )

def deghistogram(df,heading):
    ax = df.plot.hist(figsize=(11,6), fontsize=14, legend=None, color="darkorange")
    ax.set_title(heading,fontsize=30, color="k")
    ax.set_ylabel("Number of nodes", fontsize=14)
    ax.set_xlabel("Degree", fontsize=14);
    
def centralityData(graph):
    deg = nx.degree_centrality(graph)
    bet = nx.betweenness_centrality(graph, weight="weight")
    eig = nx.eigenvector_centrality(graph, weight="weight")
    close = nx.closeness_centrality(graph)
    s = pd.Series(deg)
    df = pd.DataFrame(s,columns=["degree_centrality"])
    df["weighted betweenness"] = pd.Series(bet)
    df["closeness"] = pd.Series(close)
    df["weighted eigenvector"] = pd.Series(eig)
    return df.sort_values(by="degree_centrality",ascending=False)

# %%
degreesg1=degrees_df(g1)
degreesg2=degrees_df(g2)

print(" ________\n|g1 stats|\n|________|")
degreeData(degreesg1)
print(" ________\n|g2 stats|\n|________|")
degreeData(degreesg2)
# Out:
#  ________
# |g1 stats|
# |________|
# Degree range: [1, 55]
# Mean degree: 19.26
# Median degree: 19
#  ________
# |g2 stats|
# |________|
# Degree range: [1, 55]
# Mean degree: 19.49
# Median degree: 18

# %%
deghistogram(degreesg1, "g1 Degree Distribution")

# %%
deghistogram(degreesg2, "g2 Degree Distribution")

# %%
g1measures=centralityData(g1)
g1measures.head(10)
# Out:
#                   degree_centrality  weighted betweenness  closeness  \
# Susan Sarandon             0.374150              0.048997   0.602459
# Bruce Willis               0.319728              0.036189   0.588000
# Meryl Streep               0.306122              0.018517   0.571984
# Edward Norton              0.292517              0.032631   0.565385
# Robert De Niro             0.285714              0.026997   0.561069
# Anthony Hopkins            0.278912              0.019351   0.561069
# David Thewlis              0.272109              0.013728   0.556818
# Ciarán Hinds               0.258503              0.019528   0.548507
# Jim Broadbent              0.251701              0.006017   0.554717
# Sigourney Weaver           0.244898              0.040316   0.556818
#
#                   weighted eigenvector
# Susan Sarandon                0.050505
# Bruce Willis                  0.039087
# Meryl Streep                  0.048326
# Edward Norton                 0.032816
# Robert De Niro                0.037030
# Anthony Hopkins               0.045871
# David Thewlis                 0.257465
# Ciarán Hinds                  0.108681
# Jim Broadbent                 0.199124
# Sigourney Weaver              0.044349

# %%
g1measures.corr()
# Out:
#                       degree_centrality  weighted betweenness  closeness  \
# degree_centrality              1.000000              0.809563   0.934555
# weighted betweenness           0.809563              1.000000   0.711475
# closeness                      0.934555              0.711475   1.000000
# weighted eigenvector           0.373150              0.115504   0.317151
#
#                       weighted eigenvector
# degree_centrality                 0.373150
# weighted betweenness              0.115504
# closeness                         0.317151
# weighted eigenvector              1.000000

# %% [markdown]
# We can see that weighted eigenvector is the lowest correlating

# %%
g1ms=g1measures.sort_values(by="weighted eigenvector",ascending=False).head(10)
g1ms
# Out:
#                       degree_centrality  weighted betweenness  closeness  \
# Robbie Coltrane                0.217687              0.004912   0.536496
# Alan Rickman                   0.217687              0.023075   0.542435
# Emma Watson                    0.163265              0.004297   0.508651
# Tom Felton                     0.122449              0.002220   0.469649
# Bonnie Wright                  0.102041              0.000031   0.455108
# Maggie Smith                   0.210884              0.015037   0.525000
# David Thewlis                  0.272109              0.013728   0.556818
# Helena Bonham Carter           0.238095              0.007069   0.542435
# Imelda Staunton                0.156463              0.001253   0.503425
# Jim Broadbent                  0.251701              0.006017   0.554717
#
#                       weighted eigenvector
# Robbie Coltrane                   0.355881
# Alan Rickman                      0.344466
# Emma Watson                       0.335090
# Tom Felton                        0.325524
# Bonnie Wright                     0.318367
# Maggie Smith                      0.294546
# David Thewlis                     0.257465
# Helena Bonham Carter              0.239587
# Imelda Staunton                   0.216268
# Jim Broadbent                     0.199124

# %%
plt.figure(figsize=(20,10))
plt.plot(g1ms)
plt.title("Centrality Measures of Top Eigenvectored Actors", fontsize=30, color="darkorchid")
plt.xticks(rotation=15, fontsize=14)
plt.yticks(fontsize=14)
plt.gca().legend(("degree_centrality","weighted betweenness","closeness","weighted eigenvector"))
plt.show()

# %%
degreesg1.sort_values(ascending=False).head(10)
# Out:
# Susan Sarandon      55
# Bruce Willis        47
# Meryl Streep        45
# Edward Norton       43
# Robert De Niro      42
# Anthony Hopkins     41
# David Thewlis       40
# Ciarán Hinds        38
# Jim Broadbent       37
# Sigourney Weaver    36
# dtype: int64

# %%
g1_10_weights
# Out:
# Jack Black     Seth Rogen         10
# Emma Watson    Robbie Coltrane    10
# Jack Black     Ben Stiller         9
# Emma Watson    Tom Felton          9
# Tom Felton     Robbie Coltrane     9
# Alan Rickman   Robbie Coltrane     9
# Bonnie Wright  Robbie Coltrane     9
# Tom Felton     Bonnie Wright       9
# Emma Watson    Bonnie Wright       9
#                Alan Rickman        8
# dtype: int64

# %%
g2measures=centralityData(g2)
g2measures.head(10)
# Out:
#                  degree_centrality  weighted betweenness  closeness  \
# Julianne Moore            0.345912              0.037814   0.565836
# Liam Neeson               0.314465              0.033123   0.561837
# Paul Rudd                 0.295597              0.020690   0.554007
# John Lithgow              0.264151              0.031593   0.542662
# Woody Harrelson           0.257862              0.014129   0.538983
# Julia Roberts             0.257862              0.025543   0.540816
# Kirsten Dunst             0.251572              0.031874   0.548276
# Penélope Cruz             0.251572              0.035592   0.544521
# Ralph Fiennes             0.251572              0.010459   0.544521
# Will Ferrell              0.245283              0.009627   0.535354
#
#                  weighted eigenvector
# Julianne Moore               0.069118
# Liam Neeson                  0.088089
# Paul Rudd                    0.063347
# John Lithgow                 0.038453
# Woody Harrelson              0.060458
# Julia Roberts                0.040347
# Kirsten Dunst                0.042155
# Penélope Cruz                0.048110
# Ralph Fiennes                0.251351
# Will Ferrell                 0.072691

# %%
g2measures.corr()
# Out:
#                       degree_centrality  weighted betweenness  closeness  \
# degree_centrality              1.000000              0.674368   0.874649
# weighted betweenness           0.674368              1.000000   0.527439
# closeness                      0.874649              0.527439   1.000000
# weighted eigenvector           0.347646              0.020088   0.294091
#
#                       weighted eigenvector
# degree_centrality                 0.347646
# weighted betweenness              0.020088
# closeness                         0.294091
# weighted eigenvector              1.000000

# %%
g2ms=g2measures.sort_values(by="weighted eigenvector",ascending=False).head(10)
g2ms
# Out:
#                    degree_centrality  weighted betweenness  closeness  \
# Michael Gambon              0.226415              0.009900   0.531773
# Daniel Radcliffe            0.125786              0.000317   0.478916
# James Phelps                0.081761              0.000000   0.434426
# Julie Walters               0.150943              0.002812   0.492260
# Mark Williams               0.106918              0.000470   0.464912
# Jason Isaacs                0.194969              0.011438   0.511254
# Ralph Fiennes               0.251572              0.010459   0.544521
# Richard Griffiths           0.144654              0.005734   0.486239
# Fiona Shaw                  0.157233              0.003901   0.496875
# Chris Rankin                0.081761              0.000048   0.434426
#
#                    weighted eigenvector
# Michael Gambon                 0.324241
# Daniel Radcliffe               0.319250
# James Phelps                   0.316472
# Julie Walters                  0.316239
# Mark Williams                  0.299641
# Jason Isaacs                   0.265573
# Ralph Fiennes                  0.251351
# Richard Griffiths              0.247067
# Fiona Shaw                     0.238173
# Chris Rankin                   0.214388

# %%
plt.figure(figsize=(20,10))
plt.plot(g2ms)
plt.title("Centrality Measures of Top Eigenvectored Actors", fontsize=30, color="darkorchid")
plt.xticks(rotation=15, fontsize=14)
plt.yticks(fontsize=14)
plt.gca().legend(("degree_centrality","weighted betweenness","closeness","weighted eigenvector"))
plt.show()

# %%
degreesg2.sort_values(ascending=False).head(10)
# Out:
# Julianne Moore         55
# Liam Neeson            50
# Paul Rudd              47
# John Lithgow           42
# Julia Roberts          41
# Woody Harrelson        41
# Ralph Fiennes          40
# Kirsten Dunst          40
# Penélope Cruz          40
# Matthew McConaughey    39
# dtype: int64

# %%
g2_10_weights
# Out:
# Cameron Diaz        Eddie Murphy        10
# Daniel Radcliffe    James Phelps         9
# Scarlett Johansson  Chris Evans          9
# Anthony Daniels     Peter Mayhew         9
# Julie Walters       Michael Gambon       8
# Harrison Ford       Anthony Daniels      8
# Jonah Hill          Kristen Wiig         8
# Michael Gambon      Mark Williams        7
# Julie Walters       Daniel Radcliffe     7
# Mark Williams       Daniel Radcliffe     7
# dtype: int64

# %% [markdown]
# # 3. Ego-centric analysis

# %%
g1_ego_node="Robbie Coltrane"
g2_ego_node="Michael Gambon"

# %%
eg1 = nx.ego_graph(g1, g1_ego_node)
eg2 = nx.ego_graph(g2, g2_ego_node)

# %%
##Egocentric graphs statistics##
def egoStats(eg):
    networkSizes(eg)
    showNodes(eg)

def display_ego(g, ego_node):
    # build the ego network
    eg = nx.ego_graph(g, ego_node)
    # create the figure
    plt.figure(figsize=(20,25))
    plt.margins(0.1, 0.1)
    title = "Ego network for %s (%d nodes)" % (ego_node, eg.number_of_nodes())
    plt.title(title, fontsize=14)
    # lay out all nodes
    pos = nx.spring_layout(g)
    # draw the full network
    nx.draw_networkx(eg, pos, with_labels=True, font_size=12, node_size=900, node_color="paleturquoise", font_color="red",edge_color="gold")
    # draw the ego in red, with larger node size
    nx.draw_networkx_nodes(eg, pos, nodelist=[ego_node], node_size=2500, node_color="darkorange")
    plt.axis("off")
    
def barChart(df, header):
    p = df.plot.bar(figsize=(19, 10), fontsize=14)
    p.set_title(header, fontsize=35, color="k")
    plt.xticks(rotation=45, fontsize=14)
    #p.set_xlabel('% change from baseline', fontsize=24,color="blue")
    p.set_ylabel("Number of Neigbouring Nodes", fontsize=24,color="k")

# %%
print(" _________\n|eg1 stats|\n|_________|")
egoStats(eg1)
print(" _________\n|eg2 stats|\n|_________|")
egoStats(eg2)
# Out:
#  _________
# |eg1 stats|
# |_________|
# Number of nodes: 33
# Number of edges: 223
# ('Robbie Coltrane', {})
# ('Emma Watson', {})
# ('Colin Firth', {})
# ('Mickey Rourke', {})
# ('Rachel Weisz', {})
# ('Tilda Swinton', {})
# ('Mark Hamill', {})
# ('Kenneth Branagh', {})
# ('Jim Broadbent', {})
# ('Julie Christie', {})
# ('Pam Ferris', {})
# ('Helen McCrory', {})
# ('Christian Bale', {})
# ('Toby Jones', {})
# ('Laura Linney', {})
# ('Richard Dreyfuss', {})
# ('Bonnie Wright', {})
# ('Imelda Staunton', {})
# ('Andy Serkis', {})
# ('David Thewlis', {})
# ('Pierce Brosnan', {})
# ('Alan Rickman', {})
# ('Bruce Willis', {})
# ('Ciarán Hinds', {})
# ('Maggie Smith', {})
# ('F. Murray Abraham', {})
# ('Sigourney Weaver', {})
# ('Uma Thurman', {})
# ('Matt Damon', {})
# ('Tom Felton', {})
# ('Ian McKellen', {})
# ('Ben Kingsley', {})
# ('Helena Bonham Carter', {})
#  _________
# |eg2 stats|
# |_________|
# Number of nodes: 37
# Number of edges: 212
# ('Fiona Shaw', {})
# ('William Hurt', {})
# ('Brian Caspe', {})
# ('Julianne Moore', {})
# ('Jason Isaacs', {})
# ('Julie Walters', {})
# ('Scarlett Johansson', {})
# ('Julia Stiles', {})
# ('Daniel Radcliffe', {})
# ('Denzel Washington', {})
# ('Jeff Bridges', {})
# ('Michael Gambon', {})
# ('Mark Williams', {})
# ('Kate Winslet', {})
# ('Domhnall Gleeson', {})
# ('Richard Griffiths', {})
# ('Penélope Cruz', {})
# ('Owen Wilson', {})
# ('Halle Berry', {})
# ('Chris Rankin', {})
# ('Julia Roberts', {})
# ('Nicole Kidman', {})
# ('Jonah Hill', {})
# ('Marlon Brando', {})
# ('Adrien Brody', {})
# ('Ralph Fiennes', {})
# ('Judi Dench', {})
# ('Ian Hart', {})
# ('Liv Tyler', {})
# ('Gwyneth Paltrow', {})
# ('Robert Duvall', {})
# ('James Phelps', {})
# ('Emma Thompson', {})
# ('Gabriel Byrne', {})
# ('Jonathan Rhys Meyers', {})
# ('Al Pacino', {})
# ('Colm Meaney', {})

# %%
display_ego(eg1,g1_ego_node)

# %%
components(eg1)
# Out:
# The whole network is one component, made up of 1 connected component

# %%
networkDenisty(eg1,"eg1")
# Out:
# eg1 has a network density of 0.42

# %%
networkDiameter(eg1)
# Out:
# 2

# %%
meanCluster(eg1,"eg1")
# Out:
# The nodes in eg1 have and average clustering coefficient of 0.62

# %%
eg1_weights=createDF(eg1)
histogram(eg1_weights,"eg1 weight distribution of node edges")

# %%
eg1_10_weights=eg1_weights.sort_values(ascending=False).head(10)
eg1_10_weights
# Out:
# Robbie Coltrane  Emma Watson      10
# Emma Watson      Bonnie Wright     9
# Robbie Coltrane  Bonnie Wright     9
# Bonnie Wright    Tom Felton        9
# Robbie Coltrane  Alan Rickman      9
#                  Tom Felton        9
# Emma Watson      Tom Felton        9
# Alan Rickman     Tom Felton        8
# Bonnie Wright    Alan Rickman      8
# Emma Watson      Alan Rickman      8
# dtype: int64

# %%
degrees_eg1=degrees_df(eg1)
deghistogram(degrees_eg1,"eg1 Degree Distribution")

# %%
eg1deg=degrees_eg1.sort_values(ascending=False).head(10)
eg1deg
# Out:
# Robbie Coltrane         32
# David Thewlis           24
# Alan Rickman            22
# Jim Broadbent           20
# Toby Jones              19
# Helena Bonham Carter    18
# Imelda Staunton         17
# Maggie Smith            17
# Emma Watson             17
# Colin Firth             17
# dtype: int64

# %%
type(eg1deg)
# Out:
# pandas.core.series.Series

# %%
barChart(eg1deg,"Number of Present Co Stars Per Actor ")

# %% [markdown]
# ## Ego Network 2

# %%
display_ego(eg2,g2_ego_node)

# %%
components(eg2)
# Out:
# The whole network is one component, made up of 1 connected component

# %%
networkDenisty(eg2,"eg2")
# Out:
# eg2 has a network density of 0.32

# %%
networkDiameter(eg2)
# Out:
# 2

# %%
meanCluster(eg2,"eg2")
# Out:
# The nodes in eg2 have and average clustering coefficient of 0.6

# %%
eg2_weights=createDF(eg2)
histogram(eg2_weights,"eg2 weight distribution of node edges")

# %%
eg2_10_weights=eg2_weights.sort_values(ascending=False).head(10)
eg2_10_weights
# Out:
# Daniel Radcliffe  James Phelps        9
# Julie Walters     Michael Gambon      8
#                   Daniel Radcliffe    7
# Michael Gambon    Mark Williams       7
# Daniel Radcliffe  Michael Gambon      7
#                   Mark Williams       7
# Michael Gambon    James Phelps        7
# Julie Walters     James Phelps        7
# Mark Williams     James Phelps        7
# Michael Gambon    Emma Thompson       6
# dtype: int64

# %%
degrees_eg2=degrees_df(eg2)
deghistogram(degrees_eg2,"eg2 Degree Distribution")

# %%
eg2deg=degrees_eg2.sort_values(ascending=False).head(10)
eg2deg
# Out:
# Michael Gambon       36
# Ralph Fiennes        24
# Fiona Shaw           17
# Richard Griffiths    16
# Jason Isaacs         16
# Ian Hart             16
# Julie Walters        16
# Mark Williams        16
# Emma Thompson        15
# Julianne Moore       14
# dtype: int64

# %%
type(eg2deg)
# Out:
# pandas.core.series.Series

# %%
barChart(eg2deg,"Number of Present Co Stars Per Actor ")

# %% [markdown]
# # 4. Network visualisation

# %%
# Write GEXF XML format
nx.write_gexf(g1, "18391933g1.gexf", prettyprint=True)
nx.write_gexf(g2, "18391933g2.gexf", prettyprint=True)
